# %%
import pandas as pd
from os import chdir, listdir
import zipfile
import os
import cv2

import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-17 14:12:06--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-17 14:12:06--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [          <=>       ] 984.93M  22.3MB/s    in 46s
#
# 2022-01-17 14:12:52 (21.4 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1032774646]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %%
import random

# shuffle train image data
c = list(zip(train_imgs, train_names))

# make sure shuffle is the same each time
random.seed(4)
random.shuffle(c)

train_imgs, train_names = zip(*c)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

# %% [markdown]
# # Processing tabular data
# Create seperate numpy arrays of the input and outputs.

# %%
# split the dataset into training and validation set
split_threshold = int(0.2 * len(train_names))

val_tabular = train_data_sorted[:split_threshold]
train_tabular = train_data_sorted[split_threshold:]

val_images = train_imgs[:split_threshold]
train_images = train_imgs[split_threshold:]

# %%
# Make numpy arrays of images for further analysis
train_imgs_array = np.array(train_images)
val_imgs_array = np.array(val_images)
test_imgs_array = np.array(test_imgs)

# %%
# Select x-values (the 12 input features) from training data
x_train_tabular = train_tabular.iloc[:,1:13].to_numpy()

# Select y-values (pawpularity) from training data
y_train = train_tabular.iloc[:,13].to_numpy()

# select x and y values of validation dataset
x_val_tabular = val_tabular.iloc[:,1:13].to_numpy()
y_val = val_tabular.iloc[:,13].to_numpy()

# Select x-values (12 input features) from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()

# Select y-values (pawpularity) from testing data
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create a hidden layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation='relu', input_shape=(input_size,)))
    
    return model

# Create neural network for tabular data and get summary of model 
# with 12 inputs and 100 hidden nodes
tabular_NN = build_neural_net(12, hidden_nodes=20)
tabular_NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                260
#
# =================================================================
# Total params: 260
# Trainable params: 260
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=image_size, padding='same'))
    
    # Create a maxpool layer
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))

    # Create a maxpool layer
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))
    
    return model

# %%
# Create neural network for image data and get summary of model
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size, hidden_nodes=20)
image_NN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense_1 (Dense)             (None, 20)                655380
#
# =================================================================
# Total params: 731,028
# Trainable params: 731,028
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layers of the concatenated model
    hidden_layer_1 = layers.Dense(hidden_nodes, activation="relu")(concat_input)
    hidden_layer_2 = layers.Dense(hidden_nodes, activation="relu")(hidden_layer_1)
    output_layer = layers.Dense(1, activation="linear")(hidden_layer_2)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
# Part of code from: https://www.tensorflow.org/tutorials/keras/regression

def plot_loss(history):
    """
    Plot loss during epochs of training a neural network.
    """
    
    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    for i, metric in enumerate(['loss', 'root_mean_squared_error']):
        axs[i].plot(history.history[metric])
        axs[i].plot(history.history['val_'+metric])
        axs[i].legend(['training', 'validation'], loc='best')

        axs[i].set_title('Model '+metric)
        axs[i].set_ylabel(metric)
        axs[i].set_xlabel('epoch')

    plt.show()


def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
  # Compile model and use mean squared error as loss and root mean squared error as metric
  model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

  # preprocess
  train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
  train_gen.fit(image_x)

  val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
  val_gen.fit(image_x)

  # Train the model by fitting both tabular and image data at the same time
  history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs=epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

  # plot the loss and metric
  plot_loss(history)
  print(f"Validation Accuracy: {model.evaluate(val_gen.flow([x_val_imgs, x_val_tabular], val_y))[1]}")

# Concatenate tabular and image neural networks
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)

# Train model on both tabular and image data
train_and_evaluate(concat_model, train_imgs_array, x_train_tabular, y_train, 
                   x_val_tabular, val_imgs_array, y_val,
                   preprocess={'featurewise_center': True, 'featurewise_std_normalization': True}, epochs = 20)

# See how the model scored
loss = concat_model.evaluate([test_imgs_array, x_test_tabular], y_test)

# Print to 3 decimals
print(f'Test loss: {loss}')
# Out:
# Epoch 1/20
# 248/248 [==============================] - 12s 13ms/step - loss: 520.4437 - root_mean_squared_error: 22.8132 - val_loss: 492.0011 - val_root_mean_squared_error: 22.1811
# Epoch 2/20
# 248/248 [==============================] - 3s 11ms/step - loss: 474.3655 - root_mean_squared_error: 21.7799 - val_loss: 461.8930 - val_root_mean_squared_error: 21.4917
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 461.1461 - root_mean_squared_error: 21.4743 - val_loss: 464.0248 - val_root_mean_squared_error: 21.5412
# Epoch 4/20
# 248/248 [==============================] - 3s 11ms/step - loss: 448.0004 - root_mean_squared_error: 21.1660 - val_loss: 443.8263 - val_root_mean_squared_error: 21.0672
# Epoch 5/20
# 248/248 [==============================] - 3s 11ms/step - loss: 433.9113 - root_mean_squared_error: 20.8305 - val_loss: 426.8120 - val_root_mean_squared_error: 20.6594
# Epoch 6/20
# 248/248 [==============================] - 3s 11ms/step - loss: 421.1548 - root_mean_squared_error: 20.5221 - val_loss: 428.3765 - val_root_mean_squared_error: 20.6973
# Epoch 7/20
# 248/248 [==============================] - 3s 11ms/step - loss: 406.8086 - root_mean_squared_error: 20.1695 - val_loss: 455.8032 - val_root_mean_squared_error: 21.3495
# Epoch 8/20
# 248/248 [==============================] - 3s 11ms/step - loss: 392.9055 - root_mean_squared_error: 19.8218 - val_loss: 467.7135 - val_root_mean_squared_error: 21.6267
# Epoch 9/20
# 248/248 [==============================] - 3s 11ms/step - loss: 369.7914 - root_mean_squared_error: 19.2300 - val_loss: 518.1223 - val_root_mean_squared_error: 22.7623
# Epoch 10/20
# 248/248 [==============================] - 3s 11ms/step - loss: 345.3096 - root_mean_squared_error: 18.5825 - val_loss: 620.8364 - val_root_mean_squared_error: 24.9166
# Epoch 11/20
# 248/248 [==============================] - 3s 11ms/step - loss: 318.9813 - root_mean_squared_error: 17.8600 - val_loss: 500.6480 - val_root_mean_squared_error: 22.3752
# Epoch 12/20
# 248/248 [==============================] - 3s 11ms/step - loss: 282.4795 - root_mean_squared_error: 16.8071 - val_loss: 528.5272 - val_root_mean_squared_error: 22.9897
# Epoch 13/20
# 248/248 [==============================] - 3s 11ms/step - loss: 246.6622 - root_mean_squared_error: 15.7055 - val_loss: 500.8969 - val_root_mean_squared_error: 22.3807
# Epoch 14/20
# 248/248 [==============================] - 3s 11ms/step - loss: 208.5898 - root_mean_squared_error: 14.4426 - val_loss: 569.5859 - val_root_mean_squared_error: 23.8660
# Epoch 15/20
# 248/248 [==============================] - 3s 12ms/step - loss: 180.7204 - root_mean_squared_error: 13.4432 - val_loss: 532.8836 - val_root_mean_squared_error: 23.0843
# Epoch 16/20
# 248/248 [==============================] - 3s 11ms/step - loss: 149.2731 - root_mean_squared_error: 12.2177 - val_loss: 571.2195 - val_root_mean_squared_error: 23.9002
# Epoch 17/20
# 248/248 [==============================] - 3s 11ms/step - loss: 127.5199 - root_mean_squared_error: 11.2925 - val_loss: 614.0239 - val_root_mean_squared_error: 24.7795
# Epoch 18/20
# 248/248 [==============================] - 3s 11ms/step - loss: 108.9915 - root_mean_squared_error: 10.4399 - val_loss: 574.0652 - val_root_mean_squared_error: 23.9597
# Epoch 19/20
# 248/248 [==============================] - 3s 11ms/step - loss: 94.1933 - root_mean_squared_error: 9.7053 - val_loss: 591.6718 - val_root_mean_squared_error: 24.3243
# Epoch 20/20
# 248/248 [==============================] - 3s 11ms/step - loss: 81.5523 - root_mean_squared_error: 9.0306 - val_loss: 626.6588 - val_root_mean_squared_error: 25.0332
# 62/62 [==============================] - 0s 6ms/step - loss: 626.6588 - root_mean_squared_error: 25.0332
# Validation Accuracy: 25.033153533935547
# 1/1 [==============================] - 0s 211ms/step - loss: 2129.4934 - root_mean_squared_error: 46.1464
# Test loss: [2129.493408203125, 46.14643478393555]

# %%
from sklearn.model_selection import KFold

def k_fold(num_folds, tabular_data, image_data, model1, model2, epochs=20, preprocess={}, augment={}):
    # Select x-values (the 12 input features) from training data
    x_tabular = tabular_data.iloc[:,1:13].to_numpy()

    x_imgs = np.array(image_data)

    y = tabular_data.iloc[:,13].to_numpy()

    kfold = KFold(n_splits=num_folds, shuffle=True)
    x_indices = np.array(range(len(x_tabular)))
    y_indices = np.array(range(len(y)))

    train_loss = [0,0]
    val_loss = [0,0]

    for id_train, id_val in kfold.split(x_indices, y_indices):
        x_tabular_train = x_tabular[id_train]
        x_imgs_train = x_imgs[id_train]
        y_train = y[id_train]
        
        x_tabular_val = x_tabular[id_val]
        x_imgs_val = x_imgs[id_val]
        y_val_2 = y[id_val]

        concat_model = concatenate_models(model1, model2, hidden_nodes=20)
        train_and_evaluate(concat_model, x_imgs_train, x_tabular_train, y_train, x_tabular_val, x_imgs_val, y_val_2, epochs=20, preprocess={}, augment={})

        train_loss += concat_model.evaluate([x_imgs_train, x_tabular_train], y_train)
        val_loss += concat_model.evaluate([x_imgs_val, x_tabular_val], y_val_2)

    # avg_train_loss = train_loss / num_folds
    # avg_val_loss = val_loss / num_folds

    # return avg_train_loss, avg_val_loss

avg_train_loss, avg_val_loss = k_fold(5, train_data_sorted, train_imgs,image_NN, tabular_NN)
# Out:
# Epoch 1/20
# 248/248 [==============================] - 4s 12ms/step - loss: 460.9771 - root_mean_squared_error: 21.4704 - val_loss: 446.5755 - val_root_mean_squared_error: 21.1323
# Epoch 2/20
# 248/248 [==============================] - 3s 11ms/step - loss: 420.4117 - root_mean_squared_error: 20.5039 - val_loss: 415.5478 - val_root_mean_squared_error: 20.3850
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 376.3549 - root_mean_squared_error: 19.3999 - val_loss: 390.5077 - val_root_mean_squared_error: 19.7613
# Epoch 4/20
# 248/248 [==============================] - 3s 11ms/step - loss: 328.0415 - root_mean_squared_error: 18.1119 - val_loss: 370.0711 - val_root_mean_squared_error: 19.2372
# Epoch 5/20
# 248/248 [==============================] - 3s 11ms/step - loss: 275.6480 - root_mean_squared_error: 16.6026 - val_loss: 402.6071 - val_root_mean_squared_error: 20.0651
# Epoch 6/20
# 248/248 [==============================] - 3s 10ms/step - loss: 234.5113 - root_mean_squared_error: 15.3138 - val_loss: 342.0367 - val_root_mean_squared_error: 18.4942
# Epoch 7/20
# 248/248 [==============================] - 3s 11ms/step - loss: 199.6211 - root_mean_squared_error: 14.1287 - val_loss: 341.1046 - val_root_mean_squared_error: 18.4690
# Epoch 8/20
# 248/248 [==============================] - 3s 11ms/step - loss: 171.3535 - root_mean_squared_error: 13.0902 - val_loss: 345.2340 - val_root_mean_squared_error: 18.5805
# Epoch 9/20
# 248/248 [==============================] - 3s 11ms/step - loss: 150.2565 - root_mean_squared_error: 12.2579 - val_loss: 380.7989 - val_root_mean_squared_error: 19.5141
# Epoch 10/20
# 248/248 [==============================] - 3s 11ms/step - loss: 132.7215 - root_mean_squared_error: 11.5205 - val_loss: 353.2162 - val_root_mean_squared_error: 18.7940
# Epoch 11/20
# 248/248 [==============================] - 3s 11ms/step - loss: 117.8539 - root_mean_squared_error: 10.8561 - val_loss: 356.5513 - val_root_mean_squared_error: 18.8826
# Epoch 12/20
# 248/248 [==============================] - 3s 11ms/step - loss: 105.8710 - root_mean_squared_error: 10.2894 - val_loss: 367.7853 - val_root_mean_squared_error: 19.1777
# Epoch 13/20
# 248/248 [==============================] - 3s 11ms/step - loss: 93.4391 - root_mean_squared_error: 9.6664 - val_loss: 393.6515 - val_root_mean_squared_error: 19.8407
# Epoch 14/20
# 248/248 [==============================] - 3s 11ms/step - loss: 85.3463 - root_mean_squared_error: 9.2383 - val_loss: 366.5998 - val_root_mean_squared_error: 19.1468
# Epoch 15/20
# 248/248 [==============================] - 3s 11ms/step - loss: 78.5956 - root_mean_squared_error: 8.8654 - val_loss: 372.7088 - val_root_mean_squared_error: 19.3057
# Epoch 16/20
# 248/248 [==============================] - 3s 11ms/step - loss: 70.8426 - root_mean_squared_error: 8.4168 - val_loss: 391.6712 - val_root_mean_squared_error: 19.7907
# Epoch 17/20
# 248/248 [==============================] - 3s 10ms/step - loss: 66.3424 - root_mean_squared_error: 8.1451 - val_loss: 394.3536 - val_root_mean_squared_error: 19.8583
# Epoch 18/20
# 248/248 [==============================] - 3s 11ms/step - loss: 60.3232 - root_mean_squared_error: 7.7668 - val_loss: 406.0721 - val_root_mean_squared_error: 20.1512
# Epoch 19/20
# 248/248 [==============================] - 3s 11ms/step - loss: 55.7250 - root_mean_squared_error: 7.4649 - val_loss: 396.4771 - val_root_mean_squared_error: 19.9117
# Epoch 20/20
# 248/248 [==============================] - 3s 11ms/step - loss: 52.2378 - root_mean_squared_error: 7.2276 - val_loss: 382.8029 - val_root_mean_squared_error: 19.5653
# 62/62 [==============================] - 0s 5ms/step - loss: 382.8029 - root_mean_squared_error: 19.5653
# Validation Accuracy: 19.565349578857422
# 248/248 [==============================] - 1s 5ms/step - loss: 41.0601 - root_mean_squared_error: 6.4078
# 62/62 [==============================] - 0s 5ms/step - loss: 382.8030 - root_mean_squared_error: 19.5654
# Epoch 1/20
# 248/248 [==============================] - 3s 11ms/step - loss: 414.5833 - root_mean_squared_error: 20.3613 - val_loss: 367.6082 - val_root_mean_squared_error: 19.1731
# Epoch 2/20
# 248/248 [==============================] - 3s 10ms/step - loss: 315.8369 - root_mean_squared_error: 17.7718 - val_loss: 250.6686 - val_root_mean_squared_error: 15.8325
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 223.6601 - root_mean_squared_error: 14.9553 - val_loss: 194.6017 - val_root_mean_squared_error: 13.9500
# Epoch 4/20
# 248/248 [==============================] - 3s 10ms/step - loss: 166.9875 - root_mean_squared_error: 12.9224 - val_loss: 193.6908 - val_root_mean_squared_error: 13.9173
# Epoch 5/20
# 248/248 [==============================] - 3s 10ms/step - loss: 136.0266 - root_mean_squared_error: 11.6630 - val_loss: 179.8093 - val_root_mean_squared_error: 13.4093
# Epoch 6/20
# 248/248 [==============================] - 3s 10ms/step - loss: 104.8647 - root_mean_squared_error: 10.2403 - val_loss: 133.7053 - val_root_mean_squared_error: 11.5631
# Epoch 7/20
# 248/248 [==============================] - 3s 10ms/step - loss: 85.6694 - root_mean_squared_error: 9.2558 - val_loss: 136.9130 - val_root_mean_squared_error: 11.7010
# Epoch 8/20
# 248/248 [==============================] - 3s 10ms/step - loss: 72.9432 - root_mean_squared_error: 8.5407 - val_loss: 143.0853 - val_root_mean_squared_error: 11.9618
# Epoch 9/20
# 248/248 [==============================] - 3s 10ms/step - loss: 63.4886 - root_mean_squared_error: 7.9680 - val_loss: 132.2989 - val_root_mean_squared_error: 11.5021
# Epoch 10/20
# 248/248 [==============================] - 3s 10ms/step - loss: 57.4158 - root_mean_squared_error: 7.5773 - val_loss: 149.7325 - val_root_mean_squared_error: 12.2365
# Epoch 11/20
# 248/248 [==============================] - 3s 10ms/step - loss: 50.5969 - root_mean_squared_error: 7.1132 - val_loss: 140.9049 - val_root_mean_squared_error: 11.8703
# Epoch 12/20
# 248/248 [==============================] - 3s 10ms/step - loss: 48.3130 - root_mean_squared_error: 6.9508 - val_loss: 148.5422 - val_root_mean_squared_error: 12.1878
# Epoch 13/20
# 248/248 [==============================] - 3s 10ms/step - loss: 44.4024 - root_mean_squared_error: 6.6635 - val_loss: 138.9318 - val_root_mean_squared_error: 11.7869
# Epoch 14/20
# 248/248 [==============================] - 3s 10ms/step - loss: 40.4544 - root_mean_squared_error: 6.3604 - val_loss: 168.2329 - val_root_mean_squared_error: 12.9705
# Epoch 15/20
# 248/248 [==============================] - 3s 10ms/step - loss: 37.9052 - root_mean_squared_error: 6.1567 - val_loss: 152.5473 - val_root_mean_squared_error: 12.3510
# Epoch 16/20
# 248/248 [==============================] - 3s 10ms/step - loss: 35.6654 - root_mean_squared_error: 5.9721 - val_loss: 165.2857 - val_root_mean_squared_error: 12.8563
# Epoch 17/20
# 248/248 [==============================] - 3s 11ms/step - loss: 34.8110 - root_mean_squared_error: 5.9001 - val_loss: 162.2493 - val_root_mean_squared_error: 12.7377
# Epoch 18/20
# 248/248 [==============================] - 3s 10ms/step - loss: 31.6747 - root_mean_squared_error: 5.6280 - val_loss: 160.0876 - val_root_mean_squared_error: 12.6526
# Epoch 19/20
# 248/248 [==============================] - 3s 10ms/step - loss: 30.5062 - root_mean_squared_error: 5.5232 - val_loss: 160.9289 - val_root_mean_squared_error: 12.6858
# Epoch 20/20
# 248/248 [==============================] - 3s 10ms/step - loss: 28.5738 - root_mean_squared_error: 5.3454 - val_loss: 164.8762 - val_root_mean_squared_error: 12.8404
# 62/62 [==============================] - 0s 5ms/step - loss: 164.8762 - root_mean_squared_error: 12.8404
# Validation Accuracy: 12.840412139892578
# 248/248 [==============================] - 1s 5ms/step - loss: 22.6529 - root_mean_squared_error: 4.7595
# 62/62 [==============================] - 0s 5ms/step - loss: 164.8762 - root_mean_squared_error: 12.8404
# Epoch 1/20
# 248/248 [==============================] - 4s 11ms/step - loss: 296.4285 - root_mean_squared_error: 17.2171 - val_loss: 133.8738 - val_root_mean_squared_error: 11.5704
# Epoch 2/20
# 248/248 [==============================] - 3s 10ms/step - loss: 125.1935 - root_mean_squared_error: 11.1890 - val_loss: 77.5750 - val_root_mean_squared_error: 8.8077
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 85.5955 - root_mean_squared_error: 9.2518 - val_loss: 84.2963 - val_root_mean_squared_error: 9.1813
# Epoch 4/20
# 248/248 [==============================] - 3s 11ms/step - loss: 62.4785 - root_mean_squared_error: 7.9043 - val_loss: 60.4410 - val_root_mean_squared_error: 7.7744
# Epoch 5/20
# 248/248 [==============================] - 3s 11ms/step - loss: 47.5173 - root_mean_squared_error: 6.8933 - val_loss: 51.5751 - val_root_mean_squared_error: 7.1816
# Epoch 6/20
# 248/248 [==============================] - 3s 11ms/step - loss: 41.1492 - root_mean_squared_error: 6.4148 - val_loss: 53.5096 - val_root_mean_squared_error: 7.3150
# Epoch 7/20
# 248/248 [==============================] - 3s 11ms/step - loss: 36.6461 - root_mean_squared_error: 6.0536 - val_loss: 53.1243 - val_root_mean_squared_error: 7.2886
# Epoch 8/20
# 248/248 [==============================] - 3s 11ms/step - loss: 33.9918 - root_mean_squared_error: 5.8302 - val_loss: 77.9781 - val_root_mean_squared_error: 8.8305
# Epoch 9/20
# 248/248 [==============================] - 3s 11ms/step - loss: 31.8521 - root_mean_squared_error: 5.6438 - val_loss: 55.0123 - val_root_mean_squared_error: 7.4170
# Epoch 10/20
# 248/248 [==============================] - 3s 11ms/step - loss: 29.1760 - root_mean_squared_error: 5.4015 - val_loss: 58.8088 - val_root_mean_squared_error: 7.6687
# Epoch 11/20
# 248/248 [==============================] - 3s 10ms/step - loss: 27.5273 - root_mean_squared_error: 5.2466 - val_loss: 56.1881 - val_root_mean_squared_error: 7.4959
# Epoch 12/20
# 248/248 [==============================] - 3s 11ms/step - loss: 27.0501 - root_mean_squared_error: 5.2010 - val_loss: 86.4644 - val_root_mean_squared_error: 9.2986
# Epoch 13/20
# 248/248 [==============================] - 3s 11ms/step - loss: 24.9079 - root_mean_squared_error: 4.9908 - val_loss: 76.3913 - val_root_mean_squared_error: 8.7402
# Epoch 14/20
# 248/248 [==============================] - 3s 11ms/step - loss: 24.3736 - root_mean_squared_error: 4.9370 - val_loss: 66.4659 - val_root_mean_squared_error: 8.1527
# Epoch 15/20
# 248/248 [==============================] - 3s 11ms/step - loss: 24.0670 - root_mean_squared_error: 4.9058 - val_loss: 73.6883 - val_root_mean_squared_error: 8.5842
# Epoch 16/20
# 248/248 [==============================] - 3s 11ms/step - loss: 21.9238 - root_mean_squared_error: 4.6823 - val_loss: 81.9707 - val_root_mean_squared_error: 9.0538
# Epoch 17/20
# 248/248 [==============================] - 3s 11ms/step - loss: 21.8976 - root_mean_squared_error: 4.6795 - val_loss: 71.7240 - val_root_mean_squared_error: 8.4690
# Epoch 18/20
# 248/248 [==============================] - 3s 11ms/step - loss: 20.6091 - root_mean_squared_error: 4.5397 - val_loss: 74.9551 - val_root_mean_squared_error: 8.6577
# Epoch 19/20
# 248/248 [==============================] - 3s 11ms/step - loss: 20.3934 - root_mean_squared_error: 4.5159 - val_loss: 92.3191 - val_root_mean_squared_error: 9.6083
# Epoch 20/20
# 248/248 [==============================] - 3s 11ms/step - loss: 19.6973 - root_mean_squared_error: 4.4382 - val_loss: 79.1073 - val_root_mean_squared_error: 8.8942
# 62/62 [==============================] - 0s 5ms/step - loss: 79.1073 - root_mean_squared_error: 8.8942
# Validation Accuracy: 8.8942289352417
# 248/248 [==============================] - 1s 5ms/step - loss: 12.0648 - root_mean_squared_error: 3.4734
# 62/62 [==============================] - 0s 5ms/step - loss: 79.1073 - root_mean_squared_error: 8.8942
# Epoch 1/20
# 248/248 [==============================] - 4s 11ms/step - loss: 376.4287 - root_mean_squared_error: 19.4018 - val_loss: 138.5432 - val_root_mean_squared_error: 11.7704
# Epoch 2/20
# 248/248 [==============================] - 3s 11ms/step - loss: 115.4066 - root_mean_squared_error: 10.7427 - val_loss: 66.6552 - val_root_mean_squared_error: 8.1643
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 67.3377 - root_mean_squared_error: 8.2060 - val_loss: 81.9257 - val_root_mean_squared_error: 9.0513
# Epoch 4/20
# 248/248 [==============================] - 3s 11ms/step - loss: 51.4062 - root_mean_squared_error: 7.1698 - val_loss: 50.3420 - val_root_mean_squared_error: 7.0952
# Epoch 5/20
# 248/248 [==============================] - 3s 11ms/step - loss: 40.9953 - root_mean_squared_error: 6.4028 - val_loss: 48.8122 - val_root_mean_squared_error: 6.9866
# Epoch 6/20
# 248/248 [==============================] - 3s 11ms/step - loss: 35.6691 - root_mean_squared_error: 5.9724 - val_loss: 40.5321 - val_root_mean_squared_error: 6.3665
# Epoch 7/20
# 248/248 [==============================] - 3s 11ms/step - loss: 30.3800 - root_mean_squared_error: 5.5118 - val_loss: 50.7726 - val_root_mean_squared_error: 7.1255
# Epoch 8/20
# 248/248 [==============================] - 3s 11ms/step - loss: 27.1546 - root_mean_squared_error: 5.2110 - val_loss: 74.0279 - val_root_mean_squared_error: 8.6039
# Epoch 9/20
# 248/248 [==============================] - 3s 11ms/step - loss: 25.0173 - root_mean_squared_error: 5.0017 - val_loss: 47.3929 - val_root_mean_squared_error: 6.8842
# Epoch 10/20
# 248/248 [==============================] - 3s 11ms/step - loss: 23.7715 - root_mean_squared_error: 4.8756 - val_loss: 39.7458 - val_root_mean_squared_error: 6.3044
# Epoch 11/20
# 248/248 [==============================] - 3s 11ms/step - loss: 21.7976 - root_mean_squared_error: 4.6688 - val_loss: 42.8164 - val_root_mean_squared_error: 6.5434
# Epoch 12/20
# 248/248 [==============================] - 3s 11ms/step - loss: 19.6404 - root_mean_squared_error: 4.4318 - val_loss: 46.8301 - val_root_mean_squared_error: 6.8433
# Epoch 13/20
# 248/248 [==============================] - 3s 11ms/step - loss: 19.9704 - root_mean_squared_error: 4.4688 - val_loss: 48.8357 - val_root_mean_squared_error: 6.9883
# Epoch 14/20
# 248/248 [==============================] - 3s 11ms/step - loss: 19.5940 - root_mean_squared_error: 4.4265 - val_loss: 46.0137 - val_root_mean_squared_error: 6.7833
# Epoch 15/20
# 248/248 [==============================] - 3s 11ms/step - loss: 17.7679 - root_mean_squared_error: 4.2152 - val_loss: 54.2896 - val_root_mean_squared_error: 7.3681
# Epoch 16/20
# 248/248 [==============================] - 3s 11ms/step - loss: 17.3487 - root_mean_squared_error: 4.1652 - val_loss: 52.3042 - val_root_mean_squared_error: 7.2322
# Epoch 17/20
# 248/248 [==============================] - 3s 11ms/step - loss: 17.2971 - root_mean_squared_error: 4.1590 - val_loss: 60.9853 - val_root_mean_squared_error: 7.8093
# Epoch 18/20
# 248/248 [==============================] - 3s 11ms/step - loss: 16.6170 - root_mean_squared_error: 4.0764 - val_loss: 63.0008 - val_root_mean_squared_error: 7.9373
# Epoch 19/20
# 248/248 [==============================] - 3s 11ms/step - loss: 16.5499 - root_mean_squared_error: 4.0682 - val_loss: 54.8302 - val_root_mean_squared_error: 7.4047
# Epoch 20/20
# 248/248 [==============================] - 3s 11ms/step - loss: 15.5798 - root_mean_squared_error: 3.9471 - val_loss: 60.1448 - val_root_mean_squared_error: 7.7553
# 62/62 [==============================] - 0s 5ms/step - loss: 60.1448 - root_mean_squared_error: 7.7553
# Validation Accuracy: 7.755308151245117
# 248/248 [==============================] - 1s 5ms/step - loss: 14.8413 - root_mean_squared_error: 3.8524
# 62/62 [==============================] - 0s 5ms/step - loss: 60.1448 - root_mean_squared_error: 7.7553
# Epoch 1/20
# 248/248 [==============================] - 4s 11ms/step - loss: 118.5411 - root_mean_squared_error: 10.8877 - val_loss: 40.4354 - val_root_mean_squared_error: 6.3589
# Epoch 2/20
# 248/248 [==============================] - 3s 11ms/step - loss: 39.7481 - root_mean_squared_error: 6.3046 - val_loss: 37.5553 - val_root_mean_squared_error: 6.1282
# Epoch 3/20
# 248/248 [==============================] - 3s 11ms/step - loss: 29.2281 - root_mean_squared_error: 5.4063 - val_loss: 40.6539 - val_root_mean_squared_error: 6.3760
# Epoch 4/20
# 248/248 [==============================] - 3s 11ms/step - loss: 25.6060 - root_mean_squared_error: 5.0602 - val_loss: 26.6556 - val_root_mean_squared_error: 5.1629
# Epoch 5/20
# 248/248 [==============================] - 3s 11ms/step - loss: 22.6939 - root_mean_squared_error: 4.7638 - val_loss: 18.8222 - val_root_mean_squared_error: 4.3385
# Epoch 6/20
# 248/248 [==============================] - 3s 11ms/step - loss: 20.4199 - root_mean_squared_error: 4.5188 - val_loss: 35.6441 - val_root_mean_squared_error: 5.9703
# Epoch 7/20
# 248/248 [==============================] - 3s 11ms/step - loss: 20.2516 - root_mean_squared_error: 4.5002 - val_loss: 32.4567 - val_root_mean_squared_error: 5.6971
# Epoch 8/20
# 248/248 [==============================] - 3s 11ms/step - loss: 18.6589 - root_mean_squared_error: 4.3196 - val_loss: 26.5121 - val_root_mean_squared_error: 5.1490
# Epoch 9/20
# 248/248 [==============================] - 3s 11ms/step - loss: 17.3856 - root_mean_squared_error: 4.1696 - val_loss: 24.6687 - val_root_mean_squared_error: 4.9668
# Epoch 10/20
# 248/248 [==============================] - 3s 11ms/step - loss: 16.9376 - root_mean_squared_error: 4.1155 - val_loss: 41.1536 - val_root_mean_squared_error: 6.4151
# Epoch 11/20
# 248/248 [==============================] - 3s 11ms/step - loss: 16.8822 - root_mean_squared_error: 4.1088 - val_loss: 24.8252 - val_root_mean_squared_error: 4.9825
# Epoch 12/20
# 248/248 [==============================] - 3s 11ms/step - loss: 16.2145 - root_mean_squared_error: 4.0267 - val_loss: 41.5157 - val_root_mean_squared_error: 6.4433
# Epoch 13/20
# 248/248 [==============================] - 3s 11ms/step - loss: 15.5535 - root_mean_squared_error: 3.9438 - val_loss: 26.5872 - val_root_mean_squared_error: 5.1563
# Epoch 14/20
# 248/248 [==============================] - 3s 11ms/step - loss: 15.3655 - root_mean_squared_error: 3.9199 - val_loss: 57.9398 - val_root_mean_squared_error: 7.6118
# Epoch 15/20
# 248/248 [==============================] - 3s 11ms/step - loss: 15.1988 - root_mean_squared_error: 3.8986 - val_loss: 28.7670 - val_root_mean_squared_error: 5.3635
# Epoch 16/20
# 248/248 [==============================] - 3s 11ms/step - loss: 14.9207 - root_mean_squared_error: 3.8627 - val_loss: 36.2691 - val_root_mean_squared_error: 6.0224
# Epoch 17/20
# 248/248 [==============================] - 3s 11ms/step - loss: 14.1294 - root_mean_squared_error: 3.7589 - val_loss: 31.2056 - val_root_mean_squared_error: 5.5862
# Epoch 18/20
# 248/248 [==============================] - 3s 11ms/step - loss: 13.9206 - root_mean_squared_error: 3.7310 - val_loss: 48.6428 - val_root_mean_squared_error: 6.9744
# Epoch 19/20
# 248/248 [==============================] - 3s 11ms/step - loss: 13.6354 - root_mean_squared_error: 3.6926 - val_loss: 36.3818 - val_root_mean_squared_error: 6.0317
# Epoch 20/20
# 248/248 [==============================] - 3s 11ms/step - loss: 13.2874 - root_mean_squared_error: 3.6452 - val_loss: 31.9817 - val_root_mean_squared_error: 5.6552
# 62/62 [==============================] - 0s 5ms/step - loss: 31.9816 - root_mean_squared_error: 5.6552
# Validation Accuracy: 5.655231952667236
# 248/248 [==============================] - 1s 5ms/step - loss: 9.9342 - root_mean_squared_error: 3.1519
# 62/62 [==============================] - 0s 5ms/step - loss: 31.9817 - root_mean_squared_error: 5.6552
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-109f15edfadb> in <module>()
#      36     # return avg_train_loss, avg_val_loss
#      37
# ---> 38 avg_train_loss, avg_val_loss = k_fold(5, train_data_sorted, train_imgs,image_NN, tabular_NN)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# Create overview of layers in model
tf.keras.utils.plot_model(concat_model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')
