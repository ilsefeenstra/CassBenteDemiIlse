# %% [markdown]
# # Activation functions
# In this chapter we will use different activation functions to try to minimize the cost.

# %%
import zipfile
import os
import cv2
import pandas as pd
from os import chdir, listdir

import matplotlib.pyplot as plt
import numpy as np
import random

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing, regularizers
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from keras import backend as K
from keras import activations

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-27 12:36:40--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-27 12:36:40--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 52.68.31.213
# Connecting to codeload.github.com (codeload.github.com)|52.68.31.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [       <=>          ]   1001M  13.7MB/s    in 72s
#
# 2022-01-27 12:37:53 (13.8 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1049332223]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# Create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis. After the images are imported, the images and their names are shuffled. This is done, so we can later take a validation sample containing a random subsample of the dataset. It could be that the images in the dataset contain some order, so by shuffling we ensure that the subset for the validation data is random.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])

        # Reset the index of the dataframe
        data_sorted = data_sorted.reset_index().drop(['index'],axis=1)
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

# %% [markdown]
# # Processing data
# The tabular data is split in x and y values and converted to numpy arrays, so the neural network can handle the data. Moreover, the image data is converted to numpy arrays.

# %%
# Remove samples with pawpularity score of 100
indexNames = train_data_sorted[train_data_sorted['Pawpularity'] == 100].index
train_data_new = train_data_sorted.drop(indexNames)
train_imgs_new = np.delete(train_imgs, indexNames, axis=0)

# %%
# Select x-values (the 12 input features) and y-values from training data
x_tabular = train_data_new.iloc[:,1:13].to_numpy()
y = train_data_new.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# Create numpy array of image data 
x_images = np.array(train_imgs_new)
test_imgs_array = np.array(test_imgs)

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create hidden layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation='sigmoid', input_shape=(input_size,)))    

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="sigmoid"))

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="sigmoid"))

    return model

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), input_shape=image_size, padding='same'))
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), input_shape=image_size, padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), padding='same'))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), padding='same'))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation=tf.keras.layers.LeakyReLU(), padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation=tf.keras.layers.LeakyReLU(), 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation=tf.keras.layers.LeakyReLU(), 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))
    
    return model

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
def linear_limit(x):
    """
    Create a linear activation function that clips the output at 0 and 100.
    """
    activation_x = activations.linear(x)
    activation_x_new = K.clip(activation_x, 0, 100)

    return activation_x_new

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layer with relu activation
    hidden_layer_1 = layers.Dense(hidden_nodes, activation=tf.keras.layers.LeakyReLU(), 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(concat_input)

    # Create hidden layer with relu activation
    drop_out_1 = layers.Dropout(0.4)(hidden_layer_1)    
    hidden_layer_2 = layers.Dense(hidden_nodes, activation=tf.keras.layers.LeakyReLU(), 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_1)

    # Create hidden layer with relu activation
    drop_out_2 = layers.Dropout(0.4)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(hidden_nodes, activation=tf.keras.layers.LeakyReLU(), 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_2)

    # Create output layer
    output_layer = layers.Dense(1, activation=linear_limit)(hidden_layer_3)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
    """
    This function trains and evaluated a model. It first compiles the model with 
    the loss and metrics. It then makes a train and validation generator for the 
    image data, based on the preprocess and augment input. 
    It then trains the model on both the image and tabular data for epochs times. 
    The values of the loss and metric are plotted and printed.
    """
    # Compile model and use mean squared error as loss and root mean squared error as metric
    model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

    # Preprocess the image data
    train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
    train_gen.fit(image_x)

    val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
    val_gen.fit(image_x)

    # Train the model by fitting both tabular and image data at the same time
    history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs = epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

    return history

# %%
from sklearn.model_selection import KFold

def k_fold(num_folds, x_tabular, y, x_imgs, epochs=20, preprocess={}, augment={}):
    """
    Train and evaluate the data for num-folds times, and return the average 
    training and validation loss. First the data is split in num-folds batches
    and then the model is trained on the data, where a different batch is the 
    validation data each time.
    """
    # Create kfold object to later split the data
    kfold = KFold(n_splits=num_folds, shuffle=True)
    x_indices = np.array(range(len(x_tabular)))
    y_indices = np.array(range(len(y)))

    # Pre allocate variables to store the MSE (loss) and RMSE (accuracy)
    train_loss = np.array(np.zeros(epochs))
    train_acc = np.array(np.zeros(epochs))
    val_loss = np.array(np.zeros(epochs))
    val_acc = np.array(np.zeros(epochs))
    
    # Train and evaluate the model for num-fold times on a different training 
    # and validation set each time
    for id_train, id_val in kfold.split(x_indices, y_indices):
        
        # Make Neural Networks before concatenation
        tabular_NN = build_neural_net(12, hidden_nodes=20)
        image_size = (64, 64, 3)
        image_NN = build_convol_net(image_size, hidden_nodes=20)

        # Create subset training and validation data
        x_tabular_train = x_tabular[id_train]
        x_imgs_train = x_imgs[id_train]
        y_train = y[id_train]
        
        x_tabular_val = x_tabular[id_val]
        x_imgs_val = x_imgs[id_val]
        y_val_2 = y[id_val]
        
        # Train and evaluate the model
        concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)
        history = train_and_evaluate(concat_model, x_imgs_train, x_tabular_train, 
                           y_train, x_tabular_val, x_imgs_val, y_val_2, epochs=epochs, preprocess=preprocess, augment=augment)

        # Add all the losses and metrics
        train_loss += history.history['loss']
        train_acc += history.history['root_mean_squared_error']
        val_loss += history.history['val_loss']
        val_acc += history.history['val_root_mean_squared_error']

    # Calculate average loss and metric
    avg_train_loss = train_loss / num_folds
    avg_val_loss = val_loss / num_folds
    avg_train_acc = train_acc / num_folds
    avg_val_acc = val_acc / num_folds

    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    # Plot MSE
    axs[0].plot(avg_train_loss)
    axs[0].plot(avg_val_loss)
    axs[0].legend(['training', 'validation'], loc='best')
    
    axs[0].set_title('Model MSE')
    axs[0].set_ylabel('MSE')
    axs[0].set_xlabel('epoch')
    axs[0].set_ylim([0, 1000])

    # Plot RMSE
    axs[1].plot(avg_train_acc)
    axs[1].plot(avg_val_acc)
    axs[1].legend(['training', 'validation'], loc='best')
    
    axs[1].set_title('Model RMSE')
    axs[1].set_ylabel('RMSE')
    axs[1].set_xlabel('epoch')
    axs[1].set_ylim([0, 30])

    plt.show()

    return avg_train_loss[-1], avg_val_loss[-1], avg_train_acc[-1], avg_val_acc[-1]

# Use k-fold cross-validation to train and evaluate concatenated network
avg_train_loss, avg_val_loss, avg_train_acc, avg_val_acc = k_fold(5, x_tabular, y, x_images, epochs=60, 
                                               preprocess={'featurewise_center': True, 'featurewise_std_normalization': True},
                                               augment={'rotation_range': 90, 'horizontal_flip': True, 'shear_range': 0.2})

print(f'The train MSE is {avg_train_loss}')
print(f'The train RMSE is {avg_train_acc}')
print(f'The validation MSE is {avg_val_loss}')
print(f'The validation RMSE is {avg_val_acc}')
# Out:
# Epoch 1/60
# 241/241 [==============================] - 23s 81ms/step - loss: 802.8698 - root_mean_squared_error: 25.3379 - val_loss: 931.0407 - val_root_mean_squared_error: 26.2936
# Epoch 2/60
# 241/241 [==============================] - 19s 79ms/step - loss: 532.2781 - root_mean_squared_error: 21.2163 - val_loss: 443.3409 - val_root_mean_squared_error: 19.5557
# Epoch 3/60
# 241/241 [==============================] - 19s 80ms/step - loss: 472.6941 - root_mean_squared_error: 20.3197 - val_loss: 397.1929 - val_root_mean_squared_error: 18.5494
# Epoch 4/60
# 241/241 [==============================] - 19s 79ms/step - loss: 444.4372 - root_mean_squared_error: 19.9099 - val_loss: 385.9866 - val_root_mean_squared_error: 18.6684
# Epoch 5/60
# 241/241 [==============================] - 20s 83ms/step - loss: 420.0742 - root_mean_squared_error: 19.4916 - val_loss: 376.0365 - val_root_mean_squared_error: 18.5183
# Epoch 6/60
# 241/241 [==============================] - 21s 86ms/step - loss: 410.3707 - root_mean_squared_error: 19.3969 - val_loss: 387.3710 - val_root_mean_squared_error: 18.9628
# Epoch 7/60
# 241/241 [==============================] - 19s 79ms/step - loss: 393.0694 - root_mean_squared_error: 19.0733 - val_loss: 361.7508 - val_root_mean_squared_error: 18.3100
# Epoch 8/60
# 241/241 [==============================] - 19s 79ms/step - loss: 383.0799 - root_mean_squared_error: 18.8890 - val_loss: 359.3028 - val_root_mean_squared_error: 18.2811
# Epoch 9/60
# 241/241 [==============================] - 19s 79ms/step - loss: 368.2126 - root_mean_squared_error: 18.5524 - val_loss: 362.7802 - val_root_mean_squared_error: 18.4678
# Epoch 10/60
# 241/241 [==============================] - 19s 79ms/step - loss: 360.0725 - root_mean_squared_error: 18.3860 - val_loss: 363.0980 - val_root_mean_squared_error: 18.5164
# Epoch 11/60
# 241/241 [==============================] - 19s 79ms/step - loss: 355.2351 - root_mean_squared_error: 18.3021 - val_loss: 352.4923 - val_root_mean_squared_error: 18.2429
# Epoch 12/60
# 241/241 [==============================] - 19s 79ms/step - loss: 352.0516 - root_mean_squared_error: 18.2422 - val_loss: 356.1499 - val_root_mean_squared_error: 18.3898
# Epoch 13/60
# 241/241 [==============================] - 19s 79ms/step - loss: 347.2921 - root_mean_squared_error: 18.1361 - val_loss: 353.1602 - val_root_mean_squared_error: 18.3196
# Epoch 14/60
# 241/241 [==============================] - 19s 79ms/step - loss: 343.0655 - root_mean_squared_error: 18.0435 - val_loss: 350.6985 - val_root_mean_squared_error: 18.2619
# Epoch 15/60
# 241/241 [==============================] - 19s 79ms/step - loss: 340.6797 - root_mean_squared_error: 17.9987 - val_loss: 350.4716 - val_root_mean_squared_error: 18.2738
# Epoch 16/60
# 241/241 [==============================] - 19s 80ms/step - loss: 336.2257 - root_mean_squared_error: 17.8861 - val_loss: 349.3603 - val_root_mean_squared_error: 18.2593
# Epoch 17/60
# 241/241 [==============================] - 19s 79ms/step - loss: 337.9243 - root_mean_squared_error: 17.9508 - val_loss: 348.6534 - val_root_mean_squared_error: 18.2607
# Epoch 18/60
# 241/241 [==============================] - 19s 79ms/step - loss: 335.0361 - root_mean_squared_error: 17.8874 - val_loss: 348.7450 - val_root_mean_squared_error: 18.2764
# Epoch 19/60
# 241/241 [==============================] - 19s 80ms/step - loss: 334.8792 - root_mean_squared_error: 17.8948 - val_loss: 347.7720 - val_root_mean_squared_error: 18.2621
# Epoch 20/60
# 241/241 [==============================] - 19s 79ms/step - loss: 333.1938 - root_mean_squared_error: 17.8567 - val_loss: 347.2974 - val_root_mean_squared_error: 18.2561
# Epoch 21/60
# 241/241 [==============================] - 19s 79ms/step - loss: 331.8281 - root_mean_squared_error: 17.8286 - val_loss: 347.6455 - val_root_mean_squared_error: 18.2808
# Epoch 22/60
# 241/241 [==============================] - 19s 79ms/step - loss: 330.9621 - root_mean_squared_error: 17.8207 - val_loss: 346.9013 - val_root_mean_squared_error: 18.2724
# Epoch 23/60
# 241/241 [==============================] - 19s 79ms/step - loss: 329.2298 - root_mean_squared_error: 17.7811 - val_loss: 347.2476 - val_root_mean_squared_error: 18.2926
# Epoch 24/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.7546 - root_mean_squared_error: 17.8076 - val_loss: 345.8571 - val_root_mean_squared_error: 18.2597
# Epoch 25/60
# 241/241 [==============================] - 19s 80ms/step - loss: 328.6368 - root_mean_squared_error: 17.7828 - val_loss: 346.0169 - val_root_mean_squared_error: 18.2737
# Epoch 26/60
# 241/241 [==============================] - 19s 79ms/step - loss: 327.9705 - root_mean_squared_error: 17.7732 - val_loss: 346.8520 - val_root_mean_squared_error: 18.2957
# Epoch 27/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.3938 - root_mean_squared_error: 17.7651 - val_loss: 345.6083 - val_root_mean_squared_error: 18.2799
# Epoch 28/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.4465 - root_mean_squared_error: 17.7791 - val_loss: 344.5856 - val_root_mean_squared_error: 18.2600
# Epoch 29/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.3908 - root_mean_squared_error: 17.7868 - val_loss: 344.5119 - val_root_mean_squared_error: 18.2601
# Epoch 30/60
# 241/241 [==============================] - 19s 79ms/step - loss: 326.3634 - root_mean_squared_error: 17.7649 - val_loss: 344.0851 - val_root_mean_squared_error: 18.2591
# Epoch 31/60
# 241/241 [==============================] - 19s 80ms/step - loss: 325.4654 - root_mean_squared_error: 17.7472 - val_loss: 343.6178 - val_root_mean_squared_error: 18.2537
# Epoch 32/60
# 241/241 [==============================] - 19s 80ms/step - loss: 325.9548 - root_mean_squared_error: 17.7684 - val_loss: 345.5598 - val_root_mean_squared_error: 18.3246
# Epoch 33/60
# 241/241 [==============================] - 19s 80ms/step - loss: 325.0181 - root_mean_squared_error: 17.7527 - val_loss: 343.1325 - val_root_mean_squared_error: 18.2557
# Epoch 34/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.8059 - root_mean_squared_error: 17.7507 - val_loss: 342.7851 - val_root_mean_squared_error: 18.2549
# Epoch 35/60
# 241/241 [==============================] - 19s 79ms/step - loss: 324.7360 - root_mean_squared_error: 17.7514 - val_loss: 343.1036 - val_root_mean_squared_error: 18.2706
# Epoch 36/60
# 241/241 [==============================] - 19s 79ms/step - loss: 323.7147 - root_mean_squared_error: 17.7303 - val_loss: 343.8364 - val_root_mean_squared_error: 18.2854
# Epoch 37/60
# 241/241 [==============================] - 19s 79ms/step - loss: 324.4550 - root_mean_squared_error: 17.7526 - val_loss: 342.9697 - val_root_mean_squared_error: 18.2725
# Epoch 38/60
# 241/241 [==============================] - 19s 80ms/step - loss: 323.6122 - root_mean_squared_error: 17.7351 - val_loss: 342.8133 - val_root_mean_squared_error: 18.2744
# Epoch 39/60
# 241/241 [==============================] - 19s 81ms/step - loss: 323.6365 - root_mean_squared_error: 17.7427 - val_loss: 342.9561 - val_root_mean_squared_error: 18.2820
# Epoch 40/60
# 241/241 [==============================] - 19s 81ms/step - loss: 323.4418 - root_mean_squared_error: 17.7408 - val_loss: 342.1653 - val_root_mean_squared_error: 18.2662
# Epoch 41/60
# 241/241 [==============================] - 19s 80ms/step - loss: 323.2147 - root_mean_squared_error: 17.7411 - val_loss: 341.9981 - val_root_mean_squared_error: 18.2624
# Epoch 42/60
# 241/241 [==============================] - 19s 79ms/step - loss: 322.7936 - root_mean_squared_error: 17.7312 - val_loss: 343.1940 - val_root_mean_squared_error: 18.2982
# Epoch 43/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.1821 - root_mean_squared_error: 17.7162 - val_loss: 341.8945 - val_root_mean_squared_error: 18.2694
# Epoch 44/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.5887 - root_mean_squared_error: 17.7309 - val_loss: 341.4724 - val_root_mean_squared_error: 18.2625
# Epoch 45/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.8163 - root_mean_squared_error: 17.7432 - val_loss: 342.5492 - val_root_mean_squared_error: 18.2950
# Epoch 46/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.2979 - root_mean_squared_error: 17.7322 - val_loss: 341.8867 - val_root_mean_squared_error: 18.2764
# Epoch 47/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.2470 - root_mean_squared_error: 17.7317 - val_loss: 341.8429 - val_root_mean_squared_error: 18.2808
# Epoch 48/60
# 241/241 [==============================] - 19s 80ms/step - loss: 321.9717 - root_mean_squared_error: 17.7298 - val_loss: 341.8153 - val_root_mean_squared_error: 18.2831
# Epoch 49/60
# 241/241 [==============================] - 19s 79ms/step - loss: 321.6233 - root_mean_squared_error: 17.7234 - val_loss: 341.7911 - val_root_mean_squared_error: 18.2810
# Epoch 50/60
# 241/241 [==============================] - 19s 79ms/step - loss: 321.7996 - root_mean_squared_error: 17.7279 - val_loss: 341.2641 - val_root_mean_squared_error: 18.2684
# Epoch 51/60
# 241/241 [==============================] - 19s 79ms/step - loss: 321.2386 - root_mean_squared_error: 17.7127 - val_loss: 341.9832 - val_root_mean_squared_error: 18.2909
# Epoch 52/60
# 241/241 [==============================] - 19s 79ms/step - loss: 321.5049 - root_mean_squared_error: 17.7230 - val_loss: 341.3622 - val_root_mean_squared_error: 18.2759
# Epoch 53/60
# 241/241 [==============================] - 19s 80ms/step - loss: 321.3635 - root_mean_squared_error: 17.7224 - val_loss: 342.3515 - val_root_mean_squared_error: 18.3034
# Epoch 54/60
# 241/241 [==============================] - 19s 80ms/step - loss: 320.9246 - root_mean_squared_error: 17.7092 - val_loss: 342.6480 - val_root_mean_squared_error: 18.3124
# Epoch 55/60
# 241/241 [==============================] - 19s 79ms/step - loss: 320.3039 - root_mean_squared_error: 17.6922 - val_loss: 342.5694 - val_root_mean_squared_error: 18.3145
# Epoch 56/60
# 241/241 [==============================] - 19s 80ms/step - loss: 320.8235 - root_mean_squared_error: 17.7115 - val_loss: 341.4365 - val_root_mean_squared_error: 18.2826
# Epoch 57/60
# 241/241 [==============================] - 20s 81ms/step - loss: 321.0067 - root_mean_squared_error: 17.7183 - val_loss: 342.1950 - val_root_mean_squared_error: 18.3091
# Epoch 58/60
# 241/241 [==============================] - 20s 81ms/step - loss: 320.8978 - root_mean_squared_error: 17.7172 - val_loss: 340.4674 - val_root_mean_squared_error: 18.2629
# Epoch 59/60
# 241/241 [==============================] - 19s 80ms/step - loss: 319.8945 - root_mean_squared_error: 17.6892 - val_loss: 341.3985 - val_root_mean_squared_error: 18.2863
# Epoch 60/60
# 241/241 [==============================] - 19s 80ms/step - loss: 320.0638 - root_mean_squared_error: 17.6942 - val_loss: 341.4891 - val_root_mean_squared_error: 18.2927
# Epoch 1/60
# 241/241 [==============================] - 23s 82ms/step - loss: 794.6779 - root_mean_squared_error: 25.2408 - val_loss: 689.2131 - val_root_mean_squared_error: 21.8692
# Epoch 2/60
# 241/241 [==============================] - 19s 80ms/step - loss: 545.4296 - root_mean_squared_error: 21.4517 - val_loss: 432.3431 - val_root_mean_squared_error: 18.8841
# Epoch 3/60
# 241/241 [==============================] - 19s 80ms/step - loss: 474.6887 - root_mean_squared_error: 20.3198 - val_loss: 402.0614 - val_root_mean_squared_error: 18.8115
# Epoch 4/60
# 241/241 [==============================] - 19s 80ms/step - loss: 443.4370 - root_mean_squared_error: 19.8708 - val_loss: 376.9926 - val_root_mean_squared_error: 18.4018
# Epoch 5/60
# 241/241 [==============================] - 19s 80ms/step - loss: 418.5041 - root_mean_squared_error: 19.4700 - val_loss: 378.7372 - val_root_mean_squared_error: 18.6573
# Epoch 6/60
# 241/241 [==============================] - 19s 80ms/step - loss: 400.0815 - root_mean_squared_error: 19.1604 - val_loss: 360.7328 - val_root_mean_squared_error: 18.2561
# Epoch 7/60
# 241/241 [==============================] - 19s 79ms/step - loss: 387.5782 - root_mean_squared_error: 18.9612 - val_loss: 352.5412 - val_root_mean_squared_error: 18.1271
# Epoch 8/60
# 241/241 [==============================] - 19s 80ms/step - loss: 373.9608 - root_mean_squared_error: 18.6921 - val_loss: 348.6930 - val_root_mean_squared_error: 18.0843
# Epoch 9/60
# 241/241 [==============================] - 19s 79ms/step - loss: 367.2155 - root_mean_squared_error: 18.5815 - val_loss: 344.3449 - val_root_mean_squared_error: 18.0314
# Epoch 10/60
# 241/241 [==============================] - 19s 79ms/step - loss: 357.3048 - root_mean_squared_error: 18.3681 - val_loss: 342.1695 - val_root_mean_squared_error: 17.9995
# Epoch 11/60
# 241/241 [==============================] - 19s 80ms/step - loss: 352.7714 - root_mean_squared_error: 18.2857 - val_loss: 343.7194 - val_root_mean_squared_error: 18.0557
# Epoch 12/60
# 241/241 [==============================] - 19s 80ms/step - loss: 345.8420 - root_mean_squared_error: 18.1198 - val_loss: 340.9975 - val_root_mean_squared_error: 17.9716
# Epoch 13/60
# 241/241 [==============================] - 19s 80ms/step - loss: 342.3941 - root_mean_squared_error: 18.0419 - val_loss: 339.7358 - val_root_mean_squared_error: 17.9985
# Epoch 14/60
# 241/241 [==============================] - 19s 80ms/step - loss: 342.8431 - root_mean_squared_error: 18.0758 - val_loss: 339.3792 - val_root_mean_squared_error: 18.0001
# Epoch 15/60
# 241/241 [==============================] - 19s 80ms/step - loss: 340.5417 - root_mean_squared_error: 18.0251 - val_loss: 338.5463 - val_root_mean_squared_error: 17.9995
# Epoch 16/60
# 241/241 [==============================] - 19s 80ms/step - loss: 339.1035 - root_mean_squared_error: 17.9990 - val_loss: 338.1909 - val_root_mean_squared_error: 17.9936
# Epoch 17/60
# 241/241 [==============================] - 19s 80ms/step - loss: 336.7532 - root_mean_squared_error: 17.9394 - val_loss: 340.7900 - val_root_mean_squared_error: 18.0719
# Epoch 18/60
# 241/241 [==============================] - 19s 79ms/step - loss: 336.7939 - root_mean_squared_error: 17.9572 - val_loss: 337.1618 - val_root_mean_squared_error: 17.9770
# Epoch 19/60
# 241/241 [==============================] - 19s 79ms/step - loss: 334.7513 - root_mean_squared_error: 17.9183 - val_loss: 336.7791 - val_root_mean_squared_error: 17.9838
# Epoch 20/60
# 241/241 [==============================] - 19s 80ms/step - loss: 332.6508 - root_mean_squared_error: 17.8695 - val_loss: 336.5374 - val_root_mean_squared_error: 17.9785
# Epoch 21/60
# 241/241 [==============================] - 19s 80ms/step - loss: 333.4822 - root_mean_squared_error: 17.9006 - val_loss: 336.1684 - val_root_mean_squared_error: 17.9787
# Epoch 22/60
# 241/241 [==============================] - 19s 79ms/step - loss: 332.2474 - root_mean_squared_error: 17.8808 - val_loss: 335.5635 - val_root_mean_squared_error: 17.9736
# Epoch 23/60
# 241/241 [==============================] - 19s 79ms/step - loss: 332.1722 - root_mean_squared_error: 17.8889 - val_loss: 335.1200 - val_root_mean_squared_error: 17.9842
# Epoch 24/60
# 241/241 [==============================] - 19s 79ms/step - loss: 329.9435 - root_mean_squared_error: 17.8328 - val_loss: 334.6232 - val_root_mean_squared_error: 17.9639
# Epoch 25/60
# 241/241 [==============================] - 19s 79ms/step - loss: 331.2863 - root_mean_squared_error: 17.8791 - val_loss: 334.9306 - val_root_mean_squared_error: 17.9907
# Epoch 26/60
# 241/241 [==============================] - 19s 79ms/step - loss: 329.2995 - root_mean_squared_error: 17.8346 - val_loss: 333.7648 - val_root_mean_squared_error: 17.9636
# Epoch 27/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.3170 - root_mean_squared_error: 17.8432 - val_loss: 333.9040 - val_root_mean_squared_error: 17.9741
# Epoch 28/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.3708 - root_mean_squared_error: 17.8530 - val_loss: 332.9735 - val_root_mean_squared_error: 17.9582
# Epoch 29/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.9724 - root_mean_squared_error: 17.8478 - val_loss: 332.9750 - val_root_mean_squared_error: 17.9579
# Epoch 30/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.1127 - root_mean_squared_error: 17.8380 - val_loss: 332.2805 - val_root_mean_squared_error: 17.9605
# Epoch 31/60
# 241/241 [==============================] - 19s 79ms/step - loss: 327.1054 - root_mean_squared_error: 17.8178 - val_loss: 332.2930 - val_root_mean_squared_error: 17.9668
# Epoch 32/60
# 241/241 [==============================] - 19s 79ms/step - loss: 326.7962 - root_mean_squared_error: 17.8178 - val_loss: 332.1107 - val_root_mean_squared_error: 17.9652
# Epoch 33/60
# 241/241 [==============================] - 19s 80ms/step - loss: 326.8965 - root_mean_squared_error: 17.8252 - val_loss: 331.7112 - val_root_mean_squared_error: 17.9634
# Epoch 34/60
# 241/241 [==============================] - 19s 80ms/step - loss: 326.3304 - root_mean_squared_error: 17.8141 - val_loss: 331.7824 - val_root_mean_squared_error: 17.9671
# Epoch 35/60
# 241/241 [==============================] - 19s 79ms/step - loss: 325.7372 - root_mean_squared_error: 17.7996 - val_loss: 331.5603 - val_root_mean_squared_error: 17.9618
# Epoch 36/60
# 241/241 [==============================] - 19s 80ms/step - loss: 326.4640 - root_mean_squared_error: 17.8281 - val_loss: 331.3790 - val_root_mean_squared_error: 17.9654
# Epoch 37/60
# 241/241 [==============================] - 19s 80ms/step - loss: 325.7247 - root_mean_squared_error: 17.8122 - val_loss: 331.3505 - val_root_mean_squared_error: 17.9722
# Epoch 38/60
# 241/241 [==============================] - 19s 79ms/step - loss: 325.3108 - root_mean_squared_error: 17.8035 - val_loss: 331.4527 - val_root_mean_squared_error: 17.9753
# Epoch 39/60
# 241/241 [==============================] - 19s 79ms/step - loss: 325.4849 - root_mean_squared_error: 17.8146 - val_loss: 331.2787 - val_root_mean_squared_error: 17.9750
# Epoch 40/60
# 241/241 [==============================] - 19s 80ms/step - loss: 325.1113 - root_mean_squared_error: 17.8073 - val_loss: 330.9512 - val_root_mean_squared_error: 17.9768
# Epoch 41/60
# 241/241 [==============================] - 19s 79ms/step - loss: 324.3301 - root_mean_squared_error: 17.7882 - val_loss: 331.7211 - val_root_mean_squared_error: 17.9934
# Epoch 42/60
# 241/241 [==============================] - 19s 81ms/step - loss: 324.7029 - root_mean_squared_error: 17.7982 - val_loss: 331.0070 - val_root_mean_squared_error: 17.9790
# Epoch 43/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.6723 - root_mean_squared_error: 17.8010 - val_loss: 330.9882 - val_root_mean_squared_error: 17.9804
# Epoch 44/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.5780 - root_mean_squared_error: 17.8005 - val_loss: 330.9799 - val_root_mean_squared_error: 17.9820
# Epoch 45/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.5329 - root_mean_squared_error: 17.8044 - val_loss: 330.2072 - val_root_mean_squared_error: 17.9666
# Epoch 46/60
# 241/241 [==============================] - 19s 79ms/step - loss: 323.8102 - root_mean_squared_error: 17.7854 - val_loss: 330.9757 - val_root_mean_squared_error: 17.9895
# Epoch 47/60
# 241/241 [==============================] - 19s 79ms/step - loss: 324.1429 - root_mean_squared_error: 17.7990 - val_loss: 331.0997 - val_root_mean_squared_error: 17.9934
# Epoch 48/60
# 241/241 [==============================] - 19s 81ms/step - loss: 324.0323 - root_mean_squared_error: 17.7991 - val_loss: 330.2397 - val_root_mean_squared_error: 17.9754
# Epoch 49/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.0946 - root_mean_squared_error: 17.8028 - val_loss: 330.4277 - val_root_mean_squared_error: 17.9844
# Epoch 50/60
# 241/241 [==============================] - 19s 80ms/step - loss: 323.3770 - root_mean_squared_error: 17.7832 - val_loss: 330.1821 - val_root_mean_squared_error: 17.9794
# Epoch 51/60
# 241/241 [==============================] - 19s 80ms/step - loss: 323.3244 - root_mean_squared_error: 17.7859 - val_loss: 332.0928 - val_root_mean_squared_error: 18.0240
# Epoch 52/60
# 241/241 [==============================] - 20s 81ms/step - loss: 323.3276 - root_mean_squared_error: 17.7855 - val_loss: 329.8271 - val_root_mean_squared_error: 17.9703
# Epoch 53/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.3218 - root_mean_squared_error: 17.7588 - val_loss: 330.0787 - val_root_mean_squared_error: 17.9810
# Epoch 54/60
# 241/241 [==============================] - 19s 79ms/step - loss: 323.2065 - root_mean_squared_error: 17.7887 - val_loss: 331.2542 - val_root_mean_squared_error: 18.0091
# Epoch 55/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.3783 - root_mean_squared_error: 17.7642 - val_loss: 332.6855 - val_root_mean_squared_error: 18.0481
# Epoch 56/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.8116 - root_mean_squared_error: 17.7792 - val_loss: 329.5779 - val_root_mean_squared_error: 17.9699
# Epoch 57/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.5087 - root_mean_squared_error: 17.7719 - val_loss: 329.4321 - val_root_mean_squared_error: 17.9679
# Epoch 58/60
# 241/241 [==============================] - 19s 79ms/step - loss: 322.9291 - root_mean_squared_error: 17.7866 - val_loss: 329.9308 - val_root_mean_squared_error: 17.9804
# Epoch 59/60
# 241/241 [==============================] - 19s 80ms/step - loss: 322.9325 - root_mean_squared_error: 17.7871 - val_loss: 329.9766 - val_root_mean_squared_error: 17.9849
# Epoch 60/60
# 241/241 [==============================] - 19s 80ms/step - loss: 321.9375 - root_mean_squared_error: 17.7598 - val_loss: 330.0110 - val_root_mean_squared_error: 17.9900
# Epoch 1/60
# 241/241 [==============================] - 23s 81ms/step - loss: 816.3793 - root_mean_squared_error: 25.8952 - val_loss: 512.8392 - val_root_mean_squared_error: 19.1060
# Epoch 2/60
# 241/241 [==============================] - 19s 79ms/step - loss: 545.2311 - root_mean_squared_error: 21.5936 - val_loss: 432.7951 - val_root_mean_squared_error: 19.1134
# Epoch 3/60
# 241/241 [==============================] - 19s 80ms/step - loss: 483.8586 - root_mean_squared_error: 20.6364 - val_loss: 387.7411 - val_root_mean_squared_error: 18.1066
# Epoch 4/60
# 241/241 [==============================] - 19s 79ms/step - loss: 463.3348 - root_mean_squared_error: 20.4250 - val_loss: 369.4251 - val_root_mean_squared_error: 18.3126
# Epoch 5/60
# 241/241 [==============================] - 19s 79ms/step - loss: 433.6417 - root_mean_squared_error: 19.8629 - val_loss: 360.7798 - val_root_mean_squared_error: 17.9940
# Epoch 6/60
# 241/241 [==============================] - 19s 80ms/step - loss: 413.9326 - root_mean_squared_error: 19.5035 - val_loss: 342.1958 - val_root_mean_squared_error: 17.7174
# Epoch 7/60
# 241/241 [==============================] - 19s 80ms/step - loss: 394.6741 - root_mean_squared_error: 19.1160 - val_loss: 336.2693 - val_root_mean_squared_error: 17.5477
# Epoch 8/60
# 241/241 [==============================] - 19s 79ms/step - loss: 388.1832 - root_mean_squared_error: 19.0132 - val_loss: 337.1850 - val_root_mean_squared_error: 17.7157
# Epoch 9/60
# 241/241 [==============================] - 19s 79ms/step - loss: 381.9366 - root_mean_squared_error: 18.9175 - val_loss: 334.1824 - val_root_mean_squared_error: 17.6721
# Epoch 10/60
# 241/241 [==============================] - 19s 80ms/step - loss: 371.2631 - root_mean_squared_error: 18.6869 - val_loss: 334.3170 - val_root_mean_squared_error: 17.7244
# Epoch 11/60
# 241/241 [==============================] - 19s 80ms/step - loss: 366.6607 - root_mean_squared_error: 18.6119 - val_loss: 330.7256 - val_root_mean_squared_error: 17.6472
# Epoch 12/60
# 241/241 [==============================] - 19s 80ms/step - loss: 358.0011 - root_mean_squared_error: 18.4061 - val_loss: 326.4604 - val_root_mean_squared_error: 17.5552
# Epoch 13/60
# 241/241 [==============================] - 19s 80ms/step - loss: 353.7141 - root_mean_squared_error: 18.3096 - val_loss: 328.0997 - val_root_mean_squared_error: 17.6265
# Epoch 14/60
# 241/241 [==============================] - 19s 80ms/step - loss: 350.7997 - root_mean_squared_error: 18.2512 - val_loss: 324.8275 - val_root_mean_squared_error: 17.5397
# Epoch 15/60
# 241/241 [==============================] - 19s 80ms/step - loss: 349.1010 - root_mean_squared_error: 18.2183 - val_loss: 325.0570 - val_root_mean_squared_error: 17.5602
# Epoch 16/60
# 241/241 [==============================] - 19s 80ms/step - loss: 346.2047 - root_mean_squared_error: 18.1511 - val_loss: 324.0913 - val_root_mean_squared_error: 17.5437
# Epoch 17/60
# 241/241 [==============================] - 19s 79ms/step - loss: 343.3625 - root_mean_squared_error: 18.0871 - val_loss: 324.7035 - val_root_mean_squared_error: 17.5808
# Epoch 18/60
# 241/241 [==============================] - 19s 79ms/step - loss: 343.3821 - root_mean_squared_error: 18.1043 - val_loss: 323.1877 - val_root_mean_squared_error: 17.5438
# Epoch 19/60
# 241/241 [==============================] - 19s 78ms/step - loss: 341.7489 - root_mean_squared_error: 18.0711 - val_loss: 322.3404 - val_root_mean_squared_error: 17.5284
# Epoch 20/60
# 241/241 [==============================] - 19s 78ms/step - loss: 341.6219 - root_mean_squared_error: 18.0806 - val_loss: 322.5415 - val_root_mean_squared_error: 17.5556
# Epoch 21/60
# 241/241 [==============================] - 19s 78ms/step - loss: 340.6630 - root_mean_squared_error: 18.0609 - val_loss: 322.3781 - val_root_mean_squared_error: 17.5618
# Epoch 22/60
# 241/241 [==============================] - 19s 79ms/step - loss: 340.5696 - root_mean_squared_error: 18.0669 - val_loss: 323.0923 - val_root_mean_squared_error: 17.5809
# Epoch 23/60
# 241/241 [==============================] - 19s 78ms/step - loss: 337.3646 - root_mean_squared_error: 17.9896 - val_loss: 321.0162 - val_root_mean_squared_error: 17.5308
# Epoch 24/60
# 241/241 [==============================] - 19s 79ms/step - loss: 338.4360 - root_mean_squared_error: 18.0295 - val_loss: 321.7148 - val_root_mean_squared_error: 17.5676
# Epoch 25/60
# 241/241 [==============================] - 19s 78ms/step - loss: 336.8085 - root_mean_squared_error: 17.9956 - val_loss: 320.1824 - val_root_mean_squared_error: 17.5320
# Epoch 26/60
# 241/241 [==============================] - 19s 78ms/step - loss: 336.6257 - root_mean_squared_error: 17.9979 - val_loss: 321.1796 - val_root_mean_squared_error: 17.5543
# Epoch 27/60
# 241/241 [==============================] - 19s 78ms/step - loss: 336.3607 - root_mean_squared_error: 17.9983 - val_loss: 319.3598 - val_root_mean_squared_error: 17.5257
# Epoch 28/60
# 241/241 [==============================] - 19s 78ms/step - loss: 335.6005 - root_mean_squared_error: 17.9873 - val_loss: 319.7880 - val_root_mean_squared_error: 17.5519
# Epoch 29/60
# 241/241 [==============================] - 19s 78ms/step - loss: 334.6867 - root_mean_squared_error: 17.9713 - val_loss: 319.4384 - val_root_mean_squared_error: 17.5507
# Epoch 30/60
# 241/241 [==============================] - 19s 78ms/step - loss: 334.6116 - root_mean_squared_error: 17.9765 - val_loss: 318.4847 - val_root_mean_squared_error: 17.5256
# Epoch 31/60
# 241/241 [==============================] - 19s 79ms/step - loss: 334.2479 - root_mean_squared_error: 17.9738 - val_loss: 319.5898 - val_root_mean_squared_error: 17.5706
# Epoch 32/60
# 241/241 [==============================] - 19s 79ms/step - loss: 333.1330 - root_mean_squared_error: 17.9518 - val_loss: 318.5289 - val_root_mean_squared_error: 17.5361
# Epoch 33/60
# 241/241 [==============================] - 19s 79ms/step - loss: 332.8418 - root_mean_squared_error: 17.9479 - val_loss: 319.3545 - val_root_mean_squared_error: 17.5790
# Epoch 34/60
# 241/241 [==============================] - 19s 77ms/step - loss: 333.2166 - root_mean_squared_error: 17.9681 - val_loss: 317.6552 - val_root_mean_squared_error: 17.5341
# Epoch 35/60
# 241/241 [==============================] - 18s 76ms/step - loss: 331.7597 - root_mean_squared_error: 17.9359 - val_loss: 318.1424 - val_root_mean_squared_error: 17.5613
# Epoch 36/60
# 241/241 [==============================] - 19s 77ms/step - loss: 331.6120 - root_mean_squared_error: 17.9415 - val_loss: 317.2342 - val_root_mean_squared_error: 17.5395
# Epoch 37/60
# 241/241 [==============================] - 18s 76ms/step - loss: 331.2025 - root_mean_squared_error: 17.9356 - val_loss: 317.2173 - val_root_mean_squared_error: 17.5486
# Epoch 38/60
# 241/241 [==============================] - 18s 76ms/step - loss: 330.8277 - root_mean_squared_error: 17.9281 - val_loss: 318.0405 - val_root_mean_squared_error: 17.5784
# Epoch 39/60
# 241/241 [==============================] - 19s 78ms/step - loss: 331.2249 - root_mean_squared_error: 17.9459 - val_loss: 316.2514 - val_root_mean_squared_error: 17.5232
# Epoch 40/60
# 241/241 [==============================] - 19s 78ms/step - loss: 330.9756 - root_mean_squared_error: 17.9425 - val_loss: 315.9008 - val_root_mean_squared_error: 17.5184
# Epoch 41/60
# 241/241 [==============================] - 19s 78ms/step - loss: 330.3858 - root_mean_squared_error: 17.9294 - val_loss: 316.5556 - val_root_mean_squared_error: 17.5449
# Epoch 42/60
# 241/241 [==============================] - 19s 77ms/step - loss: 330.0942 - root_mean_squared_error: 17.9228 - val_loss: 316.4183 - val_root_mean_squared_error: 17.5440
# Epoch 43/60
# 241/241 [==============================] - 19s 77ms/step - loss: 329.9714 - root_mean_squared_error: 17.9234 - val_loss: 316.1366 - val_root_mean_squared_error: 17.5318
# Epoch 44/60
# 241/241 [==============================] - 19s 77ms/step - loss: 329.4510 - root_mean_squared_error: 17.9104 - val_loss: 315.5167 - val_root_mean_squared_error: 17.5186
# Epoch 45/60
# 241/241 [==============================] - 19s 78ms/step - loss: 329.5919 - root_mean_squared_error: 17.9164 - val_loss: 317.7415 - val_root_mean_squared_error: 17.5914
# Epoch 46/60
# 241/241 [==============================] - 18s 77ms/step - loss: 329.4624 - root_mean_squared_error: 17.9183 - val_loss: 316.3156 - val_root_mean_squared_error: 17.5540
# Epoch 47/60
# 241/241 [==============================] - 19s 77ms/step - loss: 329.1221 - root_mean_squared_error: 17.9118 - val_loss: 318.0499 - val_root_mean_squared_error: 17.5989
# Epoch 48/60
# 241/241 [==============================] - 19s 78ms/step - loss: 329.1770 - root_mean_squared_error: 17.9160 - val_loss: 314.9935 - val_root_mean_squared_error: 17.5183
# Epoch 49/60
# 241/241 [==============================] - 19s 77ms/step - loss: 328.6118 - root_mean_squared_error: 17.9028 - val_loss: 315.5733 - val_root_mean_squared_error: 17.5356
# Epoch 50/60
# 241/241 [==============================] - 19s 78ms/step - loss: 328.5580 - root_mean_squared_error: 17.9040 - val_loss: 315.0542 - val_root_mean_squared_error: 17.5237
# Epoch 51/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.0166 - root_mean_squared_error: 17.8898 - val_loss: 315.1313 - val_root_mean_squared_error: 17.5275
# Epoch 52/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.5875 - root_mean_squared_error: 17.9089 - val_loss: 315.5515 - val_root_mean_squared_error: 17.5463
# Epoch 53/60
# 241/241 [==============================] - 19s 81ms/step - loss: 328.1102 - root_mean_squared_error: 17.8985 - val_loss: 314.9439 - val_root_mean_squared_error: 17.5270
# Epoch 54/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.6883 - root_mean_squared_error: 17.8873 - val_loss: 319.0295 - val_root_mean_squared_error: 17.6344
# Epoch 55/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.0830 - root_mean_squared_error: 17.8695 - val_loss: 314.3699 - val_root_mean_squared_error: 17.5112
# Epoch 56/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.0625 - root_mean_squared_error: 17.9022 - val_loss: 314.2006 - val_root_mean_squared_error: 17.5119
# Epoch 57/60
# 241/241 [==============================] - 19s 79ms/step - loss: 327.3210 - root_mean_squared_error: 17.8823 - val_loss: 313.8880 - val_root_mean_squared_error: 17.5043
# Epoch 58/60
# 241/241 [==============================] - 19s 78ms/step - loss: 327.2622 - root_mean_squared_error: 17.8828 - val_loss: 314.4640 - val_root_mean_squared_error: 17.5224
# Epoch 59/60
# 241/241 [==============================] - 19s 78ms/step - loss: 326.9732 - root_mean_squared_error: 17.8743 - val_loss: 315.1713 - val_root_mean_squared_error: 17.5461
# Epoch 60/60
# 241/241 [==============================] - 19s 78ms/step - loss: 326.6985 - root_mean_squared_error: 17.8700 - val_loss: 314.8377 - val_root_mean_squared_error: 17.5303
# Epoch 1/60
# 241/241 [==============================] - 22s 80ms/step - loss: 766.7823 - root_mean_squared_error: 24.9388 - val_loss: 787.4990 - val_root_mean_squared_error: 22.8076
# Epoch 2/60
# 241/241 [==============================] - 19s 78ms/step - loss: 542.4638 - root_mean_squared_error: 21.4171 - val_loss: 385.5855 - val_root_mean_squared_error: 18.2065
# Epoch 3/60
# 241/241 [==============================] - 19s 78ms/step - loss: 482.4883 - root_mean_squared_error: 20.4930 - val_loss: 443.4586 - val_root_mean_squared_error: 19.1798
# Epoch 4/60
# 241/241 [==============================] - 19s 78ms/step - loss: 452.7208 - root_mean_squared_error: 20.0866 - val_loss: 353.4297 - val_root_mean_squared_error: 17.8943
# Epoch 5/60
# 241/241 [==============================] - 19s 77ms/step - loss: 427.5856 - root_mean_squared_error: 19.6777 - val_loss: 356.2545 - val_root_mean_squared_error: 17.9174
# Epoch 6/60
# 241/241 [==============================] - 19s 78ms/step - loss: 407.6707 - root_mean_squared_error: 19.3307 - val_loss: 342.5223 - val_root_mean_squared_error: 17.8202
# Epoch 7/60
# 241/241 [==============================] - 19s 80ms/step - loss: 397.5983 - root_mean_squared_error: 19.2109 - val_loss: 331.9945 - val_root_mean_squared_error: 17.5404
# Epoch 8/60
# 241/241 [==============================] - 19s 79ms/step - loss: 380.7706 - root_mean_squared_error: 18.8467 - val_loss: 328.4731 - val_root_mean_squared_error: 17.5162
# Epoch 9/60
# 241/241 [==============================] - 19s 78ms/step - loss: 373.1783 - root_mean_squared_error: 18.7201 - val_loss: 326.0616 - val_root_mean_squared_error: 17.4900
# Epoch 10/60
# 241/241 [==============================] - 19s 78ms/step - loss: 362.3318 - root_mean_squared_error: 18.4834 - val_loss: 326.1826 - val_root_mean_squared_error: 17.5292
# Epoch 11/60
# 241/241 [==============================] - 19s 78ms/step - loss: 356.4318 - root_mean_squared_error: 18.3589 - val_loss: 323.3059 - val_root_mean_squared_error: 17.4836
# Epoch 12/60
# 241/241 [==============================] - 19s 78ms/step - loss: 353.0678 - root_mean_squared_error: 18.2969 - val_loss: 323.2309 - val_root_mean_squared_error: 17.4728
# Epoch 13/60
# 241/241 [==============================] - 19s 79ms/step - loss: 349.9380 - root_mean_squared_error: 18.2342 - val_loss: 327.5745 - val_root_mean_squared_error: 17.5803
# Epoch 14/60
# 241/241 [==============================] - 19s 79ms/step - loss: 346.8023 - root_mean_squared_error: 18.1607 - val_loss: 320.9314 - val_root_mean_squared_error: 17.4790
# Epoch 15/60
# 241/241 [==============================] - 19s 78ms/step - loss: 344.3094 - root_mean_squared_error: 18.1207 - val_loss: 322.1602 - val_root_mean_squared_error: 17.5071
# Epoch 16/60
# 241/241 [==============================] - 19s 77ms/step - loss: 341.2383 - root_mean_squared_error: 18.0441 - val_loss: 320.3925 - val_root_mean_squared_error: 17.4860
# Epoch 17/60
# 241/241 [==============================] - 19s 77ms/step - loss: 340.5591 - root_mean_squared_error: 18.0382 - val_loss: 322.6051 - val_root_mean_squared_error: 17.5348
# Epoch 18/60
# 241/241 [==============================] - 19s 78ms/step - loss: 340.0777 - root_mean_squared_error: 18.0434 - val_loss: 319.6285 - val_root_mean_squared_error: 17.4907
# Epoch 19/60
# 241/241 [==============================] - 19s 77ms/step - loss: 338.5018 - root_mean_squared_error: 18.0174 - val_loss: 318.8728 - val_root_mean_squared_error: 17.4788
# Epoch 20/60
# 241/241 [==============================] - 19s 77ms/step - loss: 337.9468 - root_mean_squared_error: 18.0152 - val_loss: 319.8960 - val_root_mean_squared_error: 17.5110
# Epoch 21/60
# 241/241 [==============================] - 19s 77ms/step - loss: 336.0918 - root_mean_squared_error: 17.9745 - val_loss: 318.7012 - val_root_mean_squared_error: 17.4856
# Epoch 22/60
# 241/241 [==============================] - 19s 77ms/step - loss: 335.5097 - root_mean_squared_error: 17.9706 - val_loss: 318.7544 - val_root_mean_squared_error: 17.5058
# Epoch 23/60
# 241/241 [==============================] - 19s 78ms/step - loss: 334.7326 - root_mean_squared_error: 17.9594 - val_loss: 318.3489 - val_root_mean_squared_error: 17.5048
# Epoch 24/60
# 241/241 [==============================] - 19s 78ms/step - loss: 334.6094 - root_mean_squared_error: 17.9665 - val_loss: 317.0897 - val_root_mean_squared_error: 17.4836
# Epoch 25/60
# 241/241 [==============================] - 19s 80ms/step - loss: 334.0561 - root_mean_squared_error: 17.9633 - val_loss: 316.4335 - val_root_mean_squared_error: 17.4812
# Epoch 26/60
# 241/241 [==============================] - 19s 81ms/step - loss: 332.8929 - root_mean_squared_error: 17.9425 - val_loss: 315.9869 - val_root_mean_squared_error: 17.4789
# Epoch 27/60
# 241/241 [==============================] - 20s 81ms/step - loss: 332.8607 - root_mean_squared_error: 17.9538 - val_loss: 315.6022 - val_root_mean_squared_error: 17.4775
# Epoch 28/60
# 241/241 [==============================] - 20s 81ms/step - loss: 332.4564 - root_mean_squared_error: 17.9531 - val_loss: 316.3582 - val_root_mean_squared_error: 17.5033
# Epoch 29/60
# 241/241 [==============================] - 19s 79ms/step - loss: 331.7676 - root_mean_squared_error: 17.9450 - val_loss: 317.9903 - val_root_mean_squared_error: 17.5581
# Epoch 30/60
# 241/241 [==============================] - 21s 85ms/step - loss: 331.1036 - root_mean_squared_error: 17.9347 - val_loss: 314.8267 - val_root_mean_squared_error: 17.4820
# Epoch 31/60
# 241/241 [==============================] - 31s 129ms/step - loss: 331.0457 - root_mean_squared_error: 17.9412 - val_loss: 314.3332 - val_root_mean_squared_error: 17.4804
# Epoch 32/60
# 241/241 [==============================] - 27s 111ms/step - loss: 330.3024 - root_mean_squared_error: 17.9306 - val_loss: 314.1545 - val_root_mean_squared_error: 17.4833
# Epoch 33/60
# 241/241 [==============================] - 22s 93ms/step - loss: 330.0301 - root_mean_squared_error: 17.9338 - val_loss: 314.3274 - val_root_mean_squared_error: 17.4936
# Epoch 34/60
# 241/241 [==============================] - 20s 82ms/step - loss: 330.2095 - root_mean_squared_error: 17.9440 - val_loss: 313.5788 - val_root_mean_squared_error: 17.4810
# Epoch 35/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.7012 - root_mean_squared_error: 17.9364 - val_loss: 313.5265 - val_root_mean_squared_error: 17.4851
# Epoch 36/60
# 241/241 [==============================] - 20s 81ms/step - loss: 329.2867 - root_mean_squared_error: 17.9278 - val_loss: 313.4390 - val_root_mean_squared_error: 17.4808
# Epoch 37/60
# 241/241 [==============================] - 20s 84ms/step - loss: 329.2278 - root_mean_squared_error: 17.9278 - val_loss: 314.8865 - val_root_mean_squared_error: 17.5220
# Epoch 38/60
# 241/241 [==============================] - 20s 81ms/step - loss: 329.3560 - root_mean_squared_error: 17.9343 - val_loss: 314.0338 - val_root_mean_squared_error: 17.5020
# Epoch 39/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.2157 - root_mean_squared_error: 17.9333 - val_loss: 314.5410 - val_root_mean_squared_error: 17.5176
# Epoch 40/60
# 241/241 [==============================] - 19s 81ms/step - loss: 328.7671 - root_mean_squared_error: 17.9216 - val_loss: 314.7915 - val_root_mean_squared_error: 17.5289
# Epoch 41/60
# 241/241 [==============================] - 19s 81ms/step - loss: 329.0333 - root_mean_squared_error: 17.9339 - val_loss: 313.4619 - val_root_mean_squared_error: 17.4931
# Epoch 42/60
# 241/241 [==============================] - 19s 80ms/step - loss: 328.5117 - root_mean_squared_error: 17.9201 - val_loss: 313.1008 - val_root_mean_squared_error: 17.4893
# Epoch 43/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.7289 - root_mean_squared_error: 17.9307 - val_loss: 313.4073 - val_root_mean_squared_error: 17.4978
# Epoch 44/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.2572 - root_mean_squared_error: 17.9195 - val_loss: 313.0846 - val_root_mean_squared_error: 17.4893
# Epoch 45/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.4183 - root_mean_squared_error: 17.9253 - val_loss: 313.1448 - val_root_mean_squared_error: 17.4967
# Epoch 46/60
# 241/241 [==============================] - 19s 79ms/step - loss: 328.6079 - root_mean_squared_error: 17.9339 - val_loss: 313.1505 - val_root_mean_squared_error: 17.4913
# Epoch 47/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.8438 - root_mean_squared_error: 17.9112 - val_loss: 313.0222 - val_root_mean_squared_error: 17.4950
# Epoch 48/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.8091 - root_mean_squared_error: 17.9122 - val_loss: 313.4104 - val_root_mean_squared_error: 17.5069
# Epoch 49/60
# 241/241 [==============================] - 20s 81ms/step - loss: 327.5055 - root_mean_squared_error: 17.9037 - val_loss: 312.6909 - val_root_mean_squared_error: 17.4886
# Epoch 50/60
# 241/241 [==============================] - 20s 81ms/step - loss: 327.5061 - root_mean_squared_error: 17.9068 - val_loss: 312.7405 - val_root_mean_squared_error: 17.4916
# Epoch 51/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.7813 - root_mean_squared_error: 17.9186 - val_loss: 312.1288 - val_root_mean_squared_error: 17.4771
# Epoch 52/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.6527 - root_mean_squared_error: 17.9161 - val_loss: 313.5740 - val_root_mean_squared_error: 17.5130
# Epoch 53/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.4878 - root_mean_squared_error: 17.9121 - val_loss: 314.8648 - val_root_mean_squared_error: 17.5463
# Epoch 54/60
# 241/241 [==============================] - 19s 81ms/step - loss: 327.5492 - root_mean_squared_error: 17.9159 - val_loss: 313.9499 - val_root_mean_squared_error: 17.5280
# Epoch 55/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.2367 - root_mean_squared_error: 17.9081 - val_loss: 312.6465 - val_root_mean_squared_error: 17.5000
# Epoch 56/60
# 241/241 [==============================] - 19s 79ms/step - loss: 326.4923 - root_mean_squared_error: 17.8886 - val_loss: 316.8465 - val_root_mean_squared_error: 17.6132
# Epoch 57/60
# 241/241 [==============================] - 19s 78ms/step - loss: 327.3012 - root_mean_squared_error: 17.9138 - val_loss: 314.1055 - val_root_mean_squared_error: 17.5399
# Epoch 58/60
# 241/241 [==============================] - 19s 79ms/step - loss: 325.7378 - root_mean_squared_error: 17.8678 - val_loss: 311.9734 - val_root_mean_squared_error: 17.4838
# Epoch 59/60
# 241/241 [==============================] - 19s 79ms/step - loss: 327.2380 - root_mean_squared_error: 17.9144 - val_loss: 313.9136 - val_root_mean_squared_error: 17.5390
# Epoch 60/60
# 241/241 [==============================] - 19s 80ms/step - loss: 326.7471 - root_mean_squared_error: 17.9000 - val_loss: 313.3375 - val_root_mean_squared_error: 17.5233
# Epoch 1/60
# 241/241 [==============================] - 24s 86ms/step - loss: 742.5908 - root_mean_squared_error: 24.7643 - val_loss: 558.8757 - val_root_mean_squared_error: 22.1908
# Epoch 2/60
# 241/241 [==============================] - 19s 80ms/step - loss: 521.3185 - root_mean_squared_error: 21.2972 - val_loss: 404.4935 - val_root_mean_squared_error: 18.3165
# Epoch 3/60
# 241/241 [==============================] - 19s 81ms/step - loss: 469.2210 - root_mean_squared_error: 20.4524 - val_loss: 410.6564 - val_root_mean_squared_error: 19.0413
# Epoch 4/60
# 241/241 [==============================] - 19s 80ms/step - loss: 442.2554 - root_mean_squared_error: 19.9957 - val_loss: 365.8745 - val_root_mean_squared_error: 18.0852
# Epoch 5/60
# 241/241 [==============================] - 20s 81ms/step - loss: 427.4467 - root_mean_squared_error: 19.7732 - val_loss: 372.3385 - val_root_mean_squared_error: 18.4670
# Epoch 6/60
# 241/241 [==============================] - 20s 81ms/step - loss: 406.4473 - root_mean_squared_error: 19.3600 - val_loss: 365.7899 - val_root_mean_squared_error: 18.4758
# Epoch 7/60
# 241/241 [==============================] - 20s 81ms/step - loss: 394.2787 - root_mean_squared_error: 19.1346 - val_loss: 353.6094 - val_root_mean_squared_error: 18.1613
# Epoch 8/60
# 241/241 [==============================] - 20s 82ms/step - loss: 385.7897 - root_mean_squared_error: 18.9958 - val_loss: 352.3327 - val_root_mean_squared_error: 18.1780
# Epoch 9/60
# 241/241 [==============================] - 20s 81ms/step - loss: 374.7668 - root_mean_squared_error: 18.7568 - val_loss: 348.7896 - val_root_mean_squared_error: 18.0973
# Epoch 10/60
# 241/241 [==============================] - 19s 80ms/step - loss: 365.6379 - root_mean_squared_error: 18.5652 - val_loss: 347.3820 - val_root_mean_squared_error: 18.1236
# Epoch 11/60
# 241/241 [==============================] - 19s 79ms/step - loss: 360.2181 - root_mean_squared_error: 18.4579 - val_loss: 342.1675 - val_root_mean_squared_error: 17.9752
# Epoch 12/60
# 241/241 [==============================] - 19s 80ms/step - loss: 358.3369 - root_mean_squared_error: 18.4305 - val_loss: 342.2255 - val_root_mean_squared_error: 18.0339
# Epoch 13/60
# 241/241 [==============================] - 19s 80ms/step - loss: 351.6694 - root_mean_squared_error: 18.2731 - val_loss: 341.7868 - val_root_mean_squared_error: 18.0316
# Epoch 14/60
# 241/241 [==============================] - 20s 81ms/step - loss: 345.6583 - root_mean_squared_error: 18.1243 - val_loss: 338.9047 - val_root_mean_squared_error: 17.9523
# Epoch 15/60
# 241/241 [==============================] - 19s 80ms/step - loss: 345.3665 - root_mean_squared_error: 18.1271 - val_loss: 339.7516 - val_root_mean_squared_error: 18.0026
# Epoch 16/60
# 241/241 [==============================] - 20s 82ms/step - loss: 344.6239 - root_mean_squared_error: 18.1216 - val_loss: 340.0401 - val_root_mean_squared_error: 18.0253
# Epoch 17/60
# 241/241 [==============================] - 20s 83ms/step - loss: 340.7493 - root_mean_squared_error: 18.0359 - val_loss: 338.5843 - val_root_mean_squared_error: 17.9643
# Epoch 18/60
# 241/241 [==============================] - 20s 85ms/step - loss: 340.9923 - root_mean_squared_error: 18.0532 - val_loss: 337.0068 - val_root_mean_squared_error: 17.9516
# Epoch 19/60
# 241/241 [==============================] - 20s 82ms/step - loss: 338.2046 - root_mean_squared_error: 17.9868 - val_loss: 341.6216 - val_root_mean_squared_error: 18.0815
# Epoch 20/60
# 241/241 [==============================] - 20s 82ms/step - loss: 337.5628 - root_mean_squared_error: 17.9762 - val_loss: 337.0133 - val_root_mean_squared_error: 17.9595
# Epoch 21/60
# 241/241 [==============================] - 20s 82ms/step - loss: 338.5179 - root_mean_squared_error: 18.0123 - val_loss: 338.3807 - val_root_mean_squared_error: 18.0099
# Epoch 22/60
# 241/241 [==============================] - 20s 81ms/step - loss: 336.2564 - root_mean_squared_error: 17.9606 - val_loss: 336.8565 - val_root_mean_squared_error: 17.9899
# Epoch 23/60
# 241/241 [==============================] - 20s 81ms/step - loss: 334.1918 - root_mean_squared_error: 17.9111 - val_loss: 336.7640 - val_root_mean_squared_error: 17.9867
# Epoch 24/60
# 241/241 [==============================] - 20s 82ms/step - loss: 334.2973 - root_mean_squared_error: 17.9233 - val_loss: 335.8123 - val_root_mean_squared_error: 17.9747
# Epoch 25/60
# 241/241 [==============================] - 20s 81ms/step - loss: 333.9272 - root_mean_squared_error: 17.9209 - val_loss: 335.5973 - val_root_mean_squared_error: 17.9775
# Epoch 26/60
# 241/241 [==============================] - 20s 82ms/step - loss: 332.8785 - root_mean_squared_error: 17.8999 - val_loss: 335.9185 - val_root_mean_squared_error: 17.9954
# Epoch 27/60
# 241/241 [==============================] - 20s 82ms/step - loss: 332.4892 - root_mean_squared_error: 17.8984 - val_loss: 334.7288 - val_root_mean_squared_error: 17.9641
# Epoch 28/60
# 241/241 [==============================] - 20s 82ms/step - loss: 331.7677 - root_mean_squared_error: 17.8850 - val_loss: 334.2393 - val_root_mean_squared_error: 17.9593
# Epoch 29/60
# 241/241 [==============================] - 22s 93ms/step - loss: 332.0172 - root_mean_squared_error: 17.9007 - val_loss: 335.7604 - val_root_mean_squared_error: 18.0004
# Epoch 30/60
# 241/241 [==============================] - 20s 84ms/step - loss: 331.2430 - root_mean_squared_error: 17.8840 - val_loss: 334.0208 - val_root_mean_squared_error: 17.9648
# Epoch 31/60
# 241/241 [==============================] - 20s 84ms/step - loss: 330.6688 - root_mean_squared_error: 17.8790 - val_loss: 333.9002 - val_root_mean_squared_error: 17.9795
# Epoch 32/60
# 241/241 [==============================] - 20s 81ms/step - loss: 329.9659 - root_mean_squared_error: 17.8665 - val_loss: 334.0284 - val_root_mean_squared_error: 17.9884
# Epoch 33/60
# 241/241 [==============================] - 19s 80ms/step - loss: 329.4881 - root_mean_squared_error: 17.8605 - val_loss: 333.6387 - val_root_mean_squared_error: 17.9886
# Epoch 34/60
# 241/241 [==============================] - 20s 82ms/step - loss: 328.3237 - root_mean_squared_error: 17.8347 - val_loss: 332.4510 - val_root_mean_squared_error: 17.9561
# Epoch 35/60
# 241/241 [==============================] - 20s 81ms/step - loss: 328.5576 - root_mean_squared_error: 17.8453 - val_loss: 332.7031 - val_root_mean_squared_error: 17.9609
# Epoch 36/60
# 241/241 [==============================] - 19s 80ms/step - loss: 327.7160 - root_mean_squared_error: 17.8262 - val_loss: 333.8655 - val_root_mean_squared_error: 18.0084
# Epoch 37/60
# 241/241 [==============================] - 20s 81ms/step - loss: 328.3914 - root_mean_squared_error: 17.8517 - val_loss: 332.0094 - val_root_mean_squared_error: 17.9558
# Epoch 38/60
# 241/241 [==============================] - 20s 83ms/step - loss: 326.7310 - root_mean_squared_error: 17.8094 - val_loss: 330.9097 - val_root_mean_squared_error: 17.9285
# Epoch 39/60
# 241/241 [==============================] - 20s 83ms/step - loss: 327.2519 - root_mean_squared_error: 17.8272 - val_loss: 331.9249 - val_root_mean_squared_error: 17.9697
# Epoch 40/60
# 241/241 [==============================] - 20s 82ms/step - loss: 327.4207 - root_mean_squared_error: 17.8391 - val_loss: 332.2374 - val_root_mean_squared_error: 17.9838
# Epoch 41/60
# 241/241 [==============================] - 20s 81ms/step - loss: 326.2184 - root_mean_squared_error: 17.8093 - val_loss: 331.6429 - val_root_mean_squared_error: 17.9690
# Epoch 42/60
# 241/241 [==============================] - 20s 82ms/step - loss: 326.6907 - root_mean_squared_error: 17.8304 - val_loss: 331.2743 - val_root_mean_squared_error: 17.9561
# Epoch 43/60
# 241/241 [==============================] - 20s 82ms/step - loss: 326.5449 - root_mean_squared_error: 17.8303 - val_loss: 330.6327 - val_root_mean_squared_error: 17.9458
# Epoch 44/60
# 241/241 [==============================] - 20s 81ms/step - loss: 325.6504 - root_mean_squared_error: 17.8094 - val_loss: 330.5186 - val_root_mean_squared_error: 17.9425
# Epoch 45/60
# 241/241 [==============================] - 20s 81ms/step - loss: 326.1199 - root_mean_squared_error: 17.8244 - val_loss: 331.1543 - val_root_mean_squared_error: 17.9695
# Epoch 46/60
# 241/241 [==============================] - 20s 81ms/step - loss: 325.7821 - root_mean_squared_error: 17.8199 - val_loss: 330.5088 - val_root_mean_squared_error: 17.9530
# Epoch 47/60
# 241/241 [==============================] - 20s 82ms/step - loss: 325.2711 - root_mean_squared_error: 17.8019 - val_loss: 330.2311 - val_root_mean_squared_error: 17.9451
# Epoch 48/60
# 241/241 [==============================] - 20s 82ms/step - loss: 325.4197 - root_mean_squared_error: 17.8134 - val_loss: 330.9162 - val_root_mean_squared_error: 17.9669
# Epoch 49/60
# 241/241 [==============================] - 20s 82ms/step - loss: 325.3529 - root_mean_squared_error: 17.8106 - val_loss: 329.9358 - val_root_mean_squared_error: 17.9453
# Epoch 50/60
# 241/241 [==============================] - 20s 81ms/step - loss: 325.5520 - root_mean_squared_error: 17.8233 - val_loss: 329.7398 - val_root_mean_squared_error: 17.9396
# Epoch 51/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.8237 - root_mean_squared_error: 17.8010 - val_loss: 330.3105 - val_root_mean_squared_error: 17.9571
# Epoch 52/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.7197 - root_mean_squared_error: 17.8025 - val_loss: 330.5993 - val_root_mean_squared_error: 17.9637
# Epoch 53/60
# 241/241 [==============================] - 20s 83ms/step - loss: 324.1327 - root_mean_squared_error: 17.7843 - val_loss: 330.6701 - val_root_mean_squared_error: 17.9652
# Epoch 54/60
# 241/241 [==============================] - 20s 83ms/step - loss: 323.9147 - root_mean_squared_error: 17.7763 - val_loss: 330.3488 - val_root_mean_squared_error: 17.9616
# Epoch 55/60
# 241/241 [==============================] - 20s 82ms/step - loss: 323.4434 - root_mean_squared_error: 17.7662 - val_loss: 330.4004 - val_root_mean_squared_error: 17.9650
# Epoch 56/60
# 241/241 [==============================] - 19s 80ms/step - loss: 324.0742 - root_mean_squared_error: 17.7865 - val_loss: 330.4549 - val_root_mean_squared_error: 17.9695
# Epoch 57/60
# 241/241 [==============================] - 19s 81ms/step - loss: 324.5647 - root_mean_squared_error: 17.8065 - val_loss: 329.3844 - val_root_mean_squared_error: 17.9454
# Epoch 58/60
# 241/241 [==============================] - 20s 82ms/step - loss: 323.4571 - root_mean_squared_error: 17.7738 - val_loss: 329.4183 - val_root_mean_squared_error: 17.9437
# Epoch 59/60
# 241/241 [==============================] - 20s 82ms/step - loss: 323.3655 - root_mean_squared_error: 17.7728 - val_loss: 329.7399 - val_root_mean_squared_error: 17.9530
# Epoch 60/60
# 241/241 [==============================] - 20s 82ms/step - loss: 323.3961 - root_mean_squared_error: 17.7767 - val_loss: 329.1676 - val_root_mean_squared_error: 17.9371
# The train MSE is 323.7685913085937
# The train RMSE is 17.800146865844727
# The validation MSE is 325.7685791015625
# The validation RMSE is 17.854700088500977

# %%
# Create overview of layers in model
# Create overview of layers in model
tabular_NN = build_neural_net(12, hidden_nodes=20)
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size, hidden_nodes=20)

concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)

tf.keras.utils.plot_model(concat_model,  to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')
