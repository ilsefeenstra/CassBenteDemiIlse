# %%
import zipfile
import os
import cv2
import pandas as pd
from os import chdir, listdir

import matplotlib.pyplot as plt
import numpy as np
import random

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing, regularizers
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from keras import backend as K
from keras import activations

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-26 15:17:00--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-26 15:17:00--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [                <=> ]   1001M  23.2MB/s    in 44s
#
# 2022-01-26 15:17:45 (22.5 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1049315921]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# Create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis. After the images are imported, the images and their names are shuffled. This is done, so we can later take a validation sample containing a random subsample of the dataset. It could be that the images in the dataset contain some order, so by shuffling we ensure that the subset for the validation data is random.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])

        # Reset the index of the dataframe
        data_sorted = data_sorted.reset_index().drop(['index'],axis=1)
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

# %% [markdown]
# # Processing data
# The tabular data is split in x and y values and converted to numpy arrays, so the neural network can handle the data. Moreover, the image data is converted to numpy arrays.

# %%
# Remove samples with pawpularity score of 100
indexNames = train_data_sorted[train_data_sorted['Pawpularity'] == 100].index
train_data_new = train_data_sorted.drop(indexNames)
train_imgs_new = np.delete(train_imgs, indexNames, axis=0)

# %%
# Select x-values (the 12 input features) and y-values from training data
x_tabular = train_data_new.iloc[:,1:13].to_numpy()
y = train_data_new.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# Create numpy array of image data 
x_images = np.array(train_imgs_new)
test_imgs_array = np.array(test_imgs)

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create hidden layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation='relu', input_shape=(input_size,)))    

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    return model

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=image_size, padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))
    
    return model

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
def linear_limit(x):
    """
    Create a linear activation function that clips the output at 0 and 100.
    """
    activation_x = activations.linear(x)
    activation_x_new = K.clip(activation_x, 0, 100)

    return activation_x_new

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layer with relu activation
    hidden_layer_1 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(concat_input)

    # Create hidden layer with relu activation
    drop_out_1 = layers.Dropout(0.4)(hidden_layer_1)    
    hidden_layer_2 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_1)

    # Create hidden layer with relu activation
    drop_out_2 = layers.Dropout(0.4)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_2)

    # Create output layer
    output_layer = layers.Dense(1, activation=linear_limit)(hidden_layer_3)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
    """
    This function trains and evaluated a model. It first compiles the model with 
    the loss and metrics. It then makes a train and validation generator for the 
    image data, based on the preprocess and augment input. 
    It then trains the model on both the image and tabular data for epochs times. 
    The values of the loss and metric are plotted and printed.
    """
    # Compile model and use mean squared error as loss and root mean squared error as metric
    model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

    # Preprocess the image data
    train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
    train_gen.fit(image_x)

    val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
    val_gen.fit(image_x)

    # Train the model by fitting both tabular and image data at the same time
    history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs = epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

    return history

# %%
from sklearn.model_selection import KFold

def k_fold(num_folds, x_tabular, y, x_imgs, epochs=20, preprocess={}, augment={}):
    """
    Train and evaluate the data for num-folds times, and return the average 
    training and validation loss. First the data is split in num-folds batches
    and then the model is trained on the data, where a different batch is the 
    validation data each time.
    """
    # Create kfold object to later split the data
    kfold = KFold(n_splits=num_folds, shuffle=True)
    x_indices = np.array(range(len(x_tabular)))
    y_indices = np.array(range(len(y)))

    # Pre allocate variables to store the MSE (loss) and RMSE (accuracy)
    train_loss = np.array(np.zeros(epochs))
    train_acc = np.array(np.zeros(epochs))
    val_loss = np.array(np.zeros(epochs))
    val_acc = np.array(np.zeros(epochs))
    
    # Train and evaluate the model for num-fold times on a different training 
    # and validation set each time
    for id_train, id_val in kfold.split(x_indices, y_indices):
        
        # Make Neural Networks before concatenation
        tabular_NN = build_neural_net(12, hidden_nodes=20)
        image_size = (64, 64, 3)
        image_NN = build_convol_net(image_size, hidden_nodes=100)

        # Create subset training and validation data
        x_tabular_train = x_tabular[id_train]
        x_imgs_train = x_imgs[id_train]
        y_train = y[id_train]
        
        x_tabular_val = x_tabular[id_val]
        x_imgs_val = x_imgs[id_val]
        y_val_2 = y[id_val]
        
        # Train and evaluate the model
        concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=40)
        history = train_and_evaluate(concat_model, x_imgs_train, x_tabular_train, 
                           y_train, x_tabular_val, x_imgs_val, y_val_2, epochs=epochs, preprocess=preprocess, augment=augment)

        # Add all the losses and metrics
        train_loss += history.history['loss']
        train_acc += history.history['root_mean_squared_error']
        val_loss += history.history['val_loss']
        val_acc += history.history['val_root_mean_squared_error']

    # Calculate average loss and metric
    avg_train_loss = train_loss / num_folds
    avg_val_loss = val_loss / num_folds
    avg_train_acc = train_acc / num_folds
    avg_val_acc = val_acc / num_folds

    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    # Plot MSE
    axs[0].plot(avg_train_loss)
    axs[0].plot(avg_val_loss)
    axs[0].legend(['training', 'validation'], loc='best')
    
    axs[0].set_title('Model MSE')
    axs[0].set_ylabel('MSE')
    axs[0].set_xlabel('epoch')
    axs[0].set_ylim([0, 1000])

    # Plot RMSE
    axs[1].plot(avg_train_acc)
    axs[1].plot(avg_val_acc)
    axs[1].legend(['training', 'validation'], loc='best')
    
    axs[1].set_title('Model RMSE')
    axs[1].set_ylabel('RMSE')
    axs[1].set_xlabel('epoch')
    axs[1].set_ylim([0, 30])

    plt.show()

    return avg_train_loss[-1], avg_val_loss[-1], avg_train_acc[-1], avg_val_acc[-1]

# Use k-fold cross-validation to train and evaluate concatenated network
avg_train_loss, avg_val_loss, avg_train_acc, avg_val_acc = k_fold(5, x_tabular, y, x_images, epochs=60, 
                                               preprocess={'featurewise_center': True, 'featurewise_std_normalization': True},
                                               augment={'rotation_range': 90, 'horizontal_flip': True, 'shear_range': 0.2})

print(f'The train MSE is {avg_train_loss}')
print(f'The train RMSE is {avg_train_acc}')
print(f'The validation MSE is {avg_val_loss}')
print(f'The validation RMSE is {avg_val_acc}')
# Out:
# Epoch 1/60
# 241/241 [==============================] - 23s 44ms/step - loss: 791.8835 - root_mean_squared_error: 24.3920 - val_loss: 682.5658 - val_root_mean_squared_error: 24.8657
# Epoch 2/60
# 241/241 [==============================] - 10s 41ms/step - loss: 607.2177 - root_mean_squared_error: 22.0652 - val_loss: 571.8417 - val_root_mean_squared_error: 22.6704
# Epoch 3/60
# 241/241 [==============================] - 10s 42ms/step - loss: 538.5196 - root_mean_squared_error: 21.2801 - val_loss: 501.7704 - val_root_mean_squared_error: 21.3471
# Epoch 4/60
# 241/241 [==============================] - 10s 42ms/step - loss: 475.7248 - root_mean_squared_error: 20.3073 - val_loss: 436.3024 - val_root_mean_squared_error: 19.9191
# Epoch 5/60
# 241/241 [==============================] - 10s 43ms/step - loss: 430.9701 - root_mean_squared_error: 19.5773 - val_loss: 385.5380 - val_root_mean_squared_error: 18.7240
# Epoch 6/60
# 241/241 [==============================] - 10s 42ms/step - loss: 389.8952 - root_mean_squared_error: 18.7738 - val_loss: 343.3514 - val_root_mean_squared_error: 17.6666
# Epoch 7/60
# 241/241 [==============================] - 10s 42ms/step - loss: 365.6327 - root_mean_squared_error: 18.2901 - val_loss: 339.8302 - val_root_mean_squared_error: 17.6040
# Epoch 8/60
# 241/241 [==============================] - 10s 43ms/step - loss: 357.8622 - root_mean_squared_error: 18.1573 - val_loss: 340.6344 - val_root_mean_squared_error: 17.7208
# Epoch 9/60
# 241/241 [==============================] - 10s 42ms/step - loss: 357.7016 - root_mean_squared_error: 18.1982 - val_loss: 337.9213 - val_root_mean_squared_error: 17.6446
# Epoch 10/60
# 241/241 [==============================] - 10s 42ms/step - loss: 352.8959 - root_mean_squared_error: 18.1126 - val_loss: 335.8635 - val_root_mean_squared_error: 17.6840
# Epoch 11/60
# 241/241 [==============================] - 10s 43ms/step - loss: 351.4429 - root_mean_squared_error: 18.1390 - val_loss: 331.5575 - val_root_mean_squared_error: 17.6244
# Epoch 12/60
# 241/241 [==============================] - 10s 43ms/step - loss: 347.6186 - root_mean_squared_error: 18.0885 - val_loss: 331.8080 - val_root_mean_squared_error: 17.6230
# Epoch 13/60
# 241/241 [==============================] - 10s 43ms/step - loss: 345.7424 - root_mean_squared_error: 18.0527 - val_loss: 328.5870 - val_root_mean_squared_error: 17.6359
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 343.1381 - root_mean_squared_error: 18.0346 - val_loss: 326.9768 - val_root_mean_squared_error: 17.6188
# Epoch 15/60
# 241/241 [==============================] - 10s 42ms/step - loss: 340.3889 - root_mean_squared_error: 18.0023 - val_loss: 331.3595 - val_root_mean_squared_error: 17.7443
# Epoch 16/60
# 241/241 [==============================] - 10s 42ms/step - loss: 339.4550 - root_mean_squared_error: 18.0147 - val_loss: 323.9978 - val_root_mean_squared_error: 17.6062
# Epoch 17/60
# 241/241 [==============================] - 10s 42ms/step - loss: 336.7677 - root_mean_squared_error: 17.9849 - val_loss: 322.1942 - val_root_mean_squared_error: 17.6043
# Epoch 18/60
# 241/241 [==============================] - 10s 42ms/step - loss: 335.1460 - root_mean_squared_error: 17.9601 - val_loss: 321.5228 - val_root_mean_squared_error: 17.5931
# Epoch 19/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.3126 - root_mean_squared_error: 17.9539 - val_loss: 323.1170 - val_root_mean_squared_error: 17.6667
# Epoch 20/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.3430 - root_mean_squared_error: 17.9738 - val_loss: 320.4706 - val_root_mean_squared_error: 17.6014
# Epoch 21/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.0528 - root_mean_squared_error: 17.9595 - val_loss: 323.1062 - val_root_mean_squared_error: 17.6560
# Epoch 22/60
# 241/241 [==============================] - 10s 42ms/step - loss: 332.5645 - root_mean_squared_error: 17.9574 - val_loss: 319.9185 - val_root_mean_squared_error: 17.6091
# Epoch 23/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.5095 - root_mean_squared_error: 17.9265 - val_loss: 319.0716 - val_root_mean_squared_error: 17.5963
# Epoch 24/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.7486 - root_mean_squared_error: 17.9243 - val_loss: 319.3502 - val_root_mean_squared_error: 17.6128
# Epoch 25/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.6376 - root_mean_squared_error: 17.9267 - val_loss: 320.3595 - val_root_mean_squared_error: 17.6448
# Epoch 26/60
# 241/241 [==============================] - 10s 42ms/step - loss: 329.7886 - root_mean_squared_error: 17.9111 - val_loss: 318.5434 - val_root_mean_squared_error: 17.6030
# Epoch 27/60
# 241/241 [==============================] - 10s 42ms/step - loss: 329.4197 - root_mean_squared_error: 17.9061 - val_loss: 318.3527 - val_root_mean_squared_error: 17.5988
# Epoch 28/60
# 241/241 [==============================] - 10s 42ms/step - loss: 329.1393 - root_mean_squared_error: 17.9087 - val_loss: 318.7004 - val_root_mean_squared_error: 17.6197
# Epoch 29/60
# 241/241 [==============================] - 10s 42ms/step - loss: 329.0781 - root_mean_squared_error: 17.9159 - val_loss: 317.5679 - val_root_mean_squared_error: 17.5914
# Epoch 30/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.7752 - root_mean_squared_error: 17.9073 - val_loss: 318.6852 - val_root_mean_squared_error: 17.6297
# Epoch 31/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.3954 - root_mean_squared_error: 17.9035 - val_loss: 318.1036 - val_root_mean_squared_error: 17.6089
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.3419 - root_mean_squared_error: 17.9099 - val_loss: 317.6913 - val_root_mean_squared_error: 17.6115
# Epoch 33/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.1589 - root_mean_squared_error: 17.9047 - val_loss: 316.9451 - val_root_mean_squared_error: 17.5960
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.9134 - root_mean_squared_error: 17.9028 - val_loss: 318.4890 - val_root_mean_squared_error: 17.6325
# Epoch 35/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.0322 - root_mean_squared_error: 17.9034 - val_loss: 316.7407 - val_root_mean_squared_error: 17.5892
# Epoch 36/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.7444 - root_mean_squared_error: 17.9023 - val_loss: 317.6837 - val_root_mean_squared_error: 17.6201
# Epoch 37/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.2278 - root_mean_squared_error: 17.8877 - val_loss: 317.3164 - val_root_mean_squared_error: 17.6097
# Epoch 38/60
# 241/241 [==============================] - 10s 42ms/step - loss: 327.1436 - root_mean_squared_error: 17.8888 - val_loss: 319.2975 - val_root_mean_squared_error: 17.6653
# Epoch 39/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.6978 - root_mean_squared_error: 17.8731 - val_loss: 316.9609 - val_root_mean_squared_error: 17.6045
# Epoch 40/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.9533 - root_mean_squared_error: 17.8854 - val_loss: 317.1246 - val_root_mean_squared_error: 17.6132
# Epoch 41/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.9514 - root_mean_squared_error: 17.8845 - val_loss: 317.3845 - val_root_mean_squared_error: 17.6167
# Epoch 42/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.0796 - root_mean_squared_error: 17.8899 - val_loss: 318.3556 - val_root_mean_squared_error: 17.6487
# Epoch 43/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.3848 - root_mean_squared_error: 17.8671 - val_loss: 317.6990 - val_root_mean_squared_error: 17.6254
# Epoch 44/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.3779 - root_mean_squared_error: 17.8649 - val_loss: 316.6059 - val_root_mean_squared_error: 17.5973
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.9761 - root_mean_squared_error: 17.8562 - val_loss: 316.7007 - val_root_mean_squared_error: 17.5892
# Epoch 46/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.6608 - root_mean_squared_error: 17.8465 - val_loss: 317.4272 - val_root_mean_squared_error: 17.6233
# Epoch 47/60
# 241/241 [==============================] - 10s 42ms/step - loss: 325.4374 - root_mean_squared_error: 17.8409 - val_loss: 316.4956 - val_root_mean_squared_error: 17.5912
# Epoch 48/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.0512 - root_mean_squared_error: 17.8581 - val_loss: 316.9105 - val_root_mean_squared_error: 17.6106
# Epoch 49/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.1109 - root_mean_squared_error: 17.8329 - val_loss: 321.2018 - val_root_mean_squared_error: 17.7236
# Epoch 50/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.8362 - root_mean_squared_error: 17.8215 - val_loss: 318.0779 - val_root_mean_squared_error: 17.6341
# Epoch 51/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.0025 - root_mean_squared_error: 17.7947 - val_loss: 320.4683 - val_root_mean_squared_error: 17.7001
# Epoch 52/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.8461 - root_mean_squared_error: 17.8184 - val_loss: 317.9637 - val_root_mean_squared_error: 17.6290
# Epoch 53/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.2734 - root_mean_squared_error: 17.8046 - val_loss: 317.2181 - val_root_mean_squared_error: 17.6095
# Epoch 54/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.6479 - root_mean_squared_error: 17.7865 - val_loss: 317.0912 - val_root_mean_squared_error: 17.5963
# Epoch 55/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.8607 - root_mean_squared_error: 17.7924 - val_loss: 317.5800 - val_root_mean_squared_error: 17.6192
# Epoch 56/60
# 241/241 [==============================] - 10s 42ms/step - loss: 324.1902 - root_mean_squared_error: 17.7984 - val_loss: 318.7957 - val_root_mean_squared_error: 17.6533
# Epoch 57/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.1638 - root_mean_squared_error: 17.7978 - val_loss: 318.5112 - val_root_mean_squared_error: 17.6479
# Epoch 58/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.5513 - root_mean_squared_error: 17.7795 - val_loss: 320.9560 - val_root_mean_squared_error: 17.7125
# Epoch 59/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.5146 - root_mean_squared_error: 17.7799 - val_loss: 320.2544 - val_root_mean_squared_error: 17.6916
# Epoch 60/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.5873 - root_mean_squared_error: 17.8110 - val_loss: 320.9134 - val_root_mean_squared_error: 17.7090
# Epoch 1/60
# 241/241 [==============================] - 13s 44ms/step - loss: 810.9586 - root_mean_squared_error: 24.7564 - val_loss: 638.0914 - val_root_mean_squared_error: 23.7244
# Epoch 2/60
# 241/241 [==============================] - 10s 43ms/step - loss: 623.6445 - root_mean_squared_error: 22.3007 - val_loss: 572.5203 - val_root_mean_squared_error: 22.4463
# Epoch 3/60
# 241/241 [==============================] - 10s 43ms/step - loss: 550.7913 - root_mean_squared_error: 21.3760 - val_loss: 504.9000 - val_root_mean_squared_error: 21.2031
# Epoch 4/60
# 241/241 [==============================] - 10s 44ms/step - loss: 496.6953 - root_mean_squared_error: 20.6769 - val_loss: 463.3249 - val_root_mean_squared_error: 20.5056
# Epoch 5/60
# 241/241 [==============================] - 10s 43ms/step - loss: 440.1830 - root_mean_squared_error: 19.7144 - val_loss: 390.6858 - val_root_mean_squared_error: 18.8852
# Epoch 6/60
# 241/241 [==============================] - 10s 43ms/step - loss: 396.4652 - root_mean_squared_error: 18.9220 - val_loss: 343.2033 - val_root_mean_squared_error: 17.6255
# Epoch 7/60
# 241/241 [==============================] - 10s 43ms/step - loss: 366.4013 - root_mean_squared_error: 18.2923 - val_loss: 340.0341 - val_root_mean_squared_error: 17.6606
# Epoch 8/60
# 241/241 [==============================] - 11s 44ms/step - loss: 361.9968 - root_mean_squared_error: 18.2799 - val_loss: 331.7700 - val_root_mean_squared_error: 17.4915
# Epoch 9/60
# 241/241 [==============================] - 10s 43ms/step - loss: 357.9044 - root_mean_squared_error: 18.2419 - val_loss: 331.7525 - val_root_mean_squared_error: 17.5800
# Epoch 10/60
# 241/241 [==============================] - 10s 43ms/step - loss: 355.4779 - root_mean_squared_error: 18.2271 - val_loss: 329.4382 - val_root_mean_squared_error: 17.5656
# Epoch 11/60
# 241/241 [==============================] - 10s 43ms/step - loss: 352.7294 - root_mean_squared_error: 18.2086 - val_loss: 326.5045 - val_root_mean_squared_error: 17.5161
# Epoch 12/60
# 241/241 [==============================] - 10s 43ms/step - loss: 349.7024 - root_mean_squared_error: 18.1743 - val_loss: 322.3008 - val_root_mean_squared_error: 17.4634
# Epoch 13/60
# 241/241 [==============================] - 10s 43ms/step - loss: 346.1355 - root_mean_squared_error: 18.1240 - val_loss: 326.2853 - val_root_mean_squared_error: 17.5729
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 343.3018 - root_mean_squared_error: 18.0902 - val_loss: 319.8231 - val_root_mean_squared_error: 17.4716
# Epoch 15/60
# 241/241 [==============================] - 10s 43ms/step - loss: 340.2453 - root_mean_squared_error: 18.0529 - val_loss: 318.0429 - val_root_mean_squared_error: 17.4611
# Epoch 16/60
# 241/241 [==============================] - 11s 44ms/step - loss: 338.5697 - root_mean_squared_error: 18.0408 - val_loss: 317.6653 - val_root_mean_squared_error: 17.4689
# Epoch 17/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.1287 - root_mean_squared_error: 18.0147 - val_loss: 318.2600 - val_root_mean_squared_error: 17.4997
# Epoch 18/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.3582 - root_mean_squared_error: 18.0349 - val_loss: 317.7163 - val_root_mean_squared_error: 17.4899
# Epoch 19/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.7789 - root_mean_squared_error: 18.0050 - val_loss: 318.4329 - val_root_mean_squared_error: 17.5216
# Epoch 20/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.8062 - root_mean_squared_error: 18.0169 - val_loss: 323.5432 - val_root_mean_squared_error: 17.6185
# Epoch 21/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.4914 - root_mean_squared_error: 18.0160 - val_loss: 318.1173 - val_root_mean_squared_error: 17.5225
# Epoch 22/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.4276 - root_mean_squared_error: 17.9943 - val_loss: 315.7323 - val_root_mean_squared_error: 17.4848
# Epoch 23/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.2826 - root_mean_squared_error: 17.9766 - val_loss: 314.9898 - val_root_mean_squared_error: 17.4697
# Epoch 24/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.4088 - root_mean_squared_error: 17.9905 - val_loss: 317.2444 - val_root_mean_squared_error: 17.5377
# Epoch 25/60
# 241/241 [==============================] - 10s 43ms/step - loss: 332.8554 - root_mean_squared_error: 17.9851 - val_loss: 316.6265 - val_root_mean_squared_error: 17.5262
# Epoch 26/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.7060 - root_mean_squared_error: 17.9526 - val_loss: 314.2139 - val_root_mean_squared_error: 17.4733
# Epoch 27/60
# 241/241 [==============================] - 10s 43ms/step - loss: 332.4076 - root_mean_squared_error: 17.9764 - val_loss: 315.4061 - val_root_mean_squared_error: 17.5073
# Epoch 28/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.2152 - root_mean_squared_error: 17.9528 - val_loss: 314.8753 - val_root_mean_squared_error: 17.5003
# Epoch 29/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.0313 - root_mean_squared_error: 17.9500 - val_loss: 314.5645 - val_root_mean_squared_error: 17.4922
# Epoch 30/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.4287 - root_mean_squared_error: 17.9402 - val_loss: 315.5857 - val_root_mean_squared_error: 17.5210
# Epoch 31/60
# 241/241 [==============================] - 11s 44ms/step - loss: 329.7121 - root_mean_squared_error: 17.9212 - val_loss: 315.2244 - val_root_mean_squared_error: 17.5220
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.0113 - root_mean_squared_error: 17.9324 - val_loss: 314.1310 - val_root_mean_squared_error: 17.4882
# Epoch 33/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.8922 - root_mean_squared_error: 17.9361 - val_loss: 315.1204 - val_root_mean_squared_error: 17.5193
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.5801 - root_mean_squared_error: 17.9241 - val_loss: 316.7635 - val_root_mean_squared_error: 17.5633
# Epoch 35/60
# 241/241 [==============================] - 10s 44ms/step - loss: 329.0107 - root_mean_squared_error: 17.9033 - val_loss: 315.9537 - val_root_mean_squared_error: 17.5201
# Epoch 36/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.7280 - root_mean_squared_error: 17.9363 - val_loss: 313.4125 - val_root_mean_squared_error: 17.4793
# Epoch 37/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.3549 - root_mean_squared_error: 17.8927 - val_loss: 313.2231 - val_root_mean_squared_error: 17.4701
# Epoch 38/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.5428 - root_mean_squared_error: 17.9029 - val_loss: 315.3819 - val_root_mean_squared_error: 17.5127
# Epoch 39/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.4184 - root_mean_squared_error: 17.8985 - val_loss: 314.5986 - val_root_mean_squared_error: 17.5133
# Epoch 40/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.8174 - root_mean_squared_error: 17.9188 - val_loss: 313.6800 - val_root_mean_squared_error: 17.4936
# Epoch 41/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.1514 - root_mean_squared_error: 17.9008 - val_loss: 313.0537 - val_root_mean_squared_error: 17.4787
# Epoch 42/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.1151 - root_mean_squared_error: 17.9029 - val_loss: 312.9315 - val_root_mean_squared_error: 17.4719
# Epoch 43/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.1491 - root_mean_squared_error: 17.9014 - val_loss: 316.1238 - val_root_mean_squared_error: 17.5546
# Epoch 44/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.9659 - root_mean_squared_error: 17.8990 - val_loss: 313.6924 - val_root_mean_squared_error: 17.5007
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.6022 - root_mean_squared_error: 17.8873 - val_loss: 312.3308 - val_root_mean_squared_error: 17.4656
# Epoch 46/60
# 241/241 [==============================] - 11s 44ms/step - loss: 326.7022 - root_mean_squared_error: 17.8643 - val_loss: 313.4375 - val_root_mean_squared_error: 17.4975
# Epoch 47/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.2843 - root_mean_squared_error: 17.8846 - val_loss: 313.1650 - val_root_mean_squared_error: 17.4883
# Epoch 48/60
# 241/241 [==============================] - 10s 44ms/step - loss: 327.0624 - root_mean_squared_error: 17.8805 - val_loss: 313.6299 - val_root_mean_squared_error: 17.4926
# Epoch 49/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.0138 - root_mean_squared_error: 17.8504 - val_loss: 312.4235 - val_root_mean_squared_error: 17.4695
# Epoch 50/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.6786 - root_mean_squared_error: 17.8409 - val_loss: 315.3418 - val_root_mean_squared_error: 17.5466
# Epoch 51/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.8062 - root_mean_squared_error: 17.8727 - val_loss: 311.6601 - val_root_mean_squared_error: 17.4522
# Epoch 52/60
# 241/241 [==============================] - 11s 44ms/step - loss: 326.5043 - root_mean_squared_error: 17.8681 - val_loss: 314.6176 - val_root_mean_squared_error: 17.5346
# Epoch 53/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.7079 - root_mean_squared_error: 17.8449 - val_loss: 317.8523 - val_root_mean_squared_error: 17.6033
# Epoch 54/60
# 241/241 [==============================] - 11s 44ms/step - loss: 325.2590 - root_mean_squared_error: 17.8287 - val_loss: 312.8821 - val_root_mean_squared_error: 17.4814
# Epoch 55/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.3952 - root_mean_squared_error: 17.8319 - val_loss: 310.9628 - val_root_mean_squared_error: 17.4305
# Epoch 56/60
# 241/241 [==============================] - 11s 44ms/step - loss: 325.6404 - root_mean_squared_error: 17.8417 - val_loss: 312.7465 - val_root_mean_squared_error: 17.4798
# Epoch 57/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.4169 - root_mean_squared_error: 17.8327 - val_loss: 313.7626 - val_root_mean_squared_error: 17.5086
# Epoch 58/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.1855 - root_mean_squared_error: 17.8287 - val_loss: 312.3877 - val_root_mean_squared_error: 17.4665
# Epoch 59/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.6973 - root_mean_squared_error: 17.7867 - val_loss: 312.0981 - val_root_mean_squared_error: 17.4517
# Epoch 60/60
# 241/241 [==============================] - 11s 44ms/step - loss: 324.1938 - root_mean_squared_error: 17.7944 - val_loss: 313.6702 - val_root_mean_squared_error: 17.4947
# Epoch 1/60
# 241/241 [==============================] - 13s 44ms/step - loss: 740.0964 - root_mean_squared_error: 23.6581 - val_loss: 687.3878 - val_root_mean_squared_error: 24.7722
# Epoch 2/60
# 241/241 [==============================] - 10s 43ms/step - loss: 607.2000 - root_mean_squared_error: 22.1087 - val_loss: 605.1398 - val_root_mean_squared_error: 23.0834
# Epoch 3/60
# 241/241 [==============================] - 10s 43ms/step - loss: 527.9333 - root_mean_squared_error: 20.8751 - val_loss: 593.4785 - val_root_mean_squared_error: 23.4003
# Epoch 4/60
# 241/241 [==============================] - 10s 43ms/step - loss: 469.9914 - root_mean_squared_error: 20.1446 - val_loss: 469.2661 - val_root_mean_squared_error: 20.6752
# Epoch 5/60
# 241/241 [==============================] - 10s 43ms/step - loss: 420.0883 - root_mean_squared_error: 19.2876 - val_loss: 409.8963 - val_root_mean_squared_error: 19.0872
# Epoch 6/60
# 241/241 [==============================] - 10s 43ms/step - loss: 372.7519 - root_mean_squared_error: 18.3561 - val_loss: 367.5166 - val_root_mean_squared_error: 18.3144
# Epoch 7/60
# 241/241 [==============================] - 10s 43ms/step - loss: 354.5382 - root_mean_squared_error: 18.0416 - val_loss: 362.4129 - val_root_mean_squared_error: 18.3024
# Epoch 8/60
# 241/241 [==============================] - 10s 43ms/step - loss: 349.1490 - root_mean_squared_error: 17.9613 - val_loss: 363.5835 - val_root_mean_squared_error: 18.4415
# Epoch 9/60
# 241/241 [==============================] - 11s 44ms/step - loss: 347.1758 - root_mean_squared_error: 17.9859 - val_loss: 357.9942 - val_root_mean_squared_error: 18.3133
# Epoch 10/60
# 241/241 [==============================] - 11s 44ms/step - loss: 341.8976 - root_mean_squared_error: 17.9103 - val_loss: 356.4326 - val_root_mean_squared_error: 18.3468
# Epoch 11/60
# 241/241 [==============================] - 10s 43ms/step - loss: 341.1242 - root_mean_squared_error: 17.9325 - val_loss: 354.9211 - val_root_mean_squared_error: 18.3191
# Epoch 12/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.5113 - root_mean_squared_error: 17.8825 - val_loss: 350.0063 - val_root_mean_squared_error: 18.2636
# Epoch 13/60
# 241/241 [==============================] - 11s 44ms/step - loss: 335.8302 - root_mean_squared_error: 17.8775 - val_loss: 352.7635 - val_root_mean_squared_error: 18.3892
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.4807 - root_mean_squared_error: 17.9025 - val_loss: 347.8147 - val_root_mean_squared_error: 18.2613
# Epoch 15/60
# 241/241 [==============================] - 11s 44ms/step - loss: 333.2790 - root_mean_squared_error: 17.8775 - val_loss: 349.1089 - val_root_mean_squared_error: 18.3384
# Epoch 16/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.3513 - root_mean_squared_error: 17.8491 - val_loss: 347.9393 - val_root_mean_squared_error: 18.3247
# Epoch 17/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.3573 - root_mean_squared_error: 17.8182 - val_loss: 348.3292 - val_root_mean_squared_error: 18.3602
# Epoch 18/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.9116 - root_mean_squared_error: 17.8444 - val_loss: 344.3941 - val_root_mean_squared_error: 18.2619
# Epoch 19/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.6198 - root_mean_squared_error: 17.7923 - val_loss: 347.6817 - val_root_mean_squared_error: 18.3527
# Epoch 20/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.1851 - root_mean_squared_error: 17.8198 - val_loss: 344.1995 - val_root_mean_squared_error: 18.2765
# Epoch 21/60
# 241/241 [==============================] - 11s 44ms/step - loss: 326.6707 - root_mean_squared_error: 17.7858 - val_loss: 343.7296 - val_root_mean_squared_error: 18.2657
# Epoch 22/60
# 241/241 [==============================] - 11s 44ms/step - loss: 326.0659 - root_mean_squared_error: 17.7811 - val_loss: 344.4835 - val_root_mean_squared_error: 18.3092
# Epoch 23/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.8026 - root_mean_squared_error: 17.7863 - val_loss: 344.0157 - val_root_mean_squared_error: 18.3027
# Epoch 24/60
# 241/241 [==============================] - 10s 44ms/step - loss: 325.0854 - root_mean_squared_error: 17.7714 - val_loss: 342.4981 - val_root_mean_squared_error: 18.2608
# Epoch 25/60
# 241/241 [==============================] - 11s 44ms/step - loss: 324.6342 - root_mean_squared_error: 17.7629 - val_loss: 342.9207 - val_root_mean_squared_error: 18.2777
# Epoch 26/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.9684 - root_mean_squared_error: 17.7512 - val_loss: 343.3934 - val_root_mean_squared_error: 18.3076
# Epoch 27/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.5538 - root_mean_squared_error: 17.7503 - val_loss: 341.8435 - val_root_mean_squared_error: 18.2609
# Epoch 28/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.6389 - root_mean_squared_error: 17.7506 - val_loss: 342.3316 - val_root_mean_squared_error: 18.2801
# Epoch 29/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.3061 - root_mean_squared_error: 17.7541 - val_loss: 342.1100 - val_root_mean_squared_error: 18.2718
# Epoch 30/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.9354 - root_mean_squared_error: 17.7400 - val_loss: 340.3384 - val_root_mean_squared_error: 18.2290
# Epoch 31/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.9232 - root_mean_squared_error: 17.7467 - val_loss: 340.7362 - val_root_mean_squared_error: 18.2474
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.6722 - root_mean_squared_error: 17.7450 - val_loss: 340.7807 - val_root_mean_squared_error: 18.2572
# Epoch 33/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.9171 - root_mean_squared_error: 17.7285 - val_loss: 339.9111 - val_root_mean_squared_error: 18.2296
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.3773 - root_mean_squared_error: 17.7424 - val_loss: 340.8387 - val_root_mean_squared_error: 18.2640
# Epoch 35/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.7881 - root_mean_squared_error: 17.7349 - val_loss: 341.0570 - val_root_mean_squared_error: 18.2762
# Epoch 36/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.8347 - root_mean_squared_error: 17.7342 - val_loss: 341.2375 - val_root_mean_squared_error: 18.2804
# Epoch 37/60
# 241/241 [==============================] - 11s 44ms/step - loss: 321.6087 - root_mean_squared_error: 17.7315 - val_loss: 340.4235 - val_root_mean_squared_error: 18.2621
# Epoch 38/60
# 241/241 [==============================] - 11s 44ms/step - loss: 320.9045 - root_mean_squared_error: 17.7127 - val_loss: 340.3068 - val_root_mean_squared_error: 18.2587
# Epoch 39/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.1971 - root_mean_squared_error: 17.7257 - val_loss: 339.6830 - val_root_mean_squared_error: 18.2418
# Epoch 40/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.7916 - root_mean_squared_error: 17.7114 - val_loss: 340.4047 - val_root_mean_squared_error: 18.2572
# Epoch 41/60
# 241/241 [==============================] - 10s 43ms/step - loss: 319.8535 - root_mean_squared_error: 17.6838 - val_loss: 338.4221 - val_root_mean_squared_error: 18.1972
# Epoch 42/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.9793 - root_mean_squared_error: 17.7142 - val_loss: 340.1810 - val_root_mean_squared_error: 18.2523
# Epoch 43/60
# 241/241 [==============================] - 11s 44ms/step - loss: 320.8688 - root_mean_squared_error: 17.7153 - val_loss: 338.6118 - val_root_mean_squared_error: 18.2128
# Epoch 44/60
# 241/241 [==============================] - 11s 44ms/step - loss: 320.1452 - root_mean_squared_error: 17.6958 - val_loss: 339.2935 - val_root_mean_squared_error: 18.2298
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 319.7001 - root_mean_squared_error: 17.6808 - val_loss: 340.9432 - val_root_mean_squared_error: 18.2695
# Epoch 46/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.2293 - root_mean_squared_error: 17.6971 - val_loss: 339.5710 - val_root_mean_squared_error: 18.2392
# Epoch 47/60
# 241/241 [==============================] - 11s 44ms/step - loss: 319.7313 - root_mean_squared_error: 17.6844 - val_loss: 339.6910 - val_root_mean_squared_error: 18.2420
# Epoch 48/60
# 241/241 [==============================] - 11s 44ms/step - loss: 319.2272 - root_mean_squared_error: 17.6663 - val_loss: 338.3099 - val_root_mean_squared_error: 18.2004
# Epoch 49/60
# 241/241 [==============================] - 10s 43ms/step - loss: 319.2791 - root_mean_squared_error: 17.6679 - val_loss: 339.9294 - val_root_mean_squared_error: 18.2450
# Epoch 50/60
# 241/241 [==============================] - 11s 44ms/step - loss: 319.6182 - root_mean_squared_error: 17.6813 - val_loss: 339.7208 - val_root_mean_squared_error: 18.2396
# Epoch 51/60
# 241/241 [==============================] - 11s 44ms/step - loss: 318.9688 - root_mean_squared_error: 17.6603 - val_loss: 340.1271 - val_root_mean_squared_error: 18.2456
# Epoch 52/60
# 241/241 [==============================] - 11s 44ms/step - loss: 319.2432 - root_mean_squared_error: 17.6683 - val_loss: 343.5177 - val_root_mean_squared_error: 18.3367
# Epoch 53/60
# 241/241 [==============================] - 10s 43ms/step - loss: 319.1151 - root_mean_squared_error: 17.6669 - val_loss: 339.6362 - val_root_mean_squared_error: 18.2342
# Epoch 54/60
# 241/241 [==============================] - 11s 44ms/step - loss: 318.9390 - root_mean_squared_error: 17.6577 - val_loss: 339.5414 - val_root_mean_squared_error: 18.2365
# Epoch 55/60
# 241/241 [==============================] - 10s 43ms/step - loss: 318.9830 - root_mean_squared_error: 17.6571 - val_loss: 338.3996 - val_root_mean_squared_error: 18.2037
# Epoch 56/60
# 241/241 [==============================] - 10s 44ms/step - loss: 317.6284 - root_mean_squared_error: 17.6214 - val_loss: 338.4048 - val_root_mean_squared_error: 18.1998
# Epoch 57/60
# 241/241 [==============================] - 11s 44ms/step - loss: 317.1315 - root_mean_squared_error: 17.6042 - val_loss: 340.8941 - val_root_mean_squared_error: 18.2670
# Epoch 58/60
# 241/241 [==============================] - 10s 43ms/step - loss: 319.4967 - root_mean_squared_error: 17.6694 - val_loss: 339.2769 - val_root_mean_squared_error: 18.2236
# Epoch 59/60
# 241/241 [==============================] - 11s 44ms/step - loss: 317.2717 - root_mean_squared_error: 17.6054 - val_loss: 338.3256 - val_root_mean_squared_error: 18.1962
# Epoch 60/60
# 241/241 [==============================] - 11s 44ms/step - loss: 317.7006 - root_mean_squared_error: 17.6206 - val_loss: 339.5031 - val_root_mean_squared_error: 18.2300
# Epoch 1/60
# 241/241 [==============================] - 13s 45ms/step - loss: 732.0230 - root_mean_squared_error: 23.4308 - val_loss: 824.9543 - val_root_mean_squared_error: 27.7402
# Epoch 2/60
# 241/241 [==============================] - 11s 44ms/step - loss: 601.2873 - root_mean_squared_error: 21.9562 - val_loss: 679.7325 - val_root_mean_squared_error: 24.9823
# Epoch 3/60
# 241/241 [==============================] - 10s 43ms/step - loss: 526.9630 - root_mean_squared_error: 20.9583 - val_loss: 529.4223 - val_root_mean_squared_error: 21.6504
# Epoch 4/60
# 241/241 [==============================] - 11s 44ms/step - loss: 468.8430 - root_mean_squared_error: 20.0841 - val_loss: 485.8172 - val_root_mean_squared_error: 21.0960
# Epoch 5/60
# 241/241 [==============================] - 11s 44ms/step - loss: 414.3148 - root_mean_squared_error: 19.1648 - val_loss: 403.8785 - val_root_mean_squared_error: 19.2868
# Epoch 6/60
# 241/241 [==============================] - 11s 44ms/step - loss: 372.4228 - root_mean_squared_error: 18.3885 - val_loss: 367.5174 - val_root_mean_squared_error: 18.3186
# Epoch 7/60
# 241/241 [==============================] - 11s 44ms/step - loss: 355.4624 - root_mean_squared_error: 18.0458 - val_loss: 363.0718 - val_root_mean_squared_error: 18.3514
# Epoch 8/60
# 241/241 [==============================] - 11s 44ms/step - loss: 352.7118 - root_mean_squared_error: 18.0643 - val_loss: 359.1952 - val_root_mean_squared_error: 18.2557
# Epoch 9/60
# 241/241 [==============================] - 11s 44ms/step - loss: 347.7661 - root_mean_squared_error: 17.9943 - val_loss: 356.9619 - val_root_mean_squared_error: 18.3244
# Epoch 10/60
# 241/241 [==============================] - 11s 44ms/step - loss: 342.0826 - root_mean_squared_error: 17.9165 - val_loss: 355.4057 - val_root_mean_squared_error: 18.3360
# Epoch 11/60
# 241/241 [==============================] - 11s 44ms/step - loss: 341.5515 - root_mean_squared_error: 17.9562 - val_loss: 348.5847 - val_root_mean_squared_error: 18.1720
# Epoch 12/60
# 241/241 [==============================] - 11s 44ms/step - loss: 339.2693 - root_mean_squared_error: 17.9464 - val_loss: 345.7632 - val_root_mean_squared_error: 18.1543
# Epoch 13/60
# 241/241 [==============================] - 11s 44ms/step - loss: 336.8587 - root_mean_squared_error: 17.9237 - val_loss: 350.0632 - val_root_mean_squared_error: 18.3407
# Epoch 14/60
# 241/241 [==============================] - 11s 45ms/step - loss: 333.6744 - root_mean_squared_error: 17.8687 - val_loss: 343.7925 - val_root_mean_squared_error: 18.1679
# Epoch 15/60
# 241/241 [==============================] - 11s 44ms/step - loss: 331.9462 - root_mean_squared_error: 17.8484 - val_loss: 342.5382 - val_root_mean_squared_error: 18.1626
# Epoch 16/60
# 241/241 [==============================] - 11s 44ms/step - loss: 330.4792 - root_mean_squared_error: 17.8333 - val_loss: 346.3250 - val_root_mean_squared_error: 18.2788
# Epoch 17/60
# 241/241 [==============================] - 11s 44ms/step - loss: 329.7480 - root_mean_squared_error: 17.8407 - val_loss: 340.6155 - val_root_mean_squared_error: 18.1552
# Epoch 18/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.1820 - root_mean_squared_error: 17.8413 - val_loss: 342.5880 - val_root_mean_squared_error: 18.2296
# Epoch 19/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.2581 - root_mean_squared_error: 17.8322 - val_loss: 339.3484 - val_root_mean_squared_error: 18.1467
# Epoch 20/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.1076 - root_mean_squared_error: 17.8113 - val_loss: 342.3761 - val_root_mean_squared_error: 18.2476
# Epoch 21/60
# 241/241 [==============================] - 11s 44ms/step - loss: 325.9566 - root_mean_squared_error: 17.7875 - val_loss: 338.4429 - val_root_mean_squared_error: 18.1371
# Epoch 22/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.1191 - root_mean_squared_error: 17.8012 - val_loss: 337.7489 - val_root_mean_squared_error: 18.1226
# Epoch 23/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.2701 - root_mean_squared_error: 17.8394 - val_loss: 337.5756 - val_root_mean_squared_error: 18.1238
# Epoch 24/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.9081 - root_mean_squared_error: 17.7795 - val_loss: 338.6133 - val_root_mean_squared_error: 18.1655
# Epoch 25/60
# 241/241 [==============================] - 11s 46ms/step - loss: 325.3854 - root_mean_squared_error: 17.7969 - val_loss: 337.9914 - val_root_mean_squared_error: 18.1542
# Epoch 26/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.8385 - root_mean_squared_error: 17.7899 - val_loss: 339.1165 - val_root_mean_squared_error: 18.1969
# Epoch 27/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.6529 - root_mean_squared_error: 17.7862 - val_loss: 336.4764 - val_root_mean_squared_error: 18.1208
# Epoch 28/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.9008 - root_mean_squared_error: 17.7700 - val_loss: 340.8495 - val_root_mean_squared_error: 18.2379
# Epoch 29/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.3107 - root_mean_squared_error: 17.7880 - val_loss: 336.9871 - val_root_mean_squared_error: 18.1470
# Epoch 30/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.3173 - root_mean_squared_error: 17.7614 - val_loss: 337.2915 - val_root_mean_squared_error: 18.1505
# Epoch 31/60
# 241/241 [==============================] - 11s 44ms/step - loss: 323.4873 - root_mean_squared_error: 17.7729 - val_loss: 337.6316 - val_root_mean_squared_error: 18.1741
# Epoch 32/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.6938 - root_mean_squared_error: 17.7553 - val_loss: 337.1345 - val_root_mean_squared_error: 18.1657
# Epoch 33/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.9589 - root_mean_squared_error: 17.7645 - val_loss: 337.6572 - val_root_mean_squared_error: 18.1782
# Epoch 34/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.7993 - root_mean_squared_error: 17.7635 - val_loss: 337.4612 - val_root_mean_squared_error: 18.1818
# Epoch 35/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.7859 - root_mean_squared_error: 17.7680 - val_loss: 336.3372 - val_root_mean_squared_error: 18.1469
# Epoch 36/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.9139 - root_mean_squared_error: 17.7433 - val_loss: 335.6717 - val_root_mean_squared_error: 18.1312
# Epoch 37/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.2660 - root_mean_squared_error: 17.7242 - val_loss: 335.2214 - val_root_mean_squared_error: 18.1182
# Epoch 38/60
# 241/241 [==============================] - 11s 44ms/step - loss: 322.3078 - root_mean_squared_error: 17.7576 - val_loss: 334.9534 - val_root_mean_squared_error: 18.1148
# Epoch 39/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.2691 - root_mean_squared_error: 17.7617 - val_loss: 335.7424 - val_root_mean_squared_error: 18.1432
# Epoch 40/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.5166 - root_mean_squared_error: 17.7447 - val_loss: 335.3204 - val_root_mean_squared_error: 18.1272
# Epoch 41/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.5517 - root_mean_squared_error: 17.7463 - val_loss: 337.6342 - val_root_mean_squared_error: 18.1898
# Epoch 42/60
# 241/241 [==============================] - 11s 44ms/step - loss: 321.8332 - root_mean_squared_error: 17.7549 - val_loss: 335.5872 - val_root_mean_squared_error: 18.1375
# Epoch 43/60
# 241/241 [==============================] - 11s 44ms/step - loss: 321.1964 - root_mean_squared_error: 17.7385 - val_loss: 334.9816 - val_root_mean_squared_error: 18.1272
# Epoch 44/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.3116 - root_mean_squared_error: 17.7427 - val_loss: 340.2493 - val_root_mean_squared_error: 18.2629
# Epoch 45/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.8313 - root_mean_squared_error: 17.7333 - val_loss: 337.1883 - val_root_mean_squared_error: 18.1830
# Epoch 46/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.3468 - root_mean_squared_error: 17.7479 - val_loss: 335.5078 - val_root_mean_squared_error: 18.1418
# Epoch 47/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.5213 - root_mean_squared_error: 17.7220 - val_loss: 335.7423 - val_root_mean_squared_error: 18.1513
# Epoch 48/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.4906 - root_mean_squared_error: 17.6963 - val_loss: 335.9539 - val_root_mean_squared_error: 18.1546
# Epoch 49/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.8068 - root_mean_squared_error: 17.7338 - val_loss: 334.1676 - val_root_mean_squared_error: 18.1097
# Epoch 50/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.8494 - root_mean_squared_error: 17.7377 - val_loss: 334.4597 - val_root_mean_squared_error: 18.1179
# Epoch 51/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.4678 - root_mean_squared_error: 17.7262 - val_loss: 335.0598 - val_root_mean_squared_error: 18.1363
# Epoch 52/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.1086 - root_mean_squared_error: 17.7187 - val_loss: 334.2520 - val_root_mean_squared_error: 18.1154
# Epoch 53/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.0521 - root_mean_squared_error: 17.7181 - val_loss: 337.4514 - val_root_mean_squared_error: 18.1964
# Epoch 54/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.4244 - root_mean_squared_error: 17.6982 - val_loss: 337.4582 - val_root_mean_squared_error: 18.1974
# Epoch 55/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.8092 - root_mean_squared_error: 17.7080 - val_loss: 335.5468 - val_root_mean_squared_error: 18.1492
# Epoch 56/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.2975 - root_mean_squared_error: 17.7249 - val_loss: 334.8106 - val_root_mean_squared_error: 18.1320
# Epoch 57/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.8515 - root_mean_squared_error: 17.7137 - val_loss: 334.7062 - val_root_mean_squared_error: 18.1285
# Epoch 58/60
# 241/241 [==============================] - 11s 44ms/step - loss: 319.4808 - root_mean_squared_error: 17.7005 - val_loss: 335.6086 - val_root_mean_squared_error: 18.1568
# Epoch 59/60
# 241/241 [==============================] - 11s 45ms/step - loss: 318.8823 - root_mean_squared_error: 17.6866 - val_loss: 333.6957 - val_root_mean_squared_error: 18.0994
# Epoch 60/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.6544 - root_mean_squared_error: 17.7079 - val_loss: 333.2414 - val_root_mean_squared_error: 18.0898
# Epoch 1/60
# 241/241 [==============================] - 13s 46ms/step - loss: 765.2084 - root_mean_squared_error: 23.8738 - val_loss: 636.0511 - val_root_mean_squared_error: 23.8236
# Epoch 2/60
# 241/241 [==============================] - 11s 44ms/step - loss: 599.6714 - root_mean_squared_error: 21.9183 - val_loss: 561.1862 - val_root_mean_squared_error: 22.3240
# Epoch 3/60
# 241/241 [==============================] - 11s 44ms/step - loss: 528.1817 - root_mean_squared_error: 21.0118 - val_loss: 475.2079 - val_root_mean_squared_error: 20.3404
# Epoch 4/60
# 241/241 [==============================] - 11s 44ms/step - loss: 469.1889 - root_mean_squared_error: 20.1192 - val_loss: 456.8344 - val_root_mean_squared_error: 20.4352
# Epoch 5/60
# 241/241 [==============================] - 11s 45ms/step - loss: 418.2985 - root_mean_squared_error: 19.2956 - val_loss: 377.1823 - val_root_mean_squared_error: 18.5979
# Epoch 6/60
# 241/241 [==============================] - 11s 45ms/step - loss: 377.1317 - root_mean_squared_error: 18.5036 - val_loss: 345.7090 - val_root_mean_squared_error: 17.7544
# Epoch 7/60
# 241/241 [==============================] - 11s 45ms/step - loss: 360.4987 - root_mean_squared_error: 18.1993 - val_loss: 340.9941 - val_root_mean_squared_error: 17.7498
# Epoch 8/60
# 241/241 [==============================] - 11s 45ms/step - loss: 355.2191 - root_mean_squared_error: 18.1551 - val_loss: 337.9324 - val_root_mean_squared_error: 17.7032
# Epoch 9/60
# 241/241 [==============================] - 11s 44ms/step - loss: 352.6603 - root_mean_squared_error: 18.1422 - val_loss: 336.0384 - val_root_mean_squared_error: 17.7212
# Epoch 10/60
# 241/241 [==============================] - 11s 44ms/step - loss: 352.4671 - root_mean_squared_error: 18.1674 - val_loss: 334.7819 - val_root_mean_squared_error: 17.7202
# Epoch 11/60
# 241/241 [==============================] - 11s 45ms/step - loss: 348.3429 - root_mean_squared_error: 18.1059 - val_loss: 334.8491 - val_root_mean_squared_error: 17.7427
# Epoch 12/60
# 241/241 [==============================] - 11s 45ms/step - loss: 346.5681 - root_mean_squared_error: 18.0926 - val_loss: 330.9217 - val_root_mean_squared_error: 17.6959
# Epoch 13/60
# 241/241 [==============================] - 11s 46ms/step - loss: 345.1526 - root_mean_squared_error: 18.1122 - val_loss: 330.6178 - val_root_mean_squared_error: 17.7475
# Epoch 14/60
# 241/241 [==============================] - 11s 45ms/step - loss: 342.3066 - root_mean_squared_error: 18.0529 - val_loss: 328.4803 - val_root_mean_squared_error: 17.6734
# Epoch 15/60
# 241/241 [==============================] - 11s 45ms/step - loss: 340.4929 - root_mean_squared_error: 18.0270 - val_loss: 328.3044 - val_root_mean_squared_error: 17.7253
# Epoch 16/60
# 241/241 [==============================] - 11s 46ms/step - loss: 337.7207 - root_mean_squared_error: 17.9737 - val_loss: 329.1253 - val_root_mean_squared_error: 17.7472
# Epoch 17/60
# 241/241 [==============================] - 11s 46ms/step - loss: 338.2704 - root_mean_squared_error: 18.0231 - val_loss: 325.6164 - val_root_mean_squared_error: 17.6965
# Epoch 18/60
# 241/241 [==============================] - 11s 46ms/step - loss: 335.5825 - root_mean_squared_error: 17.9812 - val_loss: 324.3824 - val_root_mean_squared_error: 17.6909
# Epoch 19/60
# 241/241 [==============================] - 11s 45ms/step - loss: 334.4840 - root_mean_squared_error: 17.9768 - val_loss: 325.8020 - val_root_mean_squared_error: 17.7385
# Epoch 20/60
# 241/241 [==============================] - 11s 46ms/step - loss: 332.9271 - root_mean_squared_error: 17.9537 - val_loss: 325.3728 - val_root_mean_squared_error: 17.7492
# Epoch 21/60
# 241/241 [==============================] - 11s 45ms/step - loss: 331.2692 - root_mean_squared_error: 17.9271 - val_loss: 322.6959 - val_root_mean_squared_error: 17.6954
# Epoch 22/60
# 241/241 [==============================] - 11s 45ms/step - loss: 331.5751 - root_mean_squared_error: 17.9409 - val_loss: 322.6747 - val_root_mean_squared_error: 17.6972
# Epoch 23/60
# 241/241 [==============================] - 11s 45ms/step - loss: 331.5720 - root_mean_squared_error: 17.9516 - val_loss: 323.0282 - val_root_mean_squared_error: 17.7134
# Epoch 24/60
# 241/241 [==============================] - 11s 45ms/step - loss: 330.4642 - root_mean_squared_error: 17.9259 - val_loss: 322.0747 - val_root_mean_squared_error: 17.6998
# Epoch 25/60
# 241/241 [==============================] - 11s 45ms/step - loss: 330.1509 - root_mean_squared_error: 17.9166 - val_loss: 321.9969 - val_root_mean_squared_error: 17.6957
# Epoch 26/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.9187 - root_mean_squared_error: 17.9174 - val_loss: 322.5806 - val_root_mean_squared_error: 17.7106
# Epoch 27/60
# 241/241 [==============================] - 11s 46ms/step - loss: 329.7578 - root_mean_squared_error: 17.9164 - val_loss: 321.1140 - val_root_mean_squared_error: 17.6860
# Epoch 28/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.9944 - root_mean_squared_error: 17.9062 - val_loss: 323.7370 - val_root_mean_squared_error: 17.7610
# Epoch 29/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.7207 - root_mean_squared_error: 17.9048 - val_loss: 321.7342 - val_root_mean_squared_error: 17.7149
# Epoch 30/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.1180 - root_mean_squared_error: 17.8924 - val_loss: 320.8432 - val_root_mean_squared_error: 17.6948
# Epoch 31/60
# 241/241 [==============================] - 11s 46ms/step - loss: 328.0604 - root_mean_squared_error: 17.8925 - val_loss: 321.3973 - val_root_mean_squared_error: 17.7148
# Epoch 32/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.0045 - root_mean_squared_error: 17.8954 - val_loss: 320.3883 - val_root_mean_squared_error: 17.6930
# Epoch 33/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.2825 - root_mean_squared_error: 17.8903 - val_loss: 320.4880 - val_root_mean_squared_error: 17.6985
# Epoch 34/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.1292 - root_mean_squared_error: 17.8838 - val_loss: 321.2842 - val_root_mean_squared_error: 17.7201
# Epoch 35/60
# 241/241 [==============================] - 11s 46ms/step - loss: 327.1225 - root_mean_squared_error: 17.8850 - val_loss: 319.8276 - val_root_mean_squared_error: 17.6883
# Epoch 36/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.5798 - root_mean_squared_error: 17.8708 - val_loss: 319.8888 - val_root_mean_squared_error: 17.6788
# Epoch 37/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.3640 - root_mean_squared_error: 17.8636 - val_loss: 319.6139 - val_root_mean_squared_error: 17.6779
# Epoch 38/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.9567 - root_mean_squared_error: 17.8794 - val_loss: 321.0800 - val_root_mean_squared_error: 17.7174
# Epoch 39/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.1833 - root_mean_squared_error: 17.8574 - val_loss: 319.5288 - val_root_mean_squared_error: 17.6714
# Epoch 40/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.4420 - root_mean_squared_error: 17.8675 - val_loss: 319.8757 - val_root_mean_squared_error: 17.6865
# Epoch 41/60
# 241/241 [==============================] - 11s 46ms/step - loss: 326.2371 - root_mean_squared_error: 17.8661 - val_loss: 319.5710 - val_root_mean_squared_error: 17.6802
# Epoch 42/60
# 241/241 [==============================] - 11s 46ms/step - loss: 325.2387 - root_mean_squared_error: 17.8359 - val_loss: 321.7784 - val_root_mean_squared_error: 17.7355
# Epoch 43/60
# 241/241 [==============================] - 11s 46ms/step - loss: 325.5715 - root_mean_squared_error: 17.8430 - val_loss: 319.5869 - val_root_mean_squared_error: 17.6785
# Epoch 44/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.7128 - root_mean_squared_error: 17.8479 - val_loss: 319.7056 - val_root_mean_squared_error: 17.6837
# Epoch 45/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.8576 - root_mean_squared_error: 17.8297 - val_loss: 320.6853 - val_root_mean_squared_error: 17.7142
# Epoch 46/60
# 241/241 [==============================] - 11s 47ms/step - loss: 324.8579 - root_mean_squared_error: 17.8273 - val_loss: 318.3485 - val_root_mean_squared_error: 17.6496
# Epoch 47/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.9785 - root_mean_squared_error: 17.7996 - val_loss: 322.3604 - val_root_mean_squared_error: 17.7573
# Epoch 48/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.6442 - root_mean_squared_error: 17.8194 - val_loss: 318.9485 - val_root_mean_squared_error: 17.6642
# Epoch 49/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.9213 - root_mean_squared_error: 17.8284 - val_loss: 320.7052 - val_root_mean_squared_error: 17.7026
# Epoch 50/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.0126 - root_mean_squared_error: 17.7998 - val_loss: 321.0704 - val_root_mean_squared_error: 17.7238
# Epoch 51/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.7241 - root_mean_squared_error: 17.7935 - val_loss: 320.2348 - val_root_mean_squared_error: 17.6921
# Epoch 52/60
# 241/241 [==============================] - 11s 46ms/step - loss: 324.0550 - root_mean_squared_error: 17.7987 - val_loss: 318.9103 - val_root_mean_squared_error: 17.6560
# Epoch 53/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.7920 - root_mean_squared_error: 17.7901 - val_loss: 320.0175 - val_root_mean_squared_error: 17.6890
# Epoch 54/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.6104 - root_mean_squared_error: 17.7861 - val_loss: 321.7509 - val_root_mean_squared_error: 17.7395
# Epoch 55/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.4266 - root_mean_squared_error: 17.7820 - val_loss: 320.2552 - val_root_mean_squared_error: 17.6981
# Epoch 56/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.8927 - root_mean_squared_error: 17.7662 - val_loss: 319.7581 - val_root_mean_squared_error: 17.6798
# Epoch 57/60
# 241/241 [==============================] - 11s 46ms/step - loss: 322.1594 - root_mean_squared_error: 17.7415 - val_loss: 320.0857 - val_root_mean_squared_error: 17.6827
# Epoch 58/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.6284 - root_mean_squared_error: 17.7283 - val_loss: 322.3448 - val_root_mean_squared_error: 17.7519
# Epoch 59/60
# 241/241 [==============================] - 11s 46ms/step - loss: 321.5152 - root_mean_squared_error: 17.7222 - val_loss: 319.3865 - val_root_mean_squared_error: 17.6597
# Epoch 60/60
# 241/241 [==============================] - 11s 46ms/step - loss: 321.5476 - root_mean_squared_error: 17.7220 - val_loss: 322.0755 - val_root_mean_squared_error: 17.7398
# The train MSE is 321.5367492675781
# The train RMSE is 17.7311767578125
# The validation MSE is 325.880712890625
# The validation RMSE is 17.852675247192384

# %%
# Create overview of layers in model
tabular_NN = build_neural_net(12, hidden_nodes=20)
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size, hidden_nodes=100)
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=40)

tf.keras.utils.plot_model(concat_model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')
