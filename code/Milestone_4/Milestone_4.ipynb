# %% [markdown]
# # Data augmentation with removed outliers using k-fold cross-validation
# In this chapter we will combine data augmentation methods and removing outliers and use k-fold cross-validation to see if the model improves and does not overfit.

# %%
import zipfile
import os
import cv2
import pandas as pd
from os import chdir, listdir

import matplotlib.pyplot as plt
import numpy as np
import random

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing, regularizers
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from keras import backend as K
from keras import activations

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-26 12:43:54--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-26 12:43:55--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [            <=>     ] 993.57M  22.7MB/s    in 44s
#
# 2022-01-26 12:44:39 (22.7 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1041838077]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# Create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis. After the images are imported, the images and their names are shuffled. This is done, so we can later take a validation sample containing a random subsample of the dataset. It could be that the images in the dataset contain some order, so by shuffling we ensure that the subset for the validation data is random.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])

        # Reset the index of the dataframe
        data_sorted = data_sorted.reset_index().drop(['index'],axis=1)
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

# %% [markdown]
# # Processing data
# The tabular data is split in x and y values and converted to numpy arrays, so the neural network can handle the data. Moreover, the image data is converted to numpy arrays.

# %%
# Remove samples with pawpularity score of 100
indexNames = train_data_sorted[train_data_sorted['Pawpularity'] == 100].index
train_data_new = train_data_sorted.drop(indexNames)
train_imgs_new = np.delete(train_imgs, indexNames, axis=0)

# %%
# Select x-values (the 12 input features) and y-values from training data
x_tabular = train_data_new.iloc[:,1:13].to_numpy()
y = train_data_new.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# Create numpy array of image data 
x_images = np.array(train_imgs_new)
test_imgs_array = np.array(test_imgs)

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create hidden layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation='relu', input_shape=(input_size,)))    

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    return model

# Create neural network for tabular data and get summary of model 
# with 12 inputs and 100 hidden nodes
tabular_NN = build_neural_net(12, hidden_nodes=20)

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=image_size, padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))

    # Create a dense layer with relu activations
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))
    
    return model

# %%
# Create neural network for image data and get summary of model
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size, hidden_nodes=100)

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
def linear_limit(x):
    """
    Create a linear activation function that clips the output at 0 and 100.
    """
    activation_x = activations.linear(x)
    activation_x_new = K.clip(activation_x, 0, 100)

    return activation_x_new

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layer with relu activation
    hidden_layer_1 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(concat_input)

    # Create hidden layer with relu activation
    drop_out_1 = layers.Dropout(0.4)(hidden_layer_1)    
    hidden_layer_2 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_1)

    # Create hidden layer with relu activation
    drop_out_2 = layers.Dropout(0.4)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_2)

    # Create output layer
    output_layer = layers.Dense(1, activation=linear_limit)(hidden_layer_3)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
# Part of code from: https://www.tensorflow.org/tutorials/keras/regression

def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
    """
    This function trains and evaluated a model. It first compiles the model with 
    the loss and metrics. It then makes a train and validation generator for the 
    image data, based on the preprocess and augment input. 
    It then trains the model on both the image and tabular data for epochs times. 
    The values of the loss and metric are plotted and printed.
    """
    # Compile model and use mean squared error as loss and root mean squared error as metric
    model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

    # Preprocess the image data
    train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
    train_gen.fit(image_x)

    val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
    val_gen.fit(image_x)

    # Train the model by fitting both tabular and image data at the same time
    history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs = epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

    return history

# %%
from sklearn.model_selection import KFold

def k_fold(num_folds, x_tabular, y, x_imgs, epochs=20, preprocess={}, augment={}):
    """
    Train and evaluate the data for num-folds times, and return the average 
    training and validation loss. First the data is split in num-folds batches
    and then the model is trained on the data, where a different batch is the 
    validation data each time.
    """
    # Create kfold object to later split the data
    kfold = KFold(n_splits=num_folds, shuffle=True)
    x_indices = np.array(range(len(x_tabular)))
    y_indices = np.array(range(len(y)))

    # Pre allocate variables to store the MSE (loss) and RMSE (accuracy)
    train_loss = np.array(np.zeros(epochs))
    train_acc = np.array(np.zeros(epochs))
    val_loss = np.array(np.zeros(epochs))
    val_acc = np.array(np.zeros(epochs))
    
    # Train and evaluate the model for num-fold times on a different training 
    # and validation set each time
    for id_train, id_val in kfold.split(x_indices, y_indices):
        
        # Make Neural Networks before concatenation
        tabular_NN = build_neural_net(12, hidden_nodes=20)
        image_size = (64, 64, 3)
        image_NN = build_convol_net(image_size, hidden_nodes=20)

        # Create subset training and validation data
        x_tabular_train = x_tabular[id_train]
        x_imgs_train = x_imgs[id_train]
        y_train = y[id_train]
        
        x_tabular_val = x_tabular[id_val]
        x_imgs_val = x_imgs[id_val]
        y_val_2 = y[id_val]
        
        # Train and evaluate the model
        concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=40)
        history = train_and_evaluate(concat_model, x_imgs_train, x_tabular_train, 
                           y_train, x_tabular_val, x_imgs_val, y_val_2, epochs=epochs, preprocess=preprocess, augment=augment)

        # Add all the losses and metrics
        train_loss += history.history['loss']
        train_acc += history.history['root_mean_squared_error']
        val_loss += history.history['val_loss']
        val_acc += history.history['val_root_mean_squared_error']

    # Calculate average loss and metric
    avg_train_loss = train_loss / num_folds
    avg_val_loss = val_loss / num_folds
    avg_train_acc = train_acc / num_folds
    avg_val_acc = val_acc / num_folds

    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    # Plot MSE
    axs[0].plot(avg_train_loss)
    axs[0].plot(avg_val_loss)
    axs[0].legend(['training', 'validation'], loc='best')
    
    axs[0].set_title('Model MSE')
    axs[0].set_ylabel('MSE')
    axs[0].set_xlabel('epoch')
    axs[0].set_ylim([0, 1000])

    # Plot RMSE
    axs[1].plot(avg_train_acc)
    axs[1].plot(avg_val_acc)
    axs[1].legend(['training', 'validation'], loc='best')
    
    axs[1].set_title('Model RMSE')
    axs[1].set_ylabel('RMSE')
    axs[1].set_xlabel('epoch')
    axs[1].set_ylim([0, 30])

    plt.show()

    return avg_train_loss[-1], avg_val_loss[-1], avg_train_acc[-1], avg_val_acc[-1]

# Use k-fold cross-validation to train and evaluate concatenated network
avg_train_loss, avg_val_loss, avg_train_acc, avg_val_acc = k_fold(5, x_tabular, y, x_images, epochs=60, 
                                               preprocess={'featurewise_center': True, 'featurewise_std_normalization': True},
                                               augment={'rotation_range': 90, 'horizontal_flip': True, 'shear_range': 0.2})

print(f'The train MSE is {avg_train_loss}')
print(f'The train RMSE is {avg_train_acc}')
print(f'The validation MSE is {avg_val_loss}')
print(f'The validation RMSE is {avg_val_acc}')
# Out:
# Epoch 1/60
# 241/241 [==============================] - 29s 68ms/step - loss: 773.3008 - root_mean_squared_error: 24.6375 - val_loss: 655.4434 - val_root_mean_squared_error: 24.5340
# Epoch 2/60
# 241/241 [==============================] - 15s 64ms/step - loss: 561.2188 - root_mean_squared_error: 21.5692 - val_loss: 524.3659 - val_root_mean_squared_error: 21.7766
# Epoch 3/60
# 241/241 [==============================] - 16s 65ms/step - loss: 494.0671 - root_mean_squared_error: 20.6723 - val_loss: 472.8614 - val_root_mean_squared_error: 20.7850
# Epoch 4/60
# 241/241 [==============================] - 16s 67ms/step - loss: 436.6965 - root_mean_squared_error: 19.6990 - val_loss: 439.3450 - val_root_mean_squared_error: 20.2352
# Epoch 5/60
# 241/241 [==============================] - 16s 66ms/step - loss: 393.5229 - root_mean_squared_error: 18.9045 - val_loss: 380.3549 - val_root_mean_squared_error: 18.8267
# Epoch 6/60
# 241/241 [==============================] - 16s 66ms/step - loss: 367.6428 - root_mean_squared_error: 18.4115 - val_loss: 360.8420 - val_root_mean_squared_error: 18.3489
# Epoch 7/60
# 241/241 [==============================] - 16s 66ms/step - loss: 352.8603 - root_mean_squared_error: 18.1308 - val_loss: 360.1982 - val_root_mean_squared_error: 18.4117
# Epoch 8/60
# 241/241 [==============================] - 16s 65ms/step - loss: 348.5318 - root_mean_squared_error: 18.0746 - val_loss: 355.4231 - val_root_mean_squared_error: 18.2908
# Epoch 9/60
# 241/241 [==============================] - 16s 66ms/step - loss: 344.1873 - root_mean_squared_error: 18.0128 - val_loss: 351.2329 - val_root_mean_squared_error: 18.2326
# Epoch 10/60
# 241/241 [==============================] - 16s 67ms/step - loss: 341.5389 - root_mean_squared_error: 17.9798 - val_loss: 354.8223 - val_root_mean_squared_error: 18.3281
# Epoch 11/60
# 241/241 [==============================] - 16s 66ms/step - loss: 337.8463 - root_mean_squared_error: 17.9146 - val_loss: 349.0496 - val_root_mean_squared_error: 18.2249
# Epoch 12/60
# 241/241 [==============================] - 16s 66ms/step - loss: 337.8934 - root_mean_squared_error: 17.9364 - val_loss: 352.5660 - val_root_mean_squared_error: 18.3785
# Epoch 13/60
# 241/241 [==============================] - 16s 67ms/step - loss: 336.7716 - root_mean_squared_error: 17.9354 - val_loss: 347.8747 - val_root_mean_squared_error: 18.2581
# Epoch 14/60
# 241/241 [==============================] - 16s 66ms/step - loss: 334.0537 - root_mean_squared_error: 17.8873 - val_loss: 349.1749 - val_root_mean_squared_error: 18.3408
# Epoch 15/60
# 241/241 [==============================] - 16s 66ms/step - loss: 332.6451 - root_mean_squared_error: 17.8712 - val_loss: 344.5877 - val_root_mean_squared_error: 18.2253
# Epoch 16/60
# 241/241 [==============================] - 16s 67ms/step - loss: 331.8471 - root_mean_squared_error: 17.8744 - val_loss: 345.0508 - val_root_mean_squared_error: 18.2536
# Epoch 17/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.1818 - root_mean_squared_error: 17.8144 - val_loss: 357.5326 - val_root_mean_squared_error: 18.5627
# Epoch 18/60
# 241/241 [==============================] - 16s 65ms/step - loss: 328.8488 - root_mean_squared_error: 17.8172 - val_loss: 343.2427 - val_root_mean_squared_error: 18.2309
# Epoch 19/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.0916 - root_mean_squared_error: 17.8399 - val_loss: 343.0909 - val_root_mean_squared_error: 18.2274
# Epoch 20/60
# 241/241 [==============================] - 16s 67ms/step - loss: 327.7339 - root_mean_squared_error: 17.8118 - val_loss: 342.3255 - val_root_mean_squared_error: 18.2269
# Epoch 21/60
# 241/241 [==============================] - 16s 67ms/step - loss: 327.9479 - root_mean_squared_error: 17.8298 - val_loss: 342.5462 - val_root_mean_squared_error: 18.2369
# Epoch 22/60
# 241/241 [==============================] - 16s 67ms/step - loss: 327.0775 - root_mean_squared_error: 17.8120 - val_loss: 349.8441 - val_root_mean_squared_error: 18.4475
# Epoch 23/60
# 241/241 [==============================] - 16s 67ms/step - loss: 326.0876 - root_mean_squared_error: 17.7889 - val_loss: 341.3090 - val_root_mean_squared_error: 18.2210
# Epoch 24/60
# 241/241 [==============================] - 16s 67ms/step - loss: 325.7459 - root_mean_squared_error: 17.7894 - val_loss: 342.9379 - val_root_mean_squared_error: 18.2575
# Epoch 25/60
# 241/241 [==============================] - 16s 68ms/step - loss: 324.4203 - root_mean_squared_error: 17.7532 - val_loss: 341.8503 - val_root_mean_squared_error: 18.2447
# Epoch 26/60
# 241/241 [==============================] - 16s 68ms/step - loss: 324.8399 - root_mean_squared_error: 17.7786 - val_loss: 341.4636 - val_root_mean_squared_error: 18.2467
# Epoch 27/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.8792 - root_mean_squared_error: 17.7834 - val_loss: 341.0477 - val_root_mean_squared_error: 18.2443
# Epoch 28/60
# 241/241 [==============================] - 16s 68ms/step - loss: 323.8207 - root_mean_squared_error: 17.7628 - val_loss: 341.2001 - val_root_mean_squared_error: 18.2472
# Epoch 29/60
# 241/241 [==============================] - 17s 68ms/step - loss: 323.0614 - root_mean_squared_error: 17.7491 - val_loss: 340.4706 - val_root_mean_squared_error: 18.2372
# Epoch 30/60
# 241/241 [==============================] - 16s 67ms/step - loss: 323.6520 - root_mean_squared_error: 17.7643 - val_loss: 339.8926 - val_root_mean_squared_error: 18.2277
# Epoch 31/60
# 241/241 [==============================] - 16s 68ms/step - loss: 322.7651 - root_mean_squared_error: 17.7529 - val_loss: 341.2021 - val_root_mean_squared_error: 18.2684
# Epoch 32/60
# 241/241 [==============================] - 16s 67ms/step - loss: 322.5256 - root_mean_squared_error: 17.7448 - val_loss: 340.5913 - val_root_mean_squared_error: 18.2412
# Epoch 33/60
# 241/241 [==============================] - 16s 67ms/step - loss: 322.5162 - root_mean_squared_error: 17.7456 - val_loss: 339.7924 - val_root_mean_squared_error: 18.2278
# Epoch 34/60
# 241/241 [==============================] - 16s 68ms/step - loss: 321.5215 - root_mean_squared_error: 17.7264 - val_loss: 339.6204 - val_root_mean_squared_error: 18.2394
# Epoch 35/60
# 241/241 [==============================] - 16s 67ms/step - loss: 321.6509 - root_mean_squared_error: 17.7358 - val_loss: 339.0841 - val_root_mean_squared_error: 18.2228
# Epoch 36/60
# 241/241 [==============================] - 16s 67ms/step - loss: 322.1506 - root_mean_squared_error: 17.7521 - val_loss: 339.6815 - val_root_mean_squared_error: 18.2376
# Epoch 37/60
# 241/241 [==============================] - 16s 68ms/step - loss: 321.9041 - root_mean_squared_error: 17.7483 - val_loss: 339.1541 - val_root_mean_squared_error: 18.2372
# Epoch 38/60
# 241/241 [==============================] - 16s 67ms/step - loss: 321.0103 - root_mean_squared_error: 17.7213 - val_loss: 338.8253 - val_root_mean_squared_error: 18.2272
# Epoch 39/60
# 241/241 [==============================] - 16s 67ms/step - loss: 321.3504 - root_mean_squared_error: 17.7370 - val_loss: 339.8818 - val_root_mean_squared_error: 18.2461
# Epoch 40/60
# 241/241 [==============================] - 16s 68ms/step - loss: 321.4468 - root_mean_squared_error: 17.7415 - val_loss: 338.2936 - val_root_mean_squared_error: 18.2195
# Epoch 41/60
# 241/241 [==============================] - 16s 67ms/step - loss: 320.5530 - root_mean_squared_error: 17.7210 - val_loss: 338.1755 - val_root_mean_squared_error: 18.2198
# Epoch 42/60
# 241/241 [==============================] - 16s 68ms/step - loss: 320.4581 - root_mean_squared_error: 17.7175 - val_loss: 340.4465 - val_root_mean_squared_error: 18.2688
# Epoch 43/60
# 241/241 [==============================] - 16s 68ms/step - loss: 320.6942 - root_mean_squared_error: 17.7251 - val_loss: 339.7676 - val_root_mean_squared_error: 18.2520
# Epoch 44/60
# 241/241 [==============================] - 16s 67ms/step - loss: 320.3899 - root_mean_squared_error: 17.7164 - val_loss: 337.4716 - val_root_mean_squared_error: 18.1988
# Epoch 45/60
# 241/241 [==============================] - 16s 66ms/step - loss: 320.0050 - root_mean_squared_error: 17.7117 - val_loss: 337.9307 - val_root_mean_squared_error: 18.2124
# Epoch 46/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.9788 - root_mean_squared_error: 17.7114 - val_loss: 337.0840 - val_root_mean_squared_error: 18.1915
# Epoch 47/60
# 241/241 [==============================] - 16s 67ms/step - loss: 320.0676 - root_mean_squared_error: 17.7173 - val_loss: 337.5424 - val_root_mean_squared_error: 18.2047
# Epoch 48/60
# 241/241 [==============================] - 16s 66ms/step - loss: 320.1926 - root_mean_squared_error: 17.7188 - val_loss: 338.7876 - val_root_mean_squared_error: 18.2306
# Epoch 49/60
# 241/241 [==============================] - 16s 68ms/step - loss: 319.2201 - root_mean_squared_error: 17.6914 - val_loss: 338.9450 - val_root_mean_squared_error: 18.2461
# Epoch 50/60
# 241/241 [==============================] - 16s 67ms/step - loss: 318.7461 - root_mean_squared_error: 17.6765 - val_loss: 338.1955 - val_root_mean_squared_error: 18.2243
# Epoch 51/60
# 241/241 [==============================] - 16s 66ms/step - loss: 319.8676 - root_mean_squared_error: 17.7133 - val_loss: 338.9870 - val_root_mean_squared_error: 18.2463
# Epoch 52/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.2448 - root_mean_squared_error: 17.7004 - val_loss: 338.8415 - val_root_mean_squared_error: 18.2457
# Epoch 53/60
# 241/241 [==============================] - 16s 66ms/step - loss: 319.2237 - root_mean_squared_error: 17.6990 - val_loss: 337.7769 - val_root_mean_squared_error: 18.2207
# Epoch 54/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.3531 - root_mean_squared_error: 17.7013 - val_loss: 337.7159 - val_root_mean_squared_error: 18.2177
# Epoch 55/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.9095 - root_mean_squared_error: 17.7180 - val_loss: 336.4686 - val_root_mean_squared_error: 18.1826
# Epoch 56/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.0098 - root_mean_squared_error: 17.6944 - val_loss: 337.0509 - val_root_mean_squared_error: 18.1936
# Epoch 57/60
# 241/241 [==============================] - 16s 66ms/step - loss: 318.4417 - root_mean_squared_error: 17.6763 - val_loss: 336.9884 - val_root_mean_squared_error: 18.1967
# Epoch 58/60
# 241/241 [==============================] - 16s 67ms/step - loss: 319.0590 - root_mean_squared_error: 17.6938 - val_loss: 337.1802 - val_root_mean_squared_error: 18.2065
# Epoch 59/60
# 241/241 [==============================] - 16s 67ms/step - loss: 318.5105 - root_mean_squared_error: 17.6796 - val_loss: 337.2971 - val_root_mean_squared_error: 18.2077
# Epoch 60/60
# 241/241 [==============================] - 17s 69ms/step - loss: 317.4178 - root_mean_squared_error: 17.6520 - val_loss: 340.4956 - val_root_mean_squared_error: 18.2818
# 241/241 [==============================] - 4s 13ms/step - loss: 318.0488 - root_mean_squared_error: 17.6713
# 61/61 [==============================] - 1s 13ms/step - loss: 338.3964 - root_mean_squared_error: 18.2379
# Epoch 1/60
# 241/241 [==============================] - 20s 70ms/step - loss: 742.2466 - root_mean_squared_error: 24.1220 - val_loss: 578.6586 - val_root_mean_squared_error: 22.4261
# Epoch 2/60
# 241/241 [==============================] - 16s 67ms/step - loss: 561.6644 - root_mean_squared_error: 21.6525 - val_loss: 501.4283 - val_root_mean_squared_error: 21.3626
# Epoch 3/60
# 241/241 [==============================] - 16s 66ms/step - loss: 487.0208 - root_mean_squared_error: 20.5960 - val_loss: 439.0615 - val_root_mean_squared_error: 20.0374
# Epoch 4/60
# 241/241 [==============================] - 16s 66ms/step - loss: 431.6668 - root_mean_squared_error: 19.6519 - val_loss: 411.2391 - val_root_mean_squared_error: 19.5964
# Epoch 5/60
# 241/241 [==============================] - 16s 67ms/step - loss: 395.2565 - root_mean_squared_error: 19.0133 - val_loss: 362.2616 - val_root_mean_squared_error: 18.3803
# Epoch 6/60
# 241/241 [==============================] - 16s 66ms/step - loss: 370.0301 - root_mean_squared_error: 18.5262 - val_loss: 346.5923 - val_root_mean_squared_error: 17.9762
# Epoch 7/60
# 241/241 [==============================] - 16s 66ms/step - loss: 359.0459 - root_mean_squared_error: 18.3138 - val_loss: 338.4070 - val_root_mean_squared_error: 17.8036
# Epoch 8/60
# 241/241 [==============================] - 16s 66ms/step - loss: 353.4242 - root_mean_squared_error: 18.2109 - val_loss: 339.8832 - val_root_mean_squared_error: 17.8906
# Epoch 9/60
# 241/241 [==============================] - 16s 65ms/step - loss: 347.4843 - root_mean_squared_error: 18.0944 - val_loss: 337.8753 - val_root_mean_squared_error: 17.7881
# Epoch 10/60
# 241/241 [==============================] - 16s 67ms/step - loss: 348.9138 - root_mean_squared_error: 18.1762 - val_loss: 337.0628 - val_root_mean_squared_error: 17.8879
# Epoch 11/60
# 241/241 [==============================] - 16s 66ms/step - loss: 344.7786 - root_mean_squared_error: 18.0781 - val_loss: 335.7112 - val_root_mean_squared_error: 17.8636
# Epoch 12/60
# 241/241 [==============================] - 16s 66ms/step - loss: 344.6723 - root_mean_squared_error: 18.1119 - val_loss: 333.8510 - val_root_mean_squared_error: 17.8389
# Epoch 13/60
# 241/241 [==============================] - 16s 67ms/step - loss: 341.3797 - root_mean_squared_error: 18.0528 - val_loss: 330.8611 - val_root_mean_squared_error: 17.7856
# Epoch 14/60
# 241/241 [==============================] - 16s 66ms/step - loss: 339.4299 - root_mean_squared_error: 18.0206 - val_loss: 330.4380 - val_root_mean_squared_error: 17.7820
# Epoch 15/60
# 241/241 [==============================] - 16s 66ms/step - loss: 338.9113 - root_mean_squared_error: 18.0260 - val_loss: 330.5051 - val_root_mean_squared_error: 17.7964
# Epoch 16/60
# 241/241 [==============================] - 16s 67ms/step - loss: 336.2770 - root_mean_squared_error: 17.9773 - val_loss: 329.2610 - val_root_mean_squared_error: 17.8035
# Epoch 17/60
# 241/241 [==============================] - 16s 67ms/step - loss: 334.2422 - root_mean_squared_error: 17.9447 - val_loss: 327.8768 - val_root_mean_squared_error: 17.7738
# Epoch 18/60
# 241/241 [==============================] - 16s 66ms/step - loss: 334.6208 - root_mean_squared_error: 17.9717 - val_loss: 326.4564 - val_root_mean_squared_error: 17.7569
# Epoch 19/60
# 241/241 [==============================] - 16s 68ms/step - loss: 333.0750 - root_mean_squared_error: 17.9380 - val_loss: 326.5008 - val_root_mean_squared_error: 17.7667
# Epoch 20/60
# 241/241 [==============================] - 16s 65ms/step - loss: 333.4177 - root_mean_squared_error: 17.9641 - val_loss: 326.7622 - val_root_mean_squared_error: 17.7760
# Epoch 21/60
# 241/241 [==============================] - 16s 66ms/step - loss: 331.8572 - root_mean_squared_error: 17.9319 - val_loss: 326.0276 - val_root_mean_squared_error: 17.7734
# Epoch 22/60
# 241/241 [==============================] - 16s 67ms/step - loss: 330.9666 - root_mean_squared_error: 17.9196 - val_loss: 326.4732 - val_root_mean_squared_error: 17.8071
# Epoch 23/60
# 241/241 [==============================] - 16s 68ms/step - loss: 331.4547 - root_mean_squared_error: 17.9400 - val_loss: 325.1768 - val_root_mean_squared_error: 17.7675
# Epoch 24/60
# 241/241 [==============================] - 16s 68ms/step - loss: 330.3212 - root_mean_squared_error: 17.9153 - val_loss: 328.8654 - val_root_mean_squared_error: 17.8639
# Epoch 25/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.9252 - root_mean_squared_error: 17.9119 - val_loss: 325.5840 - val_root_mean_squared_error: 17.8006
# Epoch 26/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.3296 - root_mean_squared_error: 17.9031 - val_loss: 324.5300 - val_root_mean_squared_error: 17.7714
# Epoch 27/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.1626 - root_mean_squared_error: 17.9046 - val_loss: 325.2856 - val_root_mean_squared_error: 17.8047
# Epoch 28/60
# 241/241 [==============================] - 16s 66ms/step - loss: 329.1142 - root_mean_squared_error: 17.9061 - val_loss: 325.4355 - val_root_mean_squared_error: 17.8119
# Epoch 29/60
# 241/241 [==============================] - 16s 66ms/step - loss: 328.9547 - root_mean_squared_error: 17.9032 - val_loss: 324.0576 - val_root_mean_squared_error: 17.7674
# Epoch 30/60
# 241/241 [==============================] - 16s 67ms/step - loss: 328.7208 - root_mean_squared_error: 17.9049 - val_loss: 324.4651 - val_root_mean_squared_error: 17.7861
# Epoch 31/60
# 241/241 [==============================] - 16s 67ms/step - loss: 327.4012 - root_mean_squared_error: 17.8709 - val_loss: 323.7784 - val_root_mean_squared_error: 17.7780
# Epoch 32/60
# 241/241 [==============================] - 16s 68ms/step - loss: 328.3741 - root_mean_squared_error: 17.9016 - val_loss: 323.9136 - val_root_mean_squared_error: 17.7770
# Epoch 33/60
# 241/241 [==============================] - 16s 67ms/step - loss: 327.3250 - root_mean_squared_error: 17.8772 - val_loss: 323.8439 - val_root_mean_squared_error: 17.7833
# Epoch 34/60
# 241/241 [==============================] - 16s 66ms/step - loss: 327.3866 - root_mean_squared_error: 17.8758 - val_loss: 324.4565 - val_root_mean_squared_error: 17.7974
# Epoch 35/60
# 241/241 [==============================] - 16s 65ms/step - loss: 326.0172 - root_mean_squared_error: 17.8471 - val_loss: 323.8563 - val_root_mean_squared_error: 17.7921
# Epoch 36/60
# 241/241 [==============================] - 16s 67ms/step - loss: 326.4263 - root_mean_squared_error: 17.8637 - val_loss: 322.8427 - val_root_mean_squared_error: 17.7709
# Epoch 37/60
# 241/241 [==============================] - 16s 66ms/step - loss: 326.3828 - root_mean_squared_error: 17.8645 - val_loss: 323.5146 - val_root_mean_squared_error: 17.7874
# Epoch 38/60
# 241/241 [==============================] - 16s 66ms/step - loss: 326.4115 - root_mean_squared_error: 17.8668 - val_loss: 322.5844 - val_root_mean_squared_error: 17.7675
# Epoch 39/60
# 241/241 [==============================] - 16s 68ms/step - loss: 326.0232 - root_mean_squared_error: 17.8657 - val_loss: 322.5075 - val_root_mean_squared_error: 17.7665
# Epoch 40/60
# 241/241 [==============================] - 16s 67ms/step - loss: 325.6019 - root_mean_squared_error: 17.8516 - val_loss: 322.6018 - val_root_mean_squared_error: 17.7776
# Epoch 41/60
# 241/241 [==============================] - 16s 66ms/step - loss: 325.8967 - root_mean_squared_error: 17.8663 - val_loss: 322.8318 - val_root_mean_squared_error: 17.7827
# Epoch 42/60
# 241/241 [==============================] - 16s 66ms/step - loss: 325.5042 - root_mean_squared_error: 17.8592 - val_loss: 322.3398 - val_root_mean_squared_error: 17.7679
# Epoch 43/60
# 241/241 [==============================] - 16s 66ms/step - loss: 325.6449 - root_mean_squared_error: 17.8626 - val_loss: 322.4689 - val_root_mean_squared_error: 17.7631
# Epoch 44/60
# 241/241 [==============================] - 16s 66ms/step - loss: 325.1926 - root_mean_squared_error: 17.8511 - val_loss: 322.0764 - val_root_mean_squared_error: 17.7674
# Epoch 45/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.5212 - root_mean_squared_error: 17.8313 - val_loss: 322.7708 - val_root_mean_squared_error: 17.7823
# Epoch 46/60
# 241/241 [==============================] - 16s 65ms/step - loss: 324.2905 - root_mean_squared_error: 17.8253 - val_loss: 321.7148 - val_root_mean_squared_error: 17.7599
# Epoch 47/60
# 241/241 [==============================] - 16s 66ms/step - loss: 324.2773 - root_mean_squared_error: 17.8318 - val_loss: 322.1025 - val_root_mean_squared_error: 17.7720
# Epoch 48/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.8210 - root_mean_squared_error: 17.8493 - val_loss: 321.9131 - val_root_mean_squared_error: 17.7731
# Epoch 49/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.0530 - root_mean_squared_error: 17.8231 - val_loss: 321.3484 - val_root_mean_squared_error: 17.7498
# Epoch 50/60
# 241/241 [==============================] - 16s 66ms/step - loss: 324.7706 - root_mean_squared_error: 17.8475 - val_loss: 321.7283 - val_root_mean_squared_error: 17.7660
# Epoch 51/60
# 241/241 [==============================] - 16s 67ms/step - loss: 323.8352 - root_mean_squared_error: 17.8233 - val_loss: 322.1104 - val_root_mean_squared_error: 17.7799
# Epoch 52/60
# 241/241 [==============================] - 16s 68ms/step - loss: 324.1647 - root_mean_squared_error: 17.8348 - val_loss: 320.9999 - val_root_mean_squared_error: 17.7550
# Epoch 53/60
# 241/241 [==============================] - 16s 68ms/step - loss: 323.9240 - root_mean_squared_error: 17.8304 - val_loss: 320.8983 - val_root_mean_squared_error: 17.7372
# Epoch 54/60
# 241/241 [==============================] - 16s 68ms/step - loss: 323.9506 - root_mean_squared_error: 17.8317 - val_loss: 320.8680 - val_root_mean_squared_error: 17.7486
# Epoch 55/60
# 241/241 [==============================] - 16s 67ms/step - loss: 323.6359 - root_mean_squared_error: 17.8238 - val_loss: 321.8212 - val_root_mean_squared_error: 17.7745
# Epoch 56/60
# 241/241 [==============================] - 16s 66ms/step - loss: 323.1360 - root_mean_squared_error: 17.8077 - val_loss: 321.4595 - val_root_mean_squared_error: 17.7571
# Epoch 57/60
# 241/241 [==============================] - 16s 67ms/step - loss: 323.4898 - root_mean_squared_error: 17.8186 - val_loss: 322.7931 - val_root_mean_squared_error: 17.8017
# Epoch 58/60
# 241/241 [==============================] - 16s 68ms/step - loss: 322.9862 - root_mean_squared_error: 17.8056 - val_loss: 321.9146 - val_root_mean_squared_error: 17.7806
# Epoch 59/60
# 241/241 [==============================] - 16s 68ms/step - loss: 322.8059 - root_mean_squared_error: 17.7973 - val_loss: 323.2335 - val_root_mean_squared_error: 17.8133
# Epoch 60/60
# 241/241 [==============================] - 17s 69ms/step - loss: 322.9979 - root_mean_squared_error: 17.8020 - val_loss: 321.9553 - val_root_mean_squared_error: 17.7814
# 241/241 [==============================] - 3s 12ms/step - loss: 324.6450 - root_mean_squared_error: 17.8587
# 61/61 [==============================] - 1s 12ms/step - loss: 322.8731 - root_mean_squared_error: 17.8092
# Epoch 1/60
# 241/241 [==============================] - 20s 69ms/step - loss: 732.6650 - root_mean_squared_error: 24.0971 - val_loss: 603.4368 - val_root_mean_squared_error: 23.4165
# Epoch 2/60
# 241/241 [==============================] - 16s 68ms/step - loss: 554.6534 - root_mean_squared_error: 21.6322 - val_loss: 464.7624 - val_root_mean_squared_error: 20.3319
# Epoch 3/60
# 241/241 [==============================] - 16s 68ms/step - loss: 485.2971 - root_mean_squared_error: 20.5624 - val_loss: 427.0233 - val_root_mean_squared_error: 19.7296
# Epoch 4/60
# 241/241 [==============================] - 17s 68ms/step - loss: 439.2129 - root_mean_squared_error: 19.8597 - val_loss: 388.9843 - val_root_mean_squared_error: 18.9599
# Epoch 5/60
# 241/241 [==============================] - 17s 69ms/step - loss: 398.3739 - root_mean_squared_error: 19.0891 - val_loss: 355.8025 - val_root_mean_squared_error: 18.2030
# Epoch 6/60
# 241/241 [==============================] - 17s 68ms/step - loss: 368.5576 - root_mean_squared_error: 18.5037 - val_loss: 337.5992 - val_root_mean_squared_error: 17.7582
# Epoch 7/60
# 241/241 [==============================] - 16s 68ms/step - loss: 354.8469 - root_mean_squared_error: 18.2242 - val_loss: 336.4290 - val_root_mean_squared_error: 17.7577
# Epoch 8/60
# 241/241 [==============================] - 16s 68ms/step - loss: 351.7762 - root_mean_squared_error: 18.1897 - val_loss: 337.0909 - val_root_mean_squared_error: 17.7439
# Epoch 9/60
# 241/241 [==============================] - 16s 68ms/step - loss: 348.7798 - root_mean_squared_error: 18.1503 - val_loss: 335.0154 - val_root_mean_squared_error: 17.7810
# Epoch 10/60
# 241/241 [==============================] - 16s 67ms/step - loss: 347.7626 - root_mean_squared_error: 18.1595 - val_loss: 329.5553 - val_root_mean_squared_error: 17.6850
# Epoch 11/60
# 241/241 [==============================] - 16s 67ms/step - loss: 343.6179 - root_mean_squared_error: 18.0777 - val_loss: 328.6533 - val_root_mean_squared_error: 17.6924
# Epoch 12/60
# 241/241 [==============================] - 16s 67ms/step - loss: 343.5892 - root_mean_squared_error: 18.1074 - val_loss: 329.1077 - val_root_mean_squared_error: 17.7414
# Epoch 13/60
# 241/241 [==============================] - 16s 68ms/step - loss: 340.5742 - root_mean_squared_error: 18.0556 - val_loss: 326.3978 - val_root_mean_squared_error: 17.6742
# Epoch 14/60
# 241/241 [==============================] - 16s 67ms/step - loss: 338.0199 - root_mean_squared_error: 18.0106 - val_loss: 328.5385 - val_root_mean_squared_error: 17.7470
# Epoch 15/60
# 241/241 [==============================] - 16s 68ms/step - loss: 338.8773 - root_mean_squared_error: 18.0569 - val_loss: 325.8022 - val_root_mean_squared_error: 17.6958
# Epoch 16/60
# 241/241 [==============================] - 16s 67ms/step - loss: 335.9043 - root_mean_squared_error: 17.9879 - val_loss: 324.3448 - val_root_mean_squared_error: 17.6580
# Epoch 17/60
# 241/241 [==============================] - 16s 67ms/step - loss: 336.5294 - root_mean_squared_error: 18.0185 - val_loss: 323.9780 - val_root_mean_squared_error: 17.6891
# Epoch 18/60
# 241/241 [==============================] - 16s 68ms/step - loss: 334.5440 - root_mean_squared_error: 17.9775 - val_loss: 325.3890 - val_root_mean_squared_error: 17.7210
# Epoch 19/60
# 241/241 [==============================] - 16s 68ms/step - loss: 334.4216 - root_mean_squared_error: 17.9884 - val_loss: 322.7876 - val_root_mean_squared_error: 17.6641
# Epoch 20/60
# 241/241 [==============================] - 16s 67ms/step - loss: 333.0529 - root_mean_squared_error: 17.9601 - val_loss: 322.1132 - val_root_mean_squared_error: 17.6601
# Epoch 21/60
# 241/241 [==============================] - 16s 68ms/step - loss: 332.4631 - root_mean_squared_error: 17.9522 - val_loss: 323.6895 - val_root_mean_squared_error: 17.7063
# Epoch 22/60
# 241/241 [==============================] - 16s 67ms/step - loss: 332.3503 - root_mean_squared_error: 17.9588 - val_loss: 322.0881 - val_root_mean_squared_error: 17.6776
# Epoch 23/60
# 241/241 [==============================] - 16s 68ms/step - loss: 330.8138 - root_mean_squared_error: 17.9306 - val_loss: 321.2787 - val_root_mean_squared_error: 17.6664
# Epoch 24/60
# 241/241 [==============================] - 17s 69ms/step - loss: 331.1075 - root_mean_squared_error: 17.9473 - val_loss: 321.5924 - val_root_mean_squared_error: 17.6708
# Epoch 25/60
# 241/241 [==============================] - 17s 69ms/step - loss: 330.3043 - root_mean_squared_error: 17.9281 - val_loss: 321.3917 - val_root_mean_squared_error: 17.6826
# Epoch 26/60
# 241/241 [==============================] - 16s 68ms/step - loss: 329.4894 - root_mean_squared_error: 17.9146 - val_loss: 320.1896 - val_root_mean_squared_error: 17.6586
# Epoch 27/60
# 241/241 [==============================] - 17s 69ms/step - loss: 328.9410 - root_mean_squared_error: 17.9027 - val_loss: 321.7479 - val_root_mean_squared_error: 17.7019
# Epoch 28/60
# 241/241 [==============================] - 16s 68ms/step - loss: 329.1705 - root_mean_squared_error: 17.9120 - val_loss: 320.3782 - val_root_mean_squared_error: 17.6614
# Epoch 29/60
# 241/241 [==============================] - 16s 68ms/step - loss: 328.5864 - root_mean_squared_error: 17.9026 - val_loss: 319.9272 - val_root_mean_squared_error: 17.6606
# Epoch 30/60
# 241/241 [==============================] - 17s 69ms/step - loss: 328.3026 - root_mean_squared_error: 17.9011 - val_loss: 318.9690 - val_root_mean_squared_error: 17.6448
# Epoch 31/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.4306 - root_mean_squared_error: 17.8814 - val_loss: 318.4092 - val_root_mean_squared_error: 17.6258
# Epoch 32/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.7319 - root_mean_squared_error: 17.8880 - val_loss: 319.0926 - val_root_mean_squared_error: 17.6434
# Epoch 33/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.6952 - root_mean_squared_error: 17.8916 - val_loss: 318.9920 - val_root_mean_squared_error: 17.6532
# Epoch 34/60
# 241/241 [==============================] - 17s 69ms/step - loss: 326.8529 - root_mean_squared_error: 17.8720 - val_loss: 318.4833 - val_root_mean_squared_error: 17.6390
# Epoch 35/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.4384 - root_mean_squared_error: 17.8979 - val_loss: 319.0960 - val_root_mean_squared_error: 17.6651
# Epoch 36/60
# 241/241 [==============================] - 16s 68ms/step - loss: 327.0438 - root_mean_squared_error: 17.8871 - val_loss: 318.8326 - val_root_mean_squared_error: 17.6641
# Epoch 37/60
# 241/241 [==============================] - 16s 67ms/step - loss: 326.8961 - root_mean_squared_error: 17.8878 - val_loss: 317.8838 - val_root_mean_squared_error: 17.6382
# Epoch 38/60
# 241/241 [==============================] - 17s 69ms/step - loss: 326.3742 - root_mean_squared_error: 17.8768 - val_loss: 319.8604 - val_root_mean_squared_error: 17.6950
# Epoch 39/60
# 241/241 [==============================] - 16s 68ms/step - loss: 326.0363 - root_mean_squared_error: 17.8683 - val_loss: 316.9209 - val_root_mean_squared_error: 17.6057
# Epoch 40/60
# 241/241 [==============================] - 16s 67ms/step - loss: 326.3425 - root_mean_squared_error: 17.8793 - val_loss: 318.0710 - val_root_mean_squared_error: 17.6442
# Epoch 41/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.6015 - root_mean_squared_error: 17.8554 - val_loss: 317.2233 - val_root_mean_squared_error: 17.6220
# Epoch 42/60
# 241/241 [==============================] - 16s 68ms/step - loss: 326.1010 - root_mean_squared_error: 17.8742 - val_loss: 317.3940 - val_root_mean_squared_error: 17.6367
# Epoch 43/60
# 241/241 [==============================] - 16s 68ms/step - loss: 325.8204 - root_mean_squared_error: 17.8683 - val_loss: 319.8087 - val_root_mean_squared_error: 17.6587
# Epoch 44/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.7365 - root_mean_squared_error: 17.8673 - val_loss: 317.0266 - val_root_mean_squared_error: 17.6263
# Epoch 45/60
# 241/241 [==============================] - 16s 68ms/step - loss: 325.6091 - root_mean_squared_error: 17.8657 - val_loss: 317.6502 - val_root_mean_squared_error: 17.6345
# Epoch 46/60
# 241/241 [==============================] - 16s 68ms/step - loss: 325.7338 - root_mean_squared_error: 17.8706 - val_loss: 317.6764 - val_root_mean_squared_error: 17.6458
# Epoch 47/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.1748 - root_mean_squared_error: 17.8516 - val_loss: 316.6479 - val_root_mean_squared_error: 17.6245
# Epoch 48/60
# 241/241 [==============================] - 16s 67ms/step - loss: 325.3434 - root_mean_squared_error: 17.8633 - val_loss: 317.3411 - val_root_mean_squared_error: 17.6378
# Epoch 49/60
# 241/241 [==============================] - 16s 68ms/step - loss: 324.6073 - root_mean_squared_error: 17.8446 - val_loss: 316.6385 - val_root_mean_squared_error: 17.6239
# Epoch 50/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.3452 - root_mean_squared_error: 17.8592 - val_loss: 318.0198 - val_root_mean_squared_error: 17.6263
# Epoch 51/60
# 241/241 [==============================] - 17s 69ms/step - loss: 324.6949 - root_mean_squared_error: 17.8437 - val_loss: 317.5492 - val_root_mean_squared_error: 17.6507
# Epoch 52/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.2410 - root_mean_squared_error: 17.8697 - val_loss: 316.4548 - val_root_mean_squared_error: 17.6254
# Epoch 53/60
# 241/241 [==============================] - 16s 68ms/step - loss: 324.6892 - root_mean_squared_error: 17.8579 - val_loss: 316.4935 - val_root_mean_squared_error: 17.6218
# Epoch 54/60
# 241/241 [==============================] - 16s 68ms/step - loss: 325.0346 - root_mean_squared_error: 17.8676 - val_loss: 316.3990 - val_root_mean_squared_error: 17.6276
# Epoch 55/60
# 241/241 [==============================] - 17s 69ms/step - loss: 324.8229 - root_mean_squared_error: 17.8649 - val_loss: 320.1076 - val_root_mean_squared_error: 17.7199
# Epoch 56/60
# 241/241 [==============================] - 16s 68ms/step - loss: 325.6106 - root_mean_squared_error: 17.8865 - val_loss: 315.9608 - val_root_mean_squared_error: 17.6207
# Epoch 57/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.5614 - root_mean_squared_error: 17.8571 - val_loss: 316.4328 - val_root_mean_squared_error: 17.6266
# Epoch 58/60
# 241/241 [==============================] - 16s 67ms/step - loss: 324.4731 - root_mean_squared_error: 17.8571 - val_loss: 316.1219 - val_root_mean_squared_error: 17.6263
# Epoch 59/60
# 241/241 [==============================] - 16s 66ms/step - loss: 323.2010 - root_mean_squared_error: 17.8171 - val_loss: 315.6143 - val_root_mean_squared_error: 17.5945
# Epoch 60/60
# 241/241 [==============================] - 16s 66ms/step - loss: 324.2129 - root_mean_squared_error: 17.8431 - val_loss: 315.8000 - val_root_mean_squared_error: 17.6070
# 241/241 [==============================] - 3s 12ms/step - loss: 323.9240 - root_mean_squared_error: 17.8460
# 61/61 [==============================] - 1s 12ms/step - loss: 317.5356 - root_mean_squared_error: 17.6661
# Epoch 1/60
# 241/241 [==============================] - 19s 69ms/step - loss: 796.5498 - root_mean_squared_error: 24.8864 - val_loss: 521.5499 - val_root_mean_squared_error: 20.7728
# Epoch 2/60
# 241/241 [==============================] - 16s 66ms/step - loss: 571.5842 - root_mean_squared_error: 21.6445 - val_loss: 551.7622 - val_root_mean_squared_error: 22.4512
# Epoch 3/60
# 241/241 [==============================] - 16s 67ms/step - loss: 492.0476 - root_mean_squared_error: 20.5242 - val_loss: 465.5215 - val_root_mean_squared_error: 20.6724
# Epoch 4/60
# 241/241 [==============================] - 16s 67ms/step - loss: 439.6342 - root_mean_squared_error: 19.7336 - val_loss: 402.1635 - val_root_mean_squared_error: 19.2413
# Epoch 5/60
# 241/241 [==============================] - 16s 66ms/step - loss: 398.7106 - root_mean_squared_error: 19.0292 - val_loss: 359.0571 - val_root_mean_squared_error: 18.1969
# Epoch 6/60
# 241/241 [==============================] - 16s 68ms/step - loss: 372.9855 - root_mean_squared_error: 18.5679 - val_loss: 342.5574 - val_root_mean_squared_error: 17.8405
# Epoch 7/60
# 241/241 [==============================] - 16s 68ms/step - loss: 358.3499 - root_mean_squared_error: 18.2759 - val_loss: 340.5539 - val_root_mean_squared_error: 17.8389
# Epoch 8/60
# 241/241 [==============================] - 16s 67ms/step - loss: 351.5693 - root_mean_squared_error: 18.1305 - val_loss: 344.0363 - val_root_mean_squared_error: 17.8855
# Epoch 9/60
# 241/241 [==============================] - 17s 69ms/step - loss: 350.0507 - root_mean_squared_error: 18.1435 - val_loss: 336.8788 - val_root_mean_squared_error: 17.7944
# Epoch 10/60
# 241/241 [==============================] - 16s 68ms/step - loss: 348.4305 - root_mean_squared_error: 18.1284 - val_loss: 333.7509 - val_root_mean_squared_error: 17.7934
# Epoch 11/60
# 241/241 [==============================] - 17s 69ms/step - loss: 344.3602 - root_mean_squared_error: 18.0809 - val_loss: 332.0225 - val_root_mean_squared_error: 17.7712
# Epoch 12/60
# 241/241 [==============================] - 17s 69ms/step - loss: 341.5974 - root_mean_squared_error: 18.0319 - val_loss: 331.5582 - val_root_mean_squared_error: 17.7749
# Epoch 13/60
# 241/241 [==============================] - 17s 69ms/step - loss: 339.0261 - root_mean_squared_error: 17.9974 - val_loss: 330.7426 - val_root_mean_squared_error: 17.7798
# Epoch 14/60
# 241/241 [==============================] - 17s 69ms/step - loss: 337.4952 - root_mean_squared_error: 17.9897 - val_loss: 328.5737 - val_root_mean_squared_error: 17.7634
# Epoch 15/60
# 241/241 [==============================] - 17s 69ms/step - loss: 336.7826 - root_mean_squared_error: 17.9869 - val_loss: 329.2307 - val_root_mean_squared_error: 17.7937
# Epoch 16/60
# 241/241 [==============================] - 16s 68ms/step - loss: 337.3784 - root_mean_squared_error: 18.0142 - val_loss: 328.0840 - val_root_mean_squared_error: 17.7628
# Epoch 17/60
# 241/241 [==============================] - 17s 69ms/step - loss: 335.7534 - root_mean_squared_error: 17.9814 - val_loss: 327.2341 - val_root_mean_squared_error: 17.7476
# Epoch 18/60
# 241/241 [==============================] - 16s 68ms/step - loss: 333.1084 - root_mean_squared_error: 17.9294 - val_loss: 329.4436 - val_root_mean_squared_error: 17.8393
# Epoch 19/60
# 241/241 [==============================] - 16s 68ms/step - loss: 333.8885 - root_mean_squared_error: 17.9650 - val_loss: 327.7607 - val_root_mean_squared_error: 17.8175
# Epoch 20/60
# 241/241 [==============================] - 17s 69ms/step - loss: 332.9066 - root_mean_squared_error: 17.9516 - val_loss: 326.0638 - val_root_mean_squared_error: 17.7565
# Epoch 21/60
# 241/241 [==============================] - 17s 69ms/step - loss: 331.8083 - root_mean_squared_error: 17.9317 - val_loss: 325.3927 - val_root_mean_squared_error: 17.7598
# Epoch 22/60
# 241/241 [==============================] - 16s 68ms/step - loss: 330.9957 - root_mean_squared_error: 17.9105 - val_loss: 325.5978 - val_root_mean_squared_error: 17.7717
# Epoch 23/60
# 241/241 [==============================] - 17s 71ms/step - loss: 331.3445 - root_mean_squared_error: 17.9350 - val_loss: 327.9436 - val_root_mean_squared_error: 17.8292
# Epoch 24/60
# 241/241 [==============================] - 17s 69ms/step - loss: 330.3239 - root_mean_squared_error: 17.9114 - val_loss: 324.3769 - val_root_mean_squared_error: 17.7554
# Epoch 25/60
# 241/241 [==============================] - 17s 69ms/step - loss: 329.7157 - root_mean_squared_error: 17.9029 - val_loss: 324.1389 - val_root_mean_squared_error: 17.7562
# Epoch 26/60
# 241/241 [==============================] - 17s 70ms/step - loss: 329.7274 - root_mean_squared_error: 17.9090 - val_loss: 324.1898 - val_root_mean_squared_error: 17.7533
# Epoch 27/60
# 241/241 [==============================] - 17s 70ms/step - loss: 328.3693 - root_mean_squared_error: 17.8786 - val_loss: 324.8906 - val_root_mean_squared_error: 17.7823
# Epoch 28/60
# 241/241 [==============================] - 17s 70ms/step - loss: 328.6429 - root_mean_squared_error: 17.8932 - val_loss: 323.5004 - val_root_mean_squared_error: 17.7546
# Epoch 29/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.9168 - root_mean_squared_error: 17.8771 - val_loss: 323.4921 - val_root_mean_squared_error: 17.7547
# Epoch 30/60
# 241/241 [==============================] - 17s 69ms/step - loss: 327.6394 - root_mean_squared_error: 17.8742 - val_loss: 323.0979 - val_root_mean_squared_error: 17.7504
# Epoch 31/60
# 241/241 [==============================] - 17s 72ms/step - loss: 326.8776 - root_mean_squared_error: 17.8554 - val_loss: 323.0492 - val_root_mean_squared_error: 17.7514
# Epoch 32/60
# 241/241 [==============================] - 17s 72ms/step - loss: 327.3368 - root_mean_squared_error: 17.8695 - val_loss: 324.0792 - val_root_mean_squared_error: 17.7754
# Epoch 33/60
# 241/241 [==============================] - 17s 72ms/step - loss: 327.0497 - root_mean_squared_error: 17.8649 - val_loss: 322.9460 - val_root_mean_squared_error: 17.7625
# Epoch 34/60
# 241/241 [==============================] - 17s 72ms/step - loss: 326.9625 - root_mean_squared_error: 17.8722 - val_loss: 323.3592 - val_root_mean_squared_error: 17.7816
# Epoch 35/60
# 241/241 [==============================] - 17s 70ms/step - loss: 326.7525 - root_mean_squared_error: 17.8708 - val_loss: 322.9182 - val_root_mean_squared_error: 17.7637
# Epoch 36/60
# 241/241 [==============================] - 17s 70ms/step - loss: 325.9114 - root_mean_squared_error: 17.8467 - val_loss: 322.3000 - val_root_mean_squared_error: 17.7500
# Epoch 37/60
# 241/241 [==============================] - 17s 70ms/step - loss: 326.4438 - root_mean_squared_error: 17.8666 - val_loss: 321.7317 - val_root_mean_squared_error: 17.7418
# Epoch 38/60
# 241/241 [==============================] - 17s 69ms/step - loss: 325.9493 - root_mean_squared_error: 17.8555 - val_loss: 322.3288 - val_root_mean_squared_error: 17.7569
# Epoch 39/60
# 241/241 [==============================] - 17s 71ms/step - loss: 326.0707 - root_mean_squared_error: 17.8633 - val_loss: 321.3829 - val_root_mean_squared_error: 17.7410
# Epoch 40/60
# 241/241 [==============================] - 17s 70ms/step - loss: 325.5401 - root_mean_squared_error: 17.8552 - val_loss: 321.6901 - val_root_mean_squared_error: 17.7435
# Epoch 41/60
# 241/241 [==============================] - 17s 70ms/step - loss: 325.1833 - root_mean_squared_error: 17.8466 - val_loss: 324.6270 - val_root_mean_squared_error: 17.8280
# Epoch 42/60
# 241/241 [==============================] - 17s 70ms/step - loss: 325.6893 - root_mean_squared_error: 17.8608 - val_loss: 321.3772 - val_root_mean_squared_error: 17.7520
# Epoch 43/60
# 241/241 [==============================] - 17s 70ms/step - loss: 325.0661 - root_mean_squared_error: 17.8452 - val_loss: 321.1113 - val_root_mean_squared_error: 17.7392
# Epoch 44/60
# 241/241 [==============================] - 17s 71ms/step - loss: 324.9086 - root_mean_squared_error: 17.8399 - val_loss: 321.3372 - val_root_mean_squared_error: 17.7423
# Epoch 45/60
# 241/241 [==============================] - 17s 72ms/step - loss: 324.6195 - root_mean_squared_error: 17.8332 - val_loss: 321.1665 - val_root_mean_squared_error: 17.7391
# Epoch 46/60
# 241/241 [==============================] - 17s 71ms/step - loss: 325.0062 - root_mean_squared_error: 17.8472 - val_loss: 321.2348 - val_root_mean_squared_error: 17.7430
# Epoch 47/60
# 241/241 [==============================] - 17s 70ms/step - loss: 324.8986 - root_mean_squared_error: 17.8455 - val_loss: 320.8759 - val_root_mean_squared_error: 17.7400
# Epoch 48/60
# 241/241 [==============================] - 17s 71ms/step - loss: 324.8897 - root_mean_squared_error: 17.8523 - val_loss: 321.1172 - val_root_mean_squared_error: 17.7473
# Epoch 49/60
# 241/241 [==============================] - 17s 70ms/step - loss: 324.5362 - root_mean_squared_error: 17.8396 - val_loss: 320.5733 - val_root_mean_squared_error: 17.7342
# Epoch 50/60
# 241/241 [==============================] - 17s 70ms/step - loss: 324.1451 - root_mean_squared_error: 17.8263 - val_loss: 323.0633 - val_root_mean_squared_error: 17.7905
# Epoch 51/60
# 241/241 [==============================] - 17s 69ms/step - loss: 324.4734 - root_mean_squared_error: 17.8381 - val_loss: 320.5070 - val_root_mean_squared_error: 17.7336
# Epoch 52/60
# 241/241 [==============================] - 17s 70ms/step - loss: 323.2123 - root_mean_squared_error: 17.8066 - val_loss: 320.7849 - val_root_mean_squared_error: 17.7421
# Epoch 53/60
# 241/241 [==============================] - 17s 69ms/step - loss: 324.0558 - root_mean_squared_error: 17.8300 - val_loss: 321.4102 - val_root_mean_squared_error: 17.7563
# Epoch 54/60
# 241/241 [==============================] - 17s 69ms/step - loss: 323.4821 - root_mean_squared_error: 17.8125 - val_loss: 321.7699 - val_root_mean_squared_error: 17.7582
# Epoch 55/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.9822 - root_mean_squared_error: 17.8247 - val_loss: 321.0245 - val_root_mean_squared_error: 17.7386
# Epoch 56/60
# 241/241 [==============================] - 17s 70ms/step - loss: 323.3908 - root_mean_squared_error: 17.8099 - val_loss: 322.6252 - val_root_mean_squared_error: 17.7851
# Epoch 57/60
# 241/241 [==============================] - 17s 70ms/step - loss: 323.8587 - root_mean_squared_error: 17.8263 - val_loss: 320.2206 - val_root_mean_squared_error: 17.7305
# Epoch 58/60
# 241/241 [==============================] - 17s 70ms/step - loss: 322.5640 - root_mean_squared_error: 17.7930 - val_loss: 320.3316 - val_root_mean_squared_error: 17.7351
# Epoch 59/60
# 241/241 [==============================] - 17s 70ms/step - loss: 323.1862 - root_mean_squared_error: 17.8137 - val_loss: 320.6802 - val_root_mean_squared_error: 17.7400
# Epoch 60/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.1562 - root_mean_squared_error: 17.7827 - val_loss: 320.8270 - val_root_mean_squared_error: 17.7438
# 241/241 [==============================] - 3s 12ms/step - loss: 322.9417 - root_mean_squared_error: 17.8082
# 61/61 [==============================] - 1s 12ms/step - loss: 320.7293 - root_mean_squared_error: 17.7460
# Epoch 1/60
# 241/241 [==============================] - 20s 72ms/step - loss: 760.0954 - root_mean_squared_error: 24.4085 - val_loss: 628.6219 - val_root_mean_squared_error: 23.8733
# Epoch 2/60
# 241/241 [==============================] - 17s 71ms/step - loss: 564.3723 - root_mean_squared_error: 21.5982 - val_loss: 467.6507 - val_root_mean_squared_error: 20.2614
# Epoch 3/60
# 241/241 [==============================] - 17s 70ms/step - loss: 494.2445 - root_mean_squared_error: 20.6800 - val_loss: 425.0227 - val_root_mean_squared_error: 19.6088
# Epoch 4/60
# 241/241 [==============================] - 17s 70ms/step - loss: 437.9600 - root_mean_squared_error: 19.7450 - val_loss: 407.8701 - val_root_mean_squared_error: 19.4525
# Epoch 5/60
# 241/241 [==============================] - 17s 70ms/step - loss: 398.6341 - root_mean_squared_error: 19.0744 - val_loss: 360.1203 - val_root_mean_squared_error: 18.2812
# Epoch 6/60
# 241/241 [==============================] - 17s 70ms/step - loss: 373.9760 - root_mean_squared_error: 18.6142 - val_loss: 346.7476 - val_root_mean_squared_error: 17.9795
# Epoch 7/60
# 241/241 [==============================] - 17s 70ms/step - loss: 359.8004 - root_mean_squared_error: 18.3299 - val_loss: 339.7516 - val_root_mean_squared_error: 17.8258
# Epoch 8/60
# 241/241 [==============================] - 17s 70ms/step - loss: 352.1808 - root_mean_squared_error: 18.1860 - val_loss: 337.4662 - val_root_mean_squared_error: 17.8100
# Epoch 9/60
# 241/241 [==============================] - 17s 71ms/step - loss: 349.5641 - root_mean_squared_error: 18.1562 - val_loss: 341.2048 - val_root_mean_squared_error: 17.9571
# Epoch 10/60
# 241/241 [==============================] - 17s 72ms/step - loss: 345.0508 - root_mean_squared_error: 18.0852 - val_loss: 334.0512 - val_root_mean_squared_error: 17.8046
# Epoch 11/60
# 241/241 [==============================] - 17s 71ms/step - loss: 341.0853 - root_mean_squared_error: 18.0043 - val_loss: 333.6302 - val_root_mean_squared_error: 17.8113
# Epoch 12/60
# 241/241 [==============================] - 17s 71ms/step - loss: 342.5922 - root_mean_squared_error: 18.0879 - val_loss: 331.8209 - val_root_mean_squared_error: 17.8097
# Epoch 13/60
# 241/241 [==============================] - 17s 71ms/step - loss: 339.1868 - root_mean_squared_error: 18.0264 - val_loss: 329.9224 - val_root_mean_squared_error: 17.7756
# Epoch 14/60
# 241/241 [==============================] - 18s 73ms/step - loss: 337.6479 - root_mean_squared_error: 17.9973 - val_loss: 329.5193 - val_root_mean_squared_error: 17.7924
# Epoch 15/60
# 241/241 [==============================] - 17s 71ms/step - loss: 335.6911 - root_mean_squared_error: 17.9607 - val_loss: 328.6056 - val_root_mean_squared_error: 17.7864
# Epoch 16/60
# 241/241 [==============================] - 17s 71ms/step - loss: 335.9431 - root_mean_squared_error: 17.9911 - val_loss: 331.2776 - val_root_mean_squared_error: 17.8751
# Epoch 17/60
# 241/241 [==============================] - 17s 70ms/step - loss: 333.9019 - root_mean_squared_error: 17.9494 - val_loss: 328.9677 - val_root_mean_squared_error: 17.8173
# Epoch 18/60
# 241/241 [==============================] - 17s 71ms/step - loss: 333.7254 - root_mean_squared_error: 17.9537 - val_loss: 328.4406 - val_root_mean_squared_error: 17.8058
# Epoch 19/60
# 241/241 [==============================] - 17s 71ms/step - loss: 333.6951 - root_mean_squared_error: 17.9709 - val_loss: 327.4968 - val_root_mean_squared_error: 17.8043
# Epoch 20/60
# 241/241 [==============================] - 17s 71ms/step - loss: 331.6250 - root_mean_squared_error: 17.9295 - val_loss: 326.6533 - val_root_mean_squared_error: 17.7882
# Epoch 21/60
# 241/241 [==============================] - 17s 71ms/step - loss: 330.6636 - root_mean_squared_error: 17.9153 - val_loss: 326.0442 - val_root_mean_squared_error: 17.7893
# Epoch 22/60
# 241/241 [==============================] - 17s 71ms/step - loss: 329.6519 - root_mean_squared_error: 17.8981 - val_loss: 325.6065 - val_root_mean_squared_error: 17.7843
# Epoch 23/60
# 241/241 [==============================] - 17s 70ms/step - loss: 329.6971 - root_mean_squared_error: 17.9061 - val_loss: 325.6284 - val_root_mean_squared_error: 17.7968
# Epoch 24/60
# 241/241 [==============================] - 17s 70ms/step - loss: 328.6943 - root_mean_squared_error: 17.8844 - val_loss: 325.0093 - val_root_mean_squared_error: 17.7822
# Epoch 25/60
# 241/241 [==============================] - 17s 70ms/step - loss: 328.7121 - root_mean_squared_error: 17.8896 - val_loss: 325.8371 - val_root_mean_squared_error: 17.8085
# Epoch 26/60
# 241/241 [==============================] - 17s 71ms/step - loss: 328.2198 - root_mean_squared_error: 17.8809 - val_loss: 325.7304 - val_root_mean_squared_error: 17.8066
# Epoch 27/60
# 241/241 [==============================] - 17s 69ms/step - loss: 328.4099 - root_mean_squared_error: 17.8852 - val_loss: 324.5658 - val_root_mean_squared_error: 17.7857
# Epoch 28/60
# 241/241 [==============================] - 17s 70ms/step - loss: 327.7346 - root_mean_squared_error: 17.8748 - val_loss: 325.1743 - val_root_mean_squared_error: 17.8156
# Epoch 29/60
# 241/241 [==============================] - 17s 71ms/step - loss: 327.2499 - root_mean_squared_error: 17.8700 - val_loss: 324.7121 - val_root_mean_squared_error: 17.7983
# Epoch 30/60
# 241/241 [==============================] - 17s 71ms/step - loss: 327.2356 - root_mean_squared_error: 17.8700 - val_loss: 324.2465 - val_root_mean_squared_error: 17.7873
# Epoch 31/60
# 241/241 [==============================] - 17s 71ms/step - loss: 327.1431 - root_mean_squared_error: 17.8709 - val_loss: 324.2025 - val_root_mean_squared_error: 17.7928
# Epoch 32/60
# 241/241 [==============================] - 17s 70ms/step - loss: 326.8116 - root_mean_squared_error: 17.8634 - val_loss: 324.7815 - val_root_mean_squared_error: 17.8105
# Epoch 33/60
# 241/241 [==============================] - 17s 70ms/step - loss: 326.2982 - root_mean_squared_error: 17.8527 - val_loss: 324.8613 - val_root_mean_squared_error: 17.8122
# Epoch 34/60
# 241/241 [==============================] - 17s 72ms/step - loss: 326.2448 - root_mean_squared_error: 17.8493 - val_loss: 327.1631 - val_root_mean_squared_error: 17.8747
# Epoch 35/60
# 241/241 [==============================] - 17s 72ms/step - loss: 326.3424 - root_mean_squared_error: 17.8592 - val_loss: 325.2067 - val_root_mean_squared_error: 17.8303
# Epoch 36/60
# 241/241 [==============================] - 17s 72ms/step - loss: 325.3846 - root_mean_squared_error: 17.8370 - val_loss: 323.7632 - val_root_mean_squared_error: 17.7922
# Epoch 37/60
# 241/241 [==============================] - 17s 72ms/step - loss: 325.5781 - root_mean_squared_error: 17.8443 - val_loss: 324.3991 - val_root_mean_squared_error: 17.8085
# Epoch 38/60
# 241/241 [==============================] - 17s 71ms/step - loss: 325.7350 - root_mean_squared_error: 17.8453 - val_loss: 324.0599 - val_root_mean_squared_error: 17.7956
# Epoch 39/60
# 241/241 [==============================] - 17s 72ms/step - loss: 325.2758 - root_mean_squared_error: 17.8347 - val_loss: 323.3121 - val_root_mean_squared_error: 17.7861
# Epoch 40/60
# 241/241 [==============================] - 17s 72ms/step - loss: 325.3750 - root_mean_squared_error: 17.8451 - val_loss: 324.0319 - val_root_mean_squared_error: 17.8087
# Epoch 41/60
# 241/241 [==============================] - 17s 71ms/step - loss: 324.7820 - root_mean_squared_error: 17.8282 - val_loss: 322.9235 - val_root_mean_squared_error: 17.7758
# Epoch 42/60
# 241/241 [==============================] - 17s 72ms/step - loss: 325.2434 - root_mean_squared_error: 17.8463 - val_loss: 322.3012 - val_root_mean_squared_error: 17.7699
# Epoch 43/60
# 241/241 [==============================] - 17s 71ms/step - loss: 324.5377 - root_mean_squared_error: 17.8264 - val_loss: 323.0807 - val_root_mean_squared_error: 17.7876
# Epoch 44/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.5209 - root_mean_squared_error: 17.7993 - val_loss: 323.9504 - val_root_mean_squared_error: 17.8033
# Epoch 45/60
# 241/241 [==============================] - 17s 71ms/step - loss: 324.5103 - root_mean_squared_error: 17.8253 - val_loss: 323.3458 - val_root_mean_squared_error: 17.7967
# Epoch 46/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.7850 - root_mean_squared_error: 17.8064 - val_loss: 322.1979 - val_root_mean_squared_error: 17.7665
# Epoch 47/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.9510 - root_mean_squared_error: 17.8126 - val_loss: 323.6672 - val_root_mean_squared_error: 17.8042
# Epoch 48/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.1973 - root_mean_squared_error: 17.7950 - val_loss: 324.0981 - val_root_mean_squared_error: 17.8225
# Epoch 49/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.8024 - root_mean_squared_error: 17.8147 - val_loss: 326.2139 - val_root_mean_squared_error: 17.8703
# Epoch 50/60
# 241/241 [==============================] - 17s 71ms/step - loss: 323.4585 - root_mean_squared_error: 17.7994 - val_loss: 323.0605 - val_root_mean_squared_error: 17.7954
# Epoch 51/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.3675 - root_mean_squared_error: 17.7720 - val_loss: 322.9941 - val_root_mean_squared_error: 17.7935
# Epoch 52/60
# 241/241 [==============================] - 17s 70ms/step - loss: 322.7635 - root_mean_squared_error: 17.7897 - val_loss: 324.6155 - val_root_mean_squared_error: 17.8421
# Epoch 53/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.8466 - root_mean_squared_error: 17.7928 - val_loss: 322.9650 - val_root_mean_squared_error: 17.7971
# Epoch 54/60
# 241/241 [==============================] - 17s 70ms/step - loss: 322.8337 - root_mean_squared_error: 17.7942 - val_loss: 322.5301 - val_root_mean_squared_error: 17.7868
# Epoch 55/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.3448 - root_mean_squared_error: 17.7806 - val_loss: 322.3625 - val_root_mean_squared_error: 17.7802
# Epoch 56/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.8014 - root_mean_squared_error: 17.7905 - val_loss: 325.5876 - val_root_mean_squared_error: 17.8657
# Epoch 57/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.9044 - root_mean_squared_error: 17.7951 - val_loss: 322.5512 - val_root_mean_squared_error: 17.7911
# Epoch 58/60
# 241/241 [==============================] - 17s 72ms/step - loss: 322.0203 - root_mean_squared_error: 17.7726 - val_loss: 324.8546 - val_root_mean_squared_error: 17.8495
# Epoch 59/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.6409 - root_mean_squared_error: 17.7886 - val_loss: 323.9616 - val_root_mean_squared_error: 17.8131
# Epoch 60/60
# 241/241 [==============================] - 17s 71ms/step - loss: 322.6437 - root_mean_squared_error: 17.7927 - val_loss: 324.1232 - val_root_mean_squared_error: 17.8315
# 241/241 [==============================] - 3s 13ms/step - loss: 323.1656 - root_mean_squared_error: 17.8171
# 61/61 [==============================] - 1s 13ms/step - loss: 321.3533 - root_mean_squared_error: 17.7661

# %%
# Create overview of layers in model
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=40)
tf.keras.utils.plot_model(concat_model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')
