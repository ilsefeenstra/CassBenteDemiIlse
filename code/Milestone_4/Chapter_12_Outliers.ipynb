# %%
import zipfile
import os
import cv2
import pandas as pd
from os import chdir, listdir

import matplotlib.pyplot as plt
import numpy as np
import random

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing, regularizers
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-24 12:28:57--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-24 12:28:57--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [              <=>   ] 992.68M  22.6MB/s    in 44s
#
# 2022-01-24 12:29:42 (22.5 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1040898846]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# Create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis. After the images are imported, the images and their names are shuffled. This is done, so we can later take a validation sample containing a random subsample of the dataset. It could be that the images in the dataset contain some order, so by shuffling we ensure that the subset for the validation data is random.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %%
# Zip train image data and names
combined = list(zip(train_imgs, train_names))

# Make sure shuffle is the same each time
random.seed(4)

# Shuffle the image data
random.shuffle(combined)

# Unzip the train images and names
train_imgs, train_names = zip(*combined)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])

        # Reset the index of the dataframe
        data_sorted = data_sorted.reset_index().drop(['index'],axis=1)
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

train_data_sorted.head()
# Out:
#                                  Id  Subject Focus  ...  Blur  Pawpularity
# 0  2aa77fd805946abddd9a71adb926c90f              0  ...     0           37
# 1  3b61d75bd66a1ad2cb8aaf3cdd740fba              0  ...     0           31
# 2  0cde0d7f02c6d60e901c653607556b21              0  ...     0           39
# 3  5a22c19ce1f3a3ceee0694304152ecae              0  ...     0           44
# 4  a458eaf4f413010702b0e86cf6872e98              1  ...     0           29
#
# [5 rows x 14 columns]

# %% [markdown]
# # Processing data
# First we split the data in a train and validation set, where 20% of the data is put in the validation set. Then the image data is converted to numpy arrays, so they can be used in the neural networks. The tabular data is split in the x and y values and also converted to numpy arrays.

# %%
# split the dataset into training and validation set
split_threshold = int(0.2 * len(train_names))

val_tabular = train_data_sorted[:split_threshold]
train_tabular = train_data_sorted[split_threshold:]

val_images = train_imgs[:split_threshold]
train_images = train_imgs[split_threshold:]

# %%
# Make numpy arrays of images for further analysis
train_imgs_array = np.array(train_images)
val_imgs_array = np.array(val_images)
test_imgs_array = np.array(test_imgs)

# %%
# Select x (the 12 input features) and y (pawpularity) values from training data
x_train_tabular = train_tabular.iloc[:,1:13].to_numpy()
y_train = train_tabular.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from validation data
x_val_tabular = val_tabular.iloc[:,1:13].to_numpy()
y_val = val_tabular.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create hidden layer with relu activations
    model.add(layers.Dense(units=hidden_nodes, activation='relu', input_shape=(input_size,)))    

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    # Create hidden layer with relu activations
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(units=hidden_nodes, activation="relu"))

    return model

# Create neural network for tabular data and get summary of model 
# with 12 inputs and 100 hidden nodes
tabular_NN = build_neural_net(12, hidden_nodes=20)
tabular_NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                260
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_2 (Dense)             (None, 20)                420
#
# =================================================================
# Total params: 1,100
# Trainable params: 1,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with relu activation
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=image_size, padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(.4))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with relu activation
    model.add(layers.Dropout(.4))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with relu activations
    model.add(layers.Dropout(.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))

    # Create a dense layer with relu activations
    model.add(layers.Dropout(.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu",
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))
    
    return model

# %%
# Create neural network for image data and get summary of model
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size, hidden_nodes=20)
image_NN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dropout_4 (Dropout)         (None, 16384)             0
#
#  dense_3 (Dense)             (None, 20)                327700
#
#  dropout_5 (Dropout)         (None, 20)                0
#
#  dense_4 (Dense)             (None, 20)                420
#
# =================================================================
# Total params: 700,728
# Trainable params: 699,832
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
from keras import backend as K
from keras import activations

def linear_limit(x):
  activation_x = activations.linear(x)
  activation_x_new = K.clip(activation_x, 0, 100)
  return activation_x_new

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layer with relu activation
    hidden_layer_1 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(concat_input)

    # Create hidden layer with relu activation
    drop_out_1 = layers.Dropout(.4)(hidden_layer_1)    
    hidden_layer_2 = layers.Dense(hidden_nodes, activation="relu",
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_1)

    # Create hidden layer with relu activation
    drop_out_2 = layers.Dropout(.4)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(hidden_nodes, activation="relu",
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_2)

    # Create output layer
    output_layer = layers.Dense(1, activation=linear_limit)(hidden_layer_3)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
# Part of code from: https://www.tensorflow.org/tutorials/keras/regression

def plot_loss(history):
    """
    Plot loss during epochs of training a neural network.
    """
    
    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    for i, metric in enumerate(['loss', 'root_mean_squared_error']):
        axs[i].plot(history.history[metric])
        axs[i].plot(history.history['val_'+metric])
        axs[i].legend(['training', 'validation'], loc='best')

        axs[i].set_title('Model '+metric)
        axs[i].set_ylabel(metric)
        axs[i].set_xlabel('epoch')

    plt.show()


def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
  """
  This function trains and evaluated a model. It first compiles the model with 
  the loss and metrics. It then makes a train and validation generator for the 
  image data, based on the preprocess and augment input. 
  It then trains the model on both the image and tabular data for epochs times. 
  The values of the loss and metric are plotted and printed.
  """

  # Compile model and use mean squared error as loss and root mean squared error as metric
  model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

  # Preprocess the image data
  train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
  train_gen.fit(image_x)

  val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
  val_gen.fit(image_x)

  # Train the model by fitting both tabular and image data at the same time
  history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs=epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

  # Plot the loss and metric
  plot_loss(history)

  print(f"Validation Accuracy: {model.evaluate(val_gen.flow([x_val_imgs, x_val_tabular], val_y))[1]}")

# Concatenate tabular and image neural networks
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)

# Train model on both tabular and image data and preprocess
train_and_evaluate(concat_model, train_imgs_array, x_train_tabular, y_train, 
                   x_val_tabular, val_imgs_array, y_val,
                   preprocess={'featurewise_center': True, 'featurewise_std_normalization': True}, epochs=60)

# See how the model scored on the testing data
loss = concat_model.evaluate([test_imgs_array, x_test_tabular], y_test)
print(f'Test loss: {loss}')
# Out:
# Epoch 1/60
# 248/248 [==============================] - 12s 37ms/step - loss: 956.6514 - root_mean_squared_error: 27.8868 - val_loss: 679.8890 - val_root_mean_squared_error: 24.7612
# Epoch 2/60
# 248/248 [==============================] - 9s 35ms/step - loss: 572.3050 - root_mean_squared_error: 21.6477 - val_loss: 606.3047 - val_root_mean_squared_error: 23.7393
# Epoch 3/60
# 248/248 [==============================] - 9s 35ms/step - loss: 459.8351 - root_mean_squared_error: 19.8144 - val_loss: 522.4478 - val_root_mean_squared_error: 22.0828
# Epoch 4/60
# 248/248 [==============================] - 9s 35ms/step - loss: 397.0017 - root_mean_squared_error: 18.6356 - val_loss: 497.0098 - val_root_mean_squared_error: 21.5207
# Epoch 5/60
# 248/248 [==============================] - 9s 35ms/step - loss: 364.5430 - root_mean_squared_error: 17.9900 - val_loss: 489.1782 - val_root_mean_squared_error: 21.4780
# Epoch 6/60
# 248/248 [==============================] - 9s 35ms/step - loss: 328.4305 - root_mean_squared_error: 17.1154 - val_loss: 475.9091 - val_root_mean_squared_error: 21.2147
# Epoch 7/60
# 248/248 [==============================] - 9s 35ms/step - loss: 317.7100 - root_mean_squared_error: 16.9070 - val_loss: 472.0718 - val_root_mean_squared_error: 21.1849
# Epoch 8/60
# 248/248 [==============================] - 9s 35ms/step - loss: 292.2506 - root_mean_squared_error: 16.1916 - val_loss: 467.4605 - val_root_mean_squared_error: 21.0955
# Epoch 9/60
# 248/248 [==============================] - 9s 35ms/step - loss: 285.2402 - root_mean_squared_error: 16.0443 - val_loss: 478.4166 - val_root_mean_squared_error: 21.3917
# Epoch 10/60
# 248/248 [==============================] - 9s 36ms/step - loss: 286.9683 - root_mean_squared_error: 16.1539 - val_loss: 470.2892 - val_root_mean_squared_error: 21.2358
# Epoch 11/60
# 248/248 [==============================] - 9s 35ms/step - loss: 263.7080 - root_mean_squared_error: 15.4385 - val_loss: 481.5541 - val_root_mean_squared_error: 21.4997
# Epoch 12/60
# 248/248 [==============================] - 9s 35ms/step - loss: 260.1982 - root_mean_squared_error: 15.3675 - val_loss: 468.3051 - val_root_mean_squared_error: 21.2155
# Epoch 13/60
# 248/248 [==============================] - 9s 36ms/step - loss: 260.5740 - root_mean_squared_error: 15.4029 - val_loss: 481.6403 - val_root_mean_squared_error: 21.5222
# Epoch 14/60
# 248/248 [==============================] - 9s 35ms/step - loss: 250.8564 - root_mean_squared_error: 15.0969 - val_loss: 465.5146 - val_root_mean_squared_error: 21.1779
# Epoch 15/60
# 248/248 [==============================] - 9s 36ms/step - loss: 246.9664 - root_mean_squared_error: 14.9944 - val_loss: 474.0525 - val_root_mean_squared_error: 21.3830
# Epoch 16/60
# 248/248 [==============================] - 9s 36ms/step - loss: 236.2264 - root_mean_squared_error: 14.6489 - val_loss: 478.3026 - val_root_mean_squared_error: 21.4907
# Epoch 17/60
# 248/248 [==============================] - 9s 35ms/step - loss: 230.3611 - root_mean_squared_error: 14.4649 - val_loss: 479.3353 - val_root_mean_squared_error: 21.5169
# Epoch 18/60
# 248/248 [==============================] - 9s 35ms/step - loss: 224.9297 - root_mean_squared_error: 14.2787 - val_loss: 468.7484 - val_root_mean_squared_error: 21.2927
# Epoch 19/60
# 248/248 [==============================] - 9s 35ms/step - loss: 234.2608 - root_mean_squared_error: 14.6314 - val_loss: 465.2257 - val_root_mean_squared_error: 21.1915
# Epoch 20/60
# 248/248 [==============================] - 9s 35ms/step - loss: 221.9702 - root_mean_squared_error: 14.2010 - val_loss: 477.0366 - val_root_mean_squared_error: 21.4840
# Epoch 21/60
# 248/248 [==============================] - 9s 35ms/step - loss: 218.3394 - root_mean_squared_error: 14.0850 - val_loss: 458.5978 - val_root_mean_squared_error: 21.0538
# Epoch 22/60
# 248/248 [==============================] - 9s 35ms/step - loss: 214.5945 - root_mean_squared_error: 13.9509 - val_loss: 468.4786 - val_root_mean_squared_error: 21.2862
# Epoch 23/60
# 248/248 [==============================] - 9s 35ms/step - loss: 210.4282 - root_mean_squared_error: 13.8112 - val_loss: 473.3345 - val_root_mean_squared_error: 21.4253
# Epoch 24/60
# 248/248 [==============================] - 9s 35ms/step - loss: 213.6356 - root_mean_squared_error: 13.9439 - val_loss: 467.8689 - val_root_mean_squared_error: 21.2876
# Epoch 25/60
# 248/248 [==============================] - 9s 35ms/step - loss: 209.0001 - root_mean_squared_error: 13.7830 - val_loss: 465.9464 - val_root_mean_squared_error: 21.2399
# Epoch 26/60
# 248/248 [==============================] - 9s 35ms/step - loss: 204.8085 - root_mean_squared_error: 13.6306 - val_loss: 465.0922 - val_root_mean_squared_error: 21.2380
# Epoch 27/60
# 248/248 [==============================] - 9s 35ms/step - loss: 205.6857 - root_mean_squared_error: 13.6723 - val_loss: 467.4055 - val_root_mean_squared_error: 21.2930
# Epoch 28/60
# 248/248 [==============================] - 9s 35ms/step - loss: 211.4149 - root_mean_squared_error: 13.8836 - val_loss: 466.6492 - val_root_mean_squared_error: 21.2845
# Epoch 29/60
# 248/248 [==============================] - 9s 35ms/step - loss: 204.4612 - root_mean_squared_error: 13.6406 - val_loss: 458.1520 - val_root_mean_squared_error: 21.0763
# Epoch 30/60
# 248/248 [==============================] - 9s 34ms/step - loss: 199.5289 - root_mean_squared_error: 13.4694 - val_loss: 460.2629 - val_root_mean_squared_error: 21.1403
# Epoch 31/60
# 248/248 [==============================] - 9s 35ms/step - loss: 199.6690 - root_mean_squared_error: 13.4809 - val_loss: 466.3073 - val_root_mean_squared_error: 21.2837
# Epoch 32/60
# 248/248 [==============================] - 9s 35ms/step - loss: 199.0270 - root_mean_squared_error: 13.4670 - val_loss: 472.0193 - val_root_mean_squared_error: 21.4144
# Epoch 33/60
# 248/248 [==============================] - 9s 35ms/step - loss: 199.1870 - root_mean_squared_error: 13.4739 - val_loss: 463.0246 - val_root_mean_squared_error: 21.2003
# Epoch 34/60
# 248/248 [==============================] - 9s 36ms/step - loss: 199.7259 - root_mean_squared_error: 13.4942 - val_loss: 459.1410 - val_root_mean_squared_error: 21.1183
# Epoch 35/60
# 248/248 [==============================] - 9s 35ms/step - loss: 195.6385 - root_mean_squared_error: 13.3398 - val_loss: 456.9853 - val_root_mean_squared_error: 21.0696
# Epoch 36/60
# 248/248 [==============================] - 9s 34ms/step - loss: 193.0165 - root_mean_squared_error: 13.2621 - val_loss: 462.8305 - val_root_mean_squared_error: 21.2177
# Epoch 37/60
# 248/248 [==============================] - 9s 34ms/step - loss: 200.5634 - root_mean_squared_error: 13.5507 - val_loss: 455.0578 - val_root_mean_squared_error: 21.0170
# Epoch 38/60
# 248/248 [==============================] - 9s 35ms/step - loss: 189.1593 - root_mean_squared_error: 13.1140 - val_loss: 470.4112 - val_root_mean_squared_error: 21.3975
# Epoch 39/60
# 248/248 [==============================] - 9s 35ms/step - loss: 195.3917 - root_mean_squared_error: 13.3607 - val_loss: 458.9622 - val_root_mean_squared_error: 21.1276
# Epoch 40/60
# 248/248 [==============================] - 9s 35ms/step - loss: 185.6732 - root_mean_squared_error: 12.9910 - val_loss: 455.7538 - val_root_mean_squared_error: 21.0549
# Epoch 41/60
# 248/248 [==============================] - 9s 35ms/step - loss: 189.7790 - root_mean_squared_error: 13.1595 - val_loss: 459.5443 - val_root_mean_squared_error: 21.1371
# Epoch 42/60
# 248/248 [==============================] - 9s 35ms/step - loss: 183.5080 - root_mean_squared_error: 12.9162 - val_loss: 459.6876 - val_root_mean_squared_error: 21.1465
# Epoch 43/60
# 248/248 [==============================] - 9s 35ms/step - loss: 183.4150 - root_mean_squared_error: 12.9188 - val_loss: 461.1952 - val_root_mean_squared_error: 21.1740
# Epoch 44/60
# 248/248 [==============================] - 9s 35ms/step - loss: 187.0548 - root_mean_squared_error: 13.0655 - val_loss: 461.6896 - val_root_mean_squared_error: 21.1976
# Epoch 45/60
# 248/248 [==============================] - 9s 35ms/step - loss: 180.5677 - root_mean_squared_error: 12.8167 - val_loss: 458.2958 - val_root_mean_squared_error: 21.1175
# Epoch 46/60
# 248/248 [==============================] - 9s 35ms/step - loss: 184.9681 - root_mean_squared_error: 12.9840 - val_loss: 462.5588 - val_root_mean_squared_error: 21.2169
# Epoch 47/60
# 248/248 [==============================] - 9s 35ms/step - loss: 179.8582 - root_mean_squared_error: 12.7878 - val_loss: 466.0317 - val_root_mean_squared_error: 21.3063
# Epoch 48/60
# 248/248 [==============================] - 9s 35ms/step - loss: 177.1352 - root_mean_squared_error: 12.6817 - val_loss: 468.0813 - val_root_mean_squared_error: 21.3467
# Epoch 49/60
# 248/248 [==============================] - 9s 35ms/step - loss: 174.8939 - root_mean_squared_error: 12.5941 - val_loss: 458.4324 - val_root_mean_squared_error: 21.1184
# Epoch 50/60
# 248/248 [==============================] - 9s 36ms/step - loss: 177.5871 - root_mean_squared_error: 12.7032 - val_loss: 463.9898 - val_root_mean_squared_error: 21.2576
# Epoch 51/60
# 248/248 [==============================] - 9s 35ms/step - loss: 177.0545 - root_mean_squared_error: 12.6822 - val_loss: 464.4546 - val_root_mean_squared_error: 21.2664
# Epoch 52/60
# 248/248 [==============================] - 9s 35ms/step - loss: 181.7172 - root_mean_squared_error: 12.8701 - val_loss: 479.2909 - val_root_mean_squared_error: 21.6043
# Epoch 53/60
# 248/248 [==============================] - 9s 35ms/step - loss: 172.5269 - root_mean_squared_error: 12.5058 - val_loss: 463.8945 - val_root_mean_squared_error: 21.2502
# Epoch 54/60
# 248/248 [==============================] - 9s 35ms/step - loss: 180.0695 - root_mean_squared_error: 12.8119 - val_loss: 469.1928 - val_root_mean_squared_error: 21.3774
# Epoch 55/60
# 248/248 [==============================] - 9s 35ms/step - loss: 170.9189 - root_mean_squared_error: 12.4447 - val_loss: 481.3168 - val_root_mean_squared_error: 21.6560
# Epoch 56/60
# 248/248 [==============================] - 9s 35ms/step - loss: 177.4752 - root_mean_squared_error: 12.7102 - val_loss: 459.7091 - val_root_mean_squared_error: 21.1592
# Epoch 57/60
# 248/248 [==============================] - 9s 35ms/step - loss: 171.7600 - root_mean_squared_error: 12.4838 - val_loss: 463.5678 - val_root_mean_squared_error: 21.2454
# Epoch 58/60
# 248/248 [==============================] - 9s 35ms/step - loss: 173.7845 - root_mean_squared_error: 12.5616 - val_loss: 471.1556 - val_root_mean_squared_error: 21.4245
# Epoch 59/60
# 248/248 [==============================] - 9s 35ms/step - loss: 168.8444 - root_mean_squared_error: 12.3682 - val_loss: 466.9948 - val_root_mean_squared_error: 21.3268
# Epoch 60/60
# 248/248 [==============================] - 9s 35ms/step - loss: 162.9925 - root_mean_squared_error: 12.1275 - val_loss: 461.7123 - val_root_mean_squared_error: 21.2092
# 62/62 [==============================] - 1s 14ms/step - loss: 461.7123 - root_mean_squared_error: 21.2092
# Validation Accuracy: 21.20920753479004
# 1/1 [==============================] - 0s 418ms/step - loss: 1931.4008 - root_mean_squared_error: 43.8229
# Test loss: [1931.4007568359375, 43.82285690307617]

# %%
# Create overview of layers in model
tf.keras.utils.plot_model(concat_model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')

# %%
# Calculate squared error per sample
predictions = concat_model.predict([train_imgs_array, x_train_tabular])
difference = np.subtract(predictions, y_train)
squared_difference = np.square(difference)

# %%
# Plot distribution of predictions
plt.hist(predictions)
plt.title('Distribution of predictions of the model')
plt.xlabel('Pawpularity score')
plt.ylabel('Occurence')
plt.show()

# %%
# Plot squared error
plt.hist(squared_error)
plt.title('Distribution of squared error of the model')
plt.xlabel('Squared error')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot difference
plt.hist(difference)
plt.title('Distribution of difference of the model')
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.show()

# %%
# Remove samples with pawpularity score of 100
indexNames = train_data_sorted[ train_data_sorted['Pawpularity'] == 100 ].index
train_data_new = train_data_sorted.drop(indexNames)
train_imgs_new = np.delete(train_imgs, indexNames, axis=0)
# Out:
# (9912, 64, 64, 3)
# (9624, 64, 64, 3) 9624

# %%
# split the dataset into training and validation set
split_threshold = int(0.2 * len(train_names))

val_tabular = train_data_new[:split_threshold]
train_tabular = train_data_new[split_threshold:]

val_images = train_imgs_new[:split_threshold]
train_images = train_imgs_new[split_threshold:]

# %%
# Make numpy arrays of images for further analysis
train_imgs_array = np.array(train_images)
val_imgs_array = np.array(val_images)
test_imgs_array = np.array(test_imgs)

# %%
# Select x (the 12 input features) and y (pawpularity) values from training data
x_train_tabular = train_tabular.iloc[:,1:13].to_numpy()
y_train = train_tabular.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from validation data
x_val_tabular = val_tabular.iloc[:,1:13].to_numpy()
y_val = val_tabular.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# %%
# Concatenate tabular and image neural networks
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)

# Train model on both tabular and image data and preprocess
train_and_evaluate(concat_model, train_imgs_array, x_train_tabular, y_train, 
                   x_val_tabular, val_imgs_array, y_val,
                   preprocess={'featurewise_center': True, 'featurewise_std_normalization': True}, epochs=60)

# See how the model scored on the testing data
loss = concat_model.evaluate([test_imgs_array, x_test_tabular], y_test)
print(f'Test loss: {loss}')
# Out:
# Epoch 1/60
# 239/239 [==============================] - 11s 36ms/step - loss: 934.4073 - root_mean_squared_error: 28.0341 - val_loss: 579.8539 - val_root_mean_squared_error: 22.7183
# Epoch 2/60
# 239/239 [==============================] - 8s 34ms/step - loss: 599.1347 - root_mean_squared_error: 22.6025 - val_loss: 588.2149 - val_root_mean_squared_error: 23.5564
# Epoch 3/60
# 239/239 [==============================] - 8s 34ms/step - loss: 498.7958 - root_mean_squared_error: 20.9855 - val_loss: 462.2648 - val_root_mean_squared_error: 20.8012
# Epoch 4/60
# 239/239 [==============================] - 8s 34ms/step - loss: 435.2207 - root_mean_squared_error: 19.8944 - val_loss: 382.8654 - val_root_mean_squared_error: 18.9103
# Epoch 5/60
# 239/239 [==============================] - 8s 34ms/step - loss: 393.6868 - root_mean_squared_error: 19.0820 - val_loss: 344.5617 - val_root_mean_squared_error: 17.9058
# Epoch 6/60
# 239/239 [==============================] - 8s 33ms/step - loss: 369.2750 - root_mean_squared_error: 18.5627 - val_loss: 337.9778 - val_root_mean_squared_error: 17.7843
# Epoch 7/60
# 239/239 [==============================] - 8s 34ms/step - loss: 361.9072 - root_mean_squared_error: 18.4395 - val_loss: 334.4767 - val_root_mean_squared_error: 17.7135
# Epoch 8/60
# 239/239 [==============================] - 8s 34ms/step - loss: 354.8918 - root_mean_squared_error: 18.2909 - val_loss: 334.0882 - val_root_mean_squared_error: 17.7584
# Epoch 9/60
# 239/239 [==============================] - 8s 33ms/step - loss: 351.0931 - root_mean_squared_error: 18.2232 - val_loss: 334.6302 - val_root_mean_squared_error: 17.8213
# Epoch 10/60
# 239/239 [==============================] - 8s 34ms/step - loss: 343.3028 - root_mean_squared_error: 18.0331 - val_loss: 333.8845 - val_root_mean_squared_error: 17.8121
# Epoch 11/60
# 239/239 [==============================] - 8s 34ms/step - loss: 336.6618 - root_mean_squared_error: 17.8674 - val_loss: 332.5245 - val_root_mean_squared_error: 17.7974
# Epoch 12/60
# 239/239 [==============================] - 8s 34ms/step - loss: 326.8766 - root_mean_squared_error: 17.6130 - val_loss: 332.4635 - val_root_mean_squared_error: 17.8192
# Epoch 13/60
# 239/239 [==============================] - 8s 33ms/step - loss: 323.0067 - root_mean_squared_error: 17.5195 - val_loss: 331.9603 - val_root_mean_squared_error: 17.8066
# Epoch 14/60
# 239/239 [==============================] - 8s 34ms/step - loss: 313.4420 - root_mean_squared_error: 17.2547 - val_loss: 334.4928 - val_root_mean_squared_error: 17.8958
# Epoch 15/60
# 239/239 [==============================] - 8s 34ms/step - loss: 307.7816 - root_mean_squared_error: 17.1022 - val_loss: 337.3846 - val_root_mean_squared_error: 17.9734
# Epoch 16/60
# 239/239 [==============================] - 8s 34ms/step - loss: 297.6539 - root_mean_squared_error: 16.8106 - val_loss: 331.1413 - val_root_mean_squared_error: 17.8269
# Epoch 17/60
# 239/239 [==============================] - 8s 33ms/step - loss: 286.8788 - root_mean_squared_error: 16.4946 - val_loss: 337.7928 - val_root_mean_squared_error: 17.9997
# Epoch 18/60
# 239/239 [==============================] - 8s 33ms/step - loss: 284.7739 - root_mean_squared_error: 16.4384 - val_loss: 336.6726 - val_root_mean_squared_error: 17.9713
# Epoch 19/60
# 239/239 [==============================] - 8s 34ms/step - loss: 277.0223 - root_mean_squared_error: 16.2093 - val_loss: 343.5021 - val_root_mean_squared_error: 18.1612
# Epoch 20/60
# 239/239 [==============================] - 8s 33ms/step - loss: 273.6438 - root_mean_squared_error: 16.1092 - val_loss: 332.5223 - val_root_mean_squared_error: 17.8855
# Epoch 21/60
# 239/239 [==============================] - 8s 34ms/step - loss: 268.2948 - root_mean_squared_error: 15.9468 - val_loss: 334.7849 - val_root_mean_squared_error: 17.9516
# Epoch 22/60
# 239/239 [==============================] - 8s 33ms/step - loss: 260.9175 - root_mean_squared_error: 15.7169 - val_loss: 334.8227 - val_root_mean_squared_error: 17.9597
# Epoch 23/60
# 239/239 [==============================] - 8s 33ms/step - loss: 258.5017 - root_mean_squared_error: 15.6492 - val_loss: 341.3833 - val_root_mean_squared_error: 18.1498
# Epoch 24/60
# 239/239 [==============================] - 8s 33ms/step - loss: 254.5967 - root_mean_squared_error: 15.5329 - val_loss: 361.2565 - val_root_mean_squared_error: 18.6534
# Epoch 25/60
# 239/239 [==============================] - 8s 34ms/step - loss: 248.1527 - root_mean_squared_error: 15.3217 - val_loss: 341.8042 - val_root_mean_squared_error: 18.1700
# Epoch 26/60
# 239/239 [==============================] - 8s 34ms/step - loss: 244.0925 - root_mean_squared_error: 15.1976 - val_loss: 341.0118 - val_root_mean_squared_error: 18.1545
# Epoch 27/60
# 239/239 [==============================] - 8s 34ms/step - loss: 237.9075 - root_mean_squared_error: 14.9885 - val_loss: 339.6160 - val_root_mean_squared_error: 18.1234
# Epoch 28/60
# 239/239 [==============================] - 8s 33ms/step - loss: 238.2464 - root_mean_squared_error: 15.0116 - val_loss: 370.1448 - val_root_mean_squared_error: 18.9173
# Epoch 29/60
# 239/239 [==============================] - 8s 34ms/step - loss: 232.1682 - root_mean_squared_error: 14.8013 - val_loss: 348.0199 - val_root_mean_squared_error: 18.3502
# Epoch 30/60
# 239/239 [==============================] - 8s 34ms/step - loss: 222.8584 - root_mean_squared_error: 14.4853 - val_loss: 352.1502 - val_root_mean_squared_error: 18.4576
# Epoch 31/60
# 239/239 [==============================] - 8s 33ms/step - loss: 222.5808 - root_mean_squared_error: 14.4856 - val_loss: 349.1038 - val_root_mean_squared_error: 18.3863
# Epoch 32/60
# 239/239 [==============================] - 8s 33ms/step - loss: 220.5748 - root_mean_squared_error: 14.4180 - val_loss: 341.0474 - val_root_mean_squared_error: 18.1735
# Epoch 33/60
# 239/239 [==============================] - 8s 33ms/step - loss: 214.7576 - root_mean_squared_error: 14.2147 - val_loss: 344.2069 - val_root_mean_squared_error: 18.2671
# Epoch 34/60
# 239/239 [==============================] - 8s 33ms/step - loss: 209.1578 - root_mean_squared_error: 14.0228 - val_loss: 336.7622 - val_root_mean_squared_error: 18.0669
# Epoch 35/60
# 239/239 [==============================] - 8s 34ms/step - loss: 205.2945 - root_mean_squared_error: 13.8828 - val_loss: 349.1168 - val_root_mean_squared_error: 18.3994
# Epoch 36/60
# 239/239 [==============================] - 8s 33ms/step - loss: 207.4786 - root_mean_squared_error: 13.9648 - val_loss: 353.9221 - val_root_mean_squared_error: 18.5226
# Epoch 37/60
# 239/239 [==============================] - 8s 34ms/step - loss: 206.1533 - root_mean_squared_error: 13.9197 - val_loss: 343.3024 - val_root_mean_squared_error: 18.2531
# Epoch 38/60
# 239/239 [==============================] - 8s 33ms/step - loss: 198.5273 - root_mean_squared_error: 13.6426 - val_loss: 346.7509 - val_root_mean_squared_error: 18.3478
# Epoch 39/60
# 239/239 [==============================] - 8s 34ms/step - loss: 202.8608 - root_mean_squared_error: 13.8020 - val_loss: 343.5907 - val_root_mean_squared_error: 18.2535
# Epoch 40/60
# 239/239 [==============================] - 8s 33ms/step - loss: 201.9354 - root_mean_squared_error: 13.7756 - val_loss: 353.8494 - val_root_mean_squared_error: 18.5308
# Epoch 41/60
# 239/239 [==============================] - 8s 33ms/step - loss: 188.1279 - root_mean_squared_error: 13.2621 - val_loss: 346.0386 - val_root_mean_squared_error: 18.3260
# Epoch 42/60
# 239/239 [==============================] - 8s 33ms/step - loss: 188.2160 - root_mean_squared_error: 13.2634 - val_loss: 348.1960 - val_root_mean_squared_error: 18.3859
# Epoch 43/60
# 239/239 [==============================] - 8s 33ms/step - loss: 190.1766 - root_mean_squared_error: 13.3428 - val_loss: 355.0797 - val_root_mean_squared_error: 18.5688
# Epoch 44/60
# 239/239 [==============================] - 8s 33ms/step - loss: 188.3993 - root_mean_squared_error: 13.2780 - val_loss: 345.3448 - val_root_mean_squared_error: 18.3177
# Epoch 45/60
# 239/239 [==============================] - 8s 34ms/step - loss: 183.4410 - root_mean_squared_error: 13.0885 - val_loss: 350.5845 - val_root_mean_squared_error: 18.4534
# Epoch 46/60
# 239/239 [==============================] - 8s 34ms/step - loss: 184.2741 - root_mean_squared_error: 13.1224 - val_loss: 353.6861 - val_root_mean_squared_error: 18.5370
# Epoch 47/60
# 239/239 [==============================] - 8s 34ms/step - loss: 188.3640 - root_mean_squared_error: 13.2779 - val_loss: 350.3787 - val_root_mean_squared_error: 18.4468
# Epoch 48/60
# 239/239 [==============================] - 8s 34ms/step - loss: 181.2774 - root_mean_squared_error: 13.0071 - val_loss: 353.4130 - val_root_mean_squared_error: 18.5422
# Epoch 49/60
# 239/239 [==============================] - 8s 34ms/step - loss: 172.3245 - root_mean_squared_error: 12.6513 - val_loss: 358.2938 - val_root_mean_squared_error: 18.6588
# Epoch 50/60
# 239/239 [==============================] - 8s 34ms/step - loss: 185.6605 - root_mean_squared_error: 13.1737 - val_loss: 355.1143 - val_root_mean_squared_error: 18.5766
# Epoch 51/60
# 239/239 [==============================] - 8s 34ms/step - loss: 180.3307 - root_mean_squared_error: 12.9683 - val_loss: 346.2742 - val_root_mean_squared_error: 18.3484
# Epoch 52/60
# 239/239 [==============================] - 8s 33ms/step - loss: 171.3403 - root_mean_squared_error: 12.6139 - val_loss: 354.4860 - val_root_mean_squared_error: 18.5683
# Epoch 53/60
# 239/239 [==============================] - 8s 34ms/step - loss: 169.5886 - root_mean_squared_error: 12.5414 - val_loss: 354.5562 - val_root_mean_squared_error: 18.5723
# Epoch 54/60
# 239/239 [==============================] - 8s 34ms/step - loss: 171.2234 - root_mean_squared_error: 12.6118 - val_loss: 352.0740 - val_root_mean_squared_error: 18.5081
# Epoch 55/60
# 239/239 [==============================] - 8s 34ms/step - loss: 172.7427 - root_mean_squared_error: 12.6772 - val_loss: 349.3377 - val_root_mean_squared_error: 18.4293
# Epoch 56/60
# 239/239 [==============================] - 8s 34ms/step - loss: 169.5290 - root_mean_squared_error: 12.5447 - val_loss: 347.5758 - val_root_mean_squared_error: 18.3867
# Epoch 57/60
# 239/239 [==============================] - 8s 34ms/step - loss: 166.2159 - root_mean_squared_error: 12.4181 - val_loss: 356.7697 - val_root_mean_squared_error: 18.6331
# Epoch 58/60
# 239/239 [==============================] - 8s 34ms/step - loss: 162.3386 - root_mean_squared_error: 12.2564 - val_loss: 350.3284 - val_root_mean_squared_error: 18.4632
# Epoch 59/60
# 239/239 [==============================] - 8s 34ms/step - loss: 163.0530 - root_mean_squared_error: 12.2810 - val_loss: 359.4760 - val_root_mean_squared_error: 18.7019
# Epoch 60/60
# 239/239 [==============================] - 8s 34ms/step - loss: 165.4184 - root_mean_squared_error: 12.3765 - val_loss: 360.7674 - val_root_mean_squared_error: 18.7415
# 62/62 [==============================] - 1s 12ms/step - loss: 360.7673 - root_mean_squared_error: 18.7415
# Validation Accuracy: 18.74151611328125
# 1/1 [==============================] - 0s 374ms/step - loss: 1449.0092 - root_mean_squared_error: 37.9277
# Test loss: [1449.0091552734375, 37.927730560302734]

# %%
predictions = concat_model.predict([train_imgs_array, x_train_tabular])
difference = np.subtract(predictions, y_train)
squared_difference = np.square(difference)

plt.hist(squared_difference)
plt.title('Distribution of squared error of the model')
plt.xlabel('Squared error')
plt.ylabel('Frequency')
plt.xlim([0, 4500])
plt.show()

# %%
plt.hist(difference)
plt.title('Distribution of squared error of the model')
plt.xlabel('Squared error')
plt.ylabel('Frequency')
plt.show()
