# %% [markdown]
# # Simple tabular neural network
# In this chapter we will make the tabular neural network simpler to check if it still works as well.

# %%
import zipfile
import cv2
import pandas as pd
from os import chdir, listdir

import matplotlib.pyplot as plt
import numpy as np
import random

import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing, regularizers
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from keras import backend as K
from keras import activations

from sklearn.model_selection import KFold

# %% [markdown]
# # Import zip with the data
# The data is imported as a zip from the github of our project group. The zip is unpacked in the google colab, so the data is accesible.

# %%
# Code from: https://towardsdatascience.com/an-informative-colab-guide-to-load-image-datasets-from-github-kaggle-and-local-machine-75cae89ffa1e

# Get zip file from Github URL
# !wget --no-check-certificate \
    "https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip" \
    -O "/tmp/pawpularity_data.zip"

# Opens the zip file in read mode and extract files into /tmp folder
zip_ref = zipfile.ZipFile('/tmp/pawpularity_data.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-01-26 13:44:03--  https://github.com/ilsefeenstra/Fitgirls0011/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main [following]
# --2022-01-26 13:44:03--  https://codeload.github.com/ilsefeenstra/Fitgirls0011/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/pawpularity_data.zip’
#
# /tmp/pawpularity_da     [             <=>    ] 993.59M  22.7MB/s    in 44s
#
# 2022-01-26 13:44:47 (22.5 MB/s) - ‘/tmp/pawpularity_data.zip’ saved [1041858845]

# %% [markdown]
# # Import tabular data
#
# The tabular data is imported. This contains information on whether several elements are present in the image, such as blur, a human, a group, etc. Also the pawpularity score of the training data is in the table. For the test data only the image ID and the features are in the table. There is also a sample submission table, which contains the pawpularity score for the test data.

# %%
# Import the CSV tables
csv_train_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train.csv")
csv_test_data = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test.csv")
sample_submission = pd.read_csv("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/sample_submission.csv")
csv_train_data.head()

# Drop rows with missing values (if NaN values are in dataframe)
# No missing values present, so no samples dropped
csv_train_data.dropna()
# Out:
#                                     Id  Subject Focus  ...  Blur  Pawpularity
# 0     0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1     0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2     0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
# 3     0018df346ac9c1d8413cfcc888ca8246              0  ...     0           15
# 4     001dc955e10590d3ca4673f034feeef2              0  ...     0           72
# ...                                ...            ...  ...   ...          ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0  ...     1           15
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0  ...     0           70
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0  ...     0           20
# 9910  fff19e2ce11718548fa1c5d039a5192a              0  ...     0           20
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0  ...     0           30
#
# [9912 rows x 14 columns]

# %%
# Create a plot that shows the distribution of the output of the training samples
plt.hist(csv_train_data['Pawpularity'], bins=100)
plt.title("Data distribution of the tabular data")
plt.xlabel("Pawpularity score")
plt.ylabel("Occurence")
plt.xlim(0, 100)

plt.show()

# %% [markdown]
# # Import image data
# The images are imported from the folders. Each image is reshaped to a 64x64 image. In this way all the images have the same shape and we do not use much memory, to speed up analysis. After the images are imported, the images and their names are shuffled. This is done, so we can later take a validation sample containing a random subsample of the dataset. It could be that the images in the dataset contain some order, so by shuffling we ensure that the subset for the validation data is random.

# %%
def reshape_images(path, n):
    """
    This function returns a list of images, which are reshaped to 64 x 64 
    and a list with the names of the images.
    """
    # Set the current path
    chdir(path)
    
    # Preset the lists
    images = []
    image_names = []
    
    # Go over all the files in the path
    for i in listdir():
        
        # Get the name of the image, without .jpg
        image_names.append(i[:-4])
        
        # Get the image and reshape to n x n
        file = cv2.imread(i)
        file = cv2.resize(file,(n, n), interpolation=cv2.INTER_AREA)
        
        # Rescale the pixels and store in the list
        images.append(file/255)
        
    return images, image_names

# Reshape train and test images
train_imgs, train_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/train", 64)
test_imgs, test_names = reshape_images("/tmp/Fitgirls0011-main/petfinder-pawpularity-score/test", 64)

# %% [markdown]
# # Combine tabular data with images
# To ensure that the dataframe has the same order as the images in the list, we sort the dataframe based on the names of the images. If this would not be the case, it could be that you learn incorrectly, as the output of an image perhaps is not the real output.

# %%
def sort_dataframe(data, images, names):
    """
    This function sorts the dataframe of the csv data according to the image names.
    """
    data_sorted = pd.DataFrame()

    # Iterate over images and get index of each image
    for img, name in zip(images, names):
        location = data[data['Id'] == name].index[0]

        # Sort dataframe according to index of images
        data_sorted = data_sorted.append([data.loc[location]])

        # Reset the index of the dataframe
        data_sorted = data_sorted.reset_index().drop(['index'],axis=1)
        
    return data_sorted

# Sort training and testing data
train_data_sorted = sort_dataframe(csv_train_data, train_imgs, train_names)
test_data_sorted = sort_dataframe(csv_test_data, test_imgs, test_names)
sample_submission_sorted = sort_dataframe(sample_submission, test_imgs, test_names)

# %% [markdown]
# # Processing data
# The tabular data is split in x and y values and converted to numpy arrays, so the neural network can handle the data. Moreover, the image data is converted to numpy arrays.

# %%
# Remove samples with pawpularity score of 100
indexNames = train_data_sorted[train_data_sorted['Pawpularity'] == 100].index
train_data_new = train_data_sorted.drop(indexNames)
train_imgs_new = np.delete(train_imgs, indexNames, axis=0)

# %%
# Select x-values (the 12 input features) and y-values from training data
x_tabular = train_data_new.iloc[:,1:13].to_numpy()
y = train_data_new.iloc[:,13].to_numpy()

# Select x (the 12 input features) and y (pawpularity) values from testing data
x_test_tabular = test_data_sorted.iloc[:,1:13].to_numpy()
y_test = sample_submission_sorted.iloc[:,1].to_numpy()

# Create numpy array of image data 
x_images = np.array(train_imgs_new)
test_imgs_array = np.array(test_imgs)

# %% [markdown]
# # Create seperate neural networks
# We create a tabular neural network to handle the data in the csv. Then we create a convolutional neural network to handle the image data. Both neural networks have no output layer, since they will be concatenated to one neural network, which will give the output.

# %%
def build_neural_net(input_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number of 
    hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()

    # Create hidden layer
    model.add(layers.Dense(units=hidden_nodes, input_shape=(input_size,)))

    return model

# %%
def build_convol_net(image_size, hidden_nodes):
    """
    Build neural network with an input size and a hidden layer with a number 
    of hidden nodes.
    """
    # Create a sequential model object
    model = models.Sequential()
    
    # Create a convolutional layer with pooling and batch norm
    model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=image_size, padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with dropout, pooling and batch norm
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())

    # Create a convolutional layer with dropout, pooling and batch norm
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2), strides=2))
    model.add(layers.BatchNormalization())
    
    # Create a flattening layer
    model.add(layers.Flatten())

    # Create a dense layer with dropout and regularization
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))

    # Create a dense layer with dropout and regularization
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-3),
              bias_regularizer=regularizers.l2(1e-3),
              activity_regularizer=regularizers.l2(1e-3)))
    
    return model

# %% [markdown]
# ## Concatenate tabular and image data models
# Concatenate the tabular and image models to create one neural network that can handle both types of data. This neural network will give the prediction of the pawpularity.

# %%
def linear_limit(x):
    """
    Create a linear activation function that clips the output at 0 and 100.
    """
    activation_x = activations.linear(x)
    activation_x_new = K.clip(activation_x, 0, 100)

    return activation_x_new

# %%
def concatenate_models(model1, model2, hidden_nodes):
    """
    Concatenate two neural network models, model1 and model2, and create
    a concatenated model with dense layers with some hidden nodes.
    """
    # Input for concatenated model is retrieved by concatenating the output
    # of both models
    concat_input = layers.concatenate([model1.output, model2.output])

    # Create hidden layer with regularization
    hidden_layer_1 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(concat_input)

    # Create hidden layer with relu dropout and regularization
    drop_out_1 = layers.Dropout(0.4)(hidden_layer_1)    
    hidden_layer_2 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_1)

    # Create hidden layer with relu dropout and regularization
    drop_out_2 = layers.Dropout(0.4)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(hidden_nodes, activation="relu", 
              kernel_regularizer=regularizers.l2(1e-1),
              bias_regularizer=regularizers.l2(1e-1),
              activity_regularizer=regularizers.l2(1e-1))(drop_out_2)

    # Create output layer with linear limit activation function
    output_layer = layers.Dense(1, activation=linear_limit)(hidden_layer_3)

    # Create concatenated model with inputs of both models and output of the
    # concatenated model
    concat_model = models.Model(inputs=[model1.input, model2.input], outputs=output_layer)

    return concat_model

# %%
def train_and_evaluate(model, image_x, tabular_x, train_y, x_val_tabular, x_val_imgs, val_y, epochs=20, preprocess = {}, augment={}):
    """
    This function trains and evaluated a model. It first compiles the model with 
    the loss and metrics. It then makes a train and validation generator for the 
    image data, based on the preprocess and augment input. 
    It then trains the model on both the image and tabular data for epochs times. 
    The values of the loss and metric are plotted and printed.
    """
    # Compile model and use mean squared error as loss and root mean squared error as metric
    model.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

    # Preprocess the image data
    train_gen = preprocessing.image.ImageDataGenerator(**preprocess, **augment)
    train_gen.fit(image_x)

    val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
    val_gen.fit(image_x)

    # Train the model by fitting both tabular and image data at the same time
    history = model.fit(train_gen.flow([image_x, tabular_x], train_y), epochs = epochs, validation_data=val_gen.flow([x_val_imgs, x_val_tabular], val_y))

    return history

# %%
def k_fold(num_folds, x_tabular, y, x_imgs, epochs=20, preprocess={}, augment={}):
    """
    Train and evaluate the data for num-folds times, and return the average 
    training and validation loss. First the data is split in num-folds batches
    and then the model is trained on the data, where a different batch is the 
    validation data each time.
    """
    losses = {}

    # Create kfold object to later split the data
    kfold = KFold(n_splits=num_folds, shuffle=True)
    x_indices = np.array(range(len(x_tabular)))
    y_indices = np.array(range(len(y)))

    # Preset arrays to add the loss for training and validation
    train_loss1 = np.array([0.0, 0.0])
    val_loss1 = np.array([0.0, 0.0])

    # Train and evaluate the model for num-fold times on a different training 
    # and validation set each time
    count = 0 

    train_loss = np.array(np.zeros(epochs))
    train_acc = np.array(np.zeros(epochs))
    val_loss = np.array(np.zeros(epochs))
    val_acc = np.array(np.zeros(epochs))
    
    # Iterate num_folds times and create different train/val split each time
    for id_train, id_val in kfold.split(x_indices, y_indices):
        
        # Make Neural Networks before concatenation
        tabular_NN = build_neural_net(input_size=12, hidden_nodes=20)
        image_size = (64, 64, 3)
        image_NN = build_convol_net(image_size=image_size, hidden_nodes=20)

        # Create subset training and validation data
        x_tabular_train = x_tabular[id_train]
        x_imgs_train = x_imgs[id_train]
        y_train = y[id_train]
        
        x_tabular_val = x_tabular[id_val]
        x_imgs_val = x_imgs[id_val]
        y_val_2 = y[id_val]
        
        # Train and evaluate the model
        concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)
        history = train_and_evaluate(concat_model, x_imgs_train, x_tabular_train, 
                           y_train, x_tabular_val, x_imgs_val, y_val_2, epochs=epochs, preprocess=preprocess, augment=augment)

        # Add the evaluation loss each time
        train_loss1 += concat_model.evaluate([x_imgs_train, x_tabular_train], y_train)
        val_loss1 += concat_model.evaluate([x_imgs_val, x_tabular_val], y_val_2)

        # Add all the losses and metrics
        train_loss += history.history['loss']
        train_acc += history.history['root_mean_squared_error']
        val_loss += history.history['val_loss']
        val_acc += history.history['val_root_mean_squared_error']

        losses[count] = history.history
        count += 1 

    # Calculate average loss and metric
    avg_train_loss = train_loss / num_folds
    avg_val_loss = val_loss / num_folds
    avg_train_acc = train_acc / num_folds
    avg_val_acc = val_acc / num_folds

    # Calculate average evaluation
    avg_train_loss1 = train_loss / num_folds
    avg_val_loss1 = val_loss / num_folds

    fig, axs = plt.subplots(1,2,figsize=(20,5)) 

    # Plot MSE
    axs[0].plot(avg_train_loss)
    axs[0].plot(avg_val_loss)
    axs[0].legend(['training', 'validation'], loc='best')
    
    axs[0].set_title('Model MSE')
    axs[0].set_ylabel('MSE')
    axs[0].set_xlabel('epoch')
    axs[0].set_ylim([0, 1000])

    # Plot RMSE
    axs[1].plot(avg_train_acc)
    axs[1].plot(avg_val_acc)
    axs[1].legend(['training', 'validation'], loc='best')
    
    axs[1].set_title('Model RMSE')
    axs[1].set_ylabel('RMSE')
    axs[1].set_xlabel('epoch')
    axs[1].set_ylim([0, 30])

    plt.show()

    return avg_train_loss1, avg_val_loss1, losses

# Use k-fold cross-validation to train and evaluate concatenated network
avg_train_loss, avg_val_loss, loss_df = k_fold(5, x_tabular, y, x_images, epochs=60, 
                                               preprocess={'featurewise_center': True, 'featurewise_std_normalization': True},
                                               augment={'rotation_range': 90, 'horizontal_flip': True, 'shear_range': 0.2})
# Out:
# Epoch 1/60
# 241/241 [==============================] - 32s 81ms/step - loss: 949.7169 - root_mean_squared_error: 27.9142 - val_loss: 578.4968 - val_root_mean_squared_error: 22.4722
# Epoch 2/60
# 241/241 [==============================] - 10s 42ms/step - loss: 642.5419 - root_mean_squared_error: 23.1210 - val_loss: 530.4286 - val_root_mean_squared_error: 21.7954
# Epoch 3/60
# 241/241 [==============================] - 10s 42ms/step - loss: 548.9996 - root_mean_squared_error: 21.7212 - val_loss: 454.1848 - val_root_mean_squared_error: 20.2404
# Epoch 4/60
# 241/241 [==============================] - 10s 42ms/step - loss: 481.2837 - root_mean_squared_error: 20.6479 - val_loss: 407.4189 - val_root_mean_squared_error: 19.3096
# Epoch 5/60
# 241/241 [==============================] - 10s 42ms/step - loss: 440.7763 - root_mean_squared_error: 19.9770 - val_loss: 368.3321 - val_root_mean_squared_error: 18.3886
# Epoch 6/60
# 241/241 [==============================] - 10s 42ms/step - loss: 414.7425 - root_mean_squared_error: 19.5483 - val_loss: 342.8405 - val_root_mean_squared_error: 17.7754
# Epoch 7/60
# 241/241 [==============================] - 10s 43ms/step - loss: 384.4684 - root_mean_squared_error: 18.9219 - val_loss: 342.2003 - val_root_mean_squared_error: 17.9006
# Epoch 8/60
# 241/241 [==============================] - 10s 42ms/step - loss: 369.4005 - root_mean_squared_error: 18.6371 - val_loss: 335.4975 - val_root_mean_squared_error: 17.7821
# Epoch 9/60
# 241/241 [==============================] - 10s 43ms/step - loss: 353.8101 - root_mean_squared_error: 18.2779 - val_loss: 332.6450 - val_root_mean_squared_error: 17.7033
# Epoch 10/60
# 241/241 [==============================] - 10s 43ms/step - loss: 351.3036 - root_mean_squared_error: 18.2444 - val_loss: 335.6894 - val_root_mean_squared_error: 17.7628
# Epoch 11/60
# 241/241 [==============================] - 10s 43ms/step - loss: 350.3579 - root_mean_squared_error: 18.2462 - val_loss: 329.5576 - val_root_mean_squared_error: 17.6980
# Epoch 12/60
# 241/241 [==============================] - 10s 42ms/step - loss: 348.0019 - root_mean_squared_error: 18.2234 - val_loss: 328.0815 - val_root_mean_squared_error: 17.7007
# Epoch 13/60
# 241/241 [==============================] - 10s 42ms/step - loss: 343.0156 - root_mean_squared_error: 18.1148 - val_loss: 327.3200 - val_root_mean_squared_error: 17.6987
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 342.1639 - root_mean_squared_error: 18.1150 - val_loss: 327.6653 - val_root_mean_squared_error: 17.7176
# Epoch 15/60
# 241/241 [==============================] - 10s 43ms/step - loss: 341.4919 - root_mean_squared_error: 18.1175 - val_loss: 325.7778 - val_root_mean_squared_error: 17.6911
# Epoch 16/60
# 241/241 [==============================] - 10s 42ms/step - loss: 337.0701 - root_mean_squared_error: 18.0074 - val_loss: 325.8066 - val_root_mean_squared_error: 17.7078
# Epoch 17/60
# 241/241 [==============================] - 10s 43ms/step - loss: 338.8374 - root_mean_squared_error: 18.0708 - val_loss: 325.7064 - val_root_mean_squared_error: 17.7151
# Epoch 18/60
# 241/241 [==============================] - 10s 42ms/step - loss: 335.3477 - root_mean_squared_error: 17.9876 - val_loss: 324.5923 - val_root_mean_squared_error: 17.6934
# Epoch 19/60
# 241/241 [==============================] - 10s 42ms/step - loss: 334.8398 - root_mean_squared_error: 17.9885 - val_loss: 323.7090 - val_root_mean_squared_error: 17.6896
# Epoch 20/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.5206 - root_mean_squared_error: 17.9606 - val_loss: 323.3436 - val_root_mean_squared_error: 17.6801
# Epoch 21/60
# 241/241 [==============================] - 10s 43ms/step - loss: 332.0493 - root_mean_squared_error: 17.9242 - val_loss: 323.3339 - val_root_mean_squared_error: 17.6920
# Epoch 22/60
# 241/241 [==============================] - 11s 44ms/step - loss: 332.9507 - root_mean_squared_error: 17.9619 - val_loss: 322.8807 - val_root_mean_squared_error: 17.6801
# Epoch 23/60
# 241/241 [==============================] - 11s 45ms/step - loss: 330.5509 - root_mean_squared_error: 17.8980 - val_loss: 322.9050 - val_root_mean_squared_error: 17.6928
# Epoch 24/60
# 241/241 [==============================] - 11s 45ms/step - loss: 331.4988 - root_mean_squared_error: 17.9328 - val_loss: 322.7245 - val_root_mean_squared_error: 17.6924
# Epoch 25/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.9312 - root_mean_squared_error: 17.8935 - val_loss: 322.9760 - val_root_mean_squared_error: 17.6958
# Epoch 26/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.7810 - root_mean_squared_error: 17.8911 - val_loss: 323.0321 - val_root_mean_squared_error: 17.7095
# Epoch 27/60
# 241/241 [==============================] - 10s 42ms/step - loss: 329.0878 - root_mean_squared_error: 17.8766 - val_loss: 322.7612 - val_root_mean_squared_error: 17.7035
# Epoch 28/60
# 241/241 [==============================] - 10s 42ms/step - loss: 328.4129 - root_mean_squared_error: 17.8646 - val_loss: 322.4581 - val_root_mean_squared_error: 17.7007
# Epoch 29/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.3060 - root_mean_squared_error: 17.8905 - val_loss: 322.6768 - val_root_mean_squared_error: 17.7074
# Epoch 30/60
# 241/241 [==============================] - 10s 42ms/step - loss: 328.3959 - root_mean_squared_error: 17.8707 - val_loss: 321.9957 - val_root_mean_squared_error: 17.6927
# Epoch 31/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.3646 - root_mean_squared_error: 17.8686 - val_loss: 327.3079 - val_root_mean_squared_error: 17.7793
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.4961 - root_mean_squared_error: 17.8781 - val_loss: 321.6163 - val_root_mean_squared_error: 17.6913
# Epoch 33/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.7567 - root_mean_squared_error: 17.8594 - val_loss: 323.2408 - val_root_mean_squared_error: 17.7324
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.4615 - root_mean_squared_error: 17.8550 - val_loss: 321.3613 - val_root_mean_squared_error: 17.6861
# Epoch 35/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.4590 - root_mean_squared_error: 17.8613 - val_loss: 324.1385 - val_root_mean_squared_error: 17.7665
# Epoch 36/60
# 241/241 [==============================] - 10s 42ms/step - loss: 327.6148 - root_mean_squared_error: 17.8713 - val_loss: 320.8729 - val_root_mean_squared_error: 17.6847
# Epoch 37/60
# 241/241 [==============================] - 10s 42ms/step - loss: 327.3549 - root_mean_squared_error: 17.8616 - val_loss: 321.6890 - val_root_mean_squared_error: 17.7071
# Epoch 38/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.8727 - root_mean_squared_error: 17.8531 - val_loss: 322.1358 - val_root_mean_squared_error: 17.7249
# Epoch 39/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.7672 - root_mean_squared_error: 17.8789 - val_loss: 321.2256 - val_root_mean_squared_error: 17.7025
# Epoch 40/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.4315 - root_mean_squared_error: 17.8489 - val_loss: 322.5063 - val_root_mean_squared_error: 17.7421
# Epoch 41/60
# 241/241 [==============================] - 10s 42ms/step - loss: 327.1218 - root_mean_squared_error: 17.8772 - val_loss: 321.3861 - val_root_mean_squared_error: 17.7090
# Epoch 42/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.9839 - root_mean_squared_error: 17.8728 - val_loss: 320.8806 - val_root_mean_squared_error: 17.7051
# Epoch 43/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.9191 - root_mean_squared_error: 17.8712 - val_loss: 320.4518 - val_root_mean_squared_error: 17.6938
# Epoch 44/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.7417 - root_mean_squared_error: 17.8636 - val_loss: 320.3026 - val_root_mean_squared_error: 17.6856
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.7599 - root_mean_squared_error: 17.8743 - val_loss: 320.2076 - val_root_mean_squared_error: 17.6962
# Epoch 46/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.0456 - root_mean_squared_error: 17.8544 - val_loss: 319.9661 - val_root_mean_squared_error: 17.6852
# Epoch 47/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.1394 - root_mean_squared_error: 17.8582 - val_loss: 322.2366 - val_root_mean_squared_error: 17.7147
# Epoch 48/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.3638 - root_mean_squared_error: 17.8606 - val_loss: 320.5442 - val_root_mean_squared_error: 17.7023
# Epoch 49/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.2217 - root_mean_squared_error: 17.8628 - val_loss: 321.3567 - val_root_mean_squared_error: 17.7335
# Epoch 50/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.7239 - root_mean_squared_error: 17.8475 - val_loss: 319.9582 - val_root_mean_squared_error: 17.6913
# Epoch 51/60
# 241/241 [==============================] - 10s 42ms/step - loss: 325.8310 - root_mean_squared_error: 17.8566 - val_loss: 319.5327 - val_root_mean_squared_error: 17.6767
# Epoch 52/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.7885 - root_mean_squared_error: 17.8568 - val_loss: 320.0141 - val_root_mean_squared_error: 17.6989
# Epoch 53/60
# 241/241 [==============================] - 10s 42ms/step - loss: 325.2953 - root_mean_squared_error: 17.8468 - val_loss: 319.8318 - val_root_mean_squared_error: 17.6936
# Epoch 54/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.9698 - root_mean_squared_error: 17.8367 - val_loss: 320.1441 - val_root_mean_squared_error: 17.7057
# Epoch 55/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.1283 - root_mean_squared_error: 17.8417 - val_loss: 320.3804 - val_root_mean_squared_error: 17.7120
# Epoch 56/60
# 241/241 [==============================] - 10s 42ms/step - loss: 324.4559 - root_mean_squared_error: 17.8218 - val_loss: 319.5407 - val_root_mean_squared_error: 17.6850
# Epoch 57/60
# 241/241 [==============================] - 10s 42ms/step - loss: 324.8990 - root_mean_squared_error: 17.8397 - val_loss: 319.7629 - val_root_mean_squared_error: 17.6868
# Epoch 58/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.5262 - root_mean_squared_error: 17.8227 - val_loss: 319.9160 - val_root_mean_squared_error: 17.6972
# Epoch 59/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.2556 - root_mean_squared_error: 17.8156 - val_loss: 318.8943 - val_root_mean_squared_error: 17.6651
# Epoch 60/60
# 241/241 [==============================] - 10s 42ms/step - loss: 325.0125 - root_mean_squared_error: 17.8421 - val_loss: 320.6755 - val_root_mean_squared_error: 17.7064
# 241/241 [==============================] - 2s 7ms/step - loss: 324.8477 - root_mean_squared_error: 17.8460
# 61/61 [==============================] - 0s 8ms/step - loss: 320.2393 - root_mean_squared_error: 17.7167
# Epoch 1/60
# 241/241 [==============================] - 12s 43ms/step - loss: 918.0171 - root_mean_squared_error: 27.5864 - val_loss: 622.2815 - val_root_mean_squared_error: 23.4650
# Epoch 2/60
# 241/241 [==============================] - 10s 42ms/step - loss: 630.7883 - root_mean_squared_error: 22.9685 - val_loss: 578.1504 - val_root_mean_squared_error: 23.0354
# Epoch 3/60
# 241/241 [==============================] - 10s 42ms/step - loss: 542.9738 - root_mean_squared_error: 21.7129 - val_loss: 501.6411 - val_root_mean_squared_error: 21.4265
# Epoch 4/60
# 241/241 [==============================] - 10s 43ms/step - loss: 483.9961 - root_mean_squared_error: 20.7222 - val_loss: 449.3238 - val_root_mean_squared_error: 20.3709
# Epoch 5/60
# 241/241 [==============================] - 10s 42ms/step - loss: 438.6627 - root_mean_squared_error: 19.9491 - val_loss: 403.3093 - val_root_mean_squared_error: 19.3959
# Epoch 6/60
# 241/241 [==============================] - 10s 42ms/step - loss: 400.8883 - root_mean_squared_error: 19.2282 - val_loss: 381.4014 - val_root_mean_squared_error: 18.9221
# Epoch 7/60
# 241/241 [==============================] - 10s 43ms/step - loss: 375.7610 - root_mean_squared_error: 18.7190 - val_loss: 366.0457 - val_root_mean_squared_error: 18.5092
# Epoch 8/60
# 241/241 [==============================] - 10s 42ms/step - loss: 362.2853 - root_mean_squared_error: 18.4620 - val_loss: 351.3726 - val_root_mean_squared_error: 18.2160
# Epoch 9/60
# 241/241 [==============================] - 10s 43ms/step - loss: 351.8529 - root_mean_squared_error: 18.2225 - val_loss: 354.1968 - val_root_mean_squared_error: 18.3456
# Epoch 10/60
# 241/241 [==============================] - 10s 43ms/step - loss: 349.2130 - root_mean_squared_error: 18.1900 - val_loss: 349.8135 - val_root_mean_squared_error: 18.2427
# Epoch 11/60
# 241/241 [==============================] - 13s 54ms/step - loss: 345.5659 - root_mean_squared_error: 18.1274 - val_loss: 347.6495 - val_root_mean_squared_error: 18.1808
# Epoch 12/60
# 241/241 [==============================] - 10s 42ms/step - loss: 340.6335 - root_mean_squared_error: 18.0252 - val_loss: 345.3889 - val_root_mean_squared_error: 18.1664
# Epoch 13/60
# 241/241 [==============================] - 10s 43ms/step - loss: 338.4716 - root_mean_squared_error: 17.9918 - val_loss: 345.7680 - val_root_mean_squared_error: 18.2159
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.6749 - root_mean_squared_error: 17.9937 - val_loss: 343.9301 - val_root_mean_squared_error: 18.1692
# Epoch 15/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.4523 - root_mean_squared_error: 17.9967 - val_loss: 343.1925 - val_root_mean_squared_error: 18.1634
# Epoch 16/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.3592 - root_mean_squared_error: 17.9546 - val_loss: 342.9035 - val_root_mean_squared_error: 18.1736
# Epoch 17/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.5579 - root_mean_squared_error: 17.9522 - val_loss: 342.5980 - val_root_mean_squared_error: 18.1838
# Epoch 18/60
# 241/241 [==============================] - 10s 42ms/step - loss: 331.0296 - root_mean_squared_error: 17.8653 - val_loss: 342.7244 - val_root_mean_squared_error: 18.2017
# Epoch 19/60
# 241/241 [==============================] - 10s 42ms/step - loss: 330.6206 - root_mean_squared_error: 17.8651 - val_loss: 342.9175 - val_root_mean_squared_error: 18.2171
# Epoch 20/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.7453 - root_mean_squared_error: 17.8729 - val_loss: 343.6158 - val_root_mean_squared_error: 18.2479
# Epoch 21/60
# 241/241 [==============================] - 10s 42ms/step - loss: 330.1189 - root_mean_squared_error: 17.8685 - val_loss: 341.0362 - val_root_mean_squared_error: 18.1771
# Epoch 22/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.3422 - root_mean_squared_error: 17.8021 - val_loss: 342.0751 - val_root_mean_squared_error: 18.2176
# Epoch 23/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.7961 - root_mean_squared_error: 17.8219 - val_loss: 340.0447 - val_root_mean_squared_error: 18.1643
# Epoch 24/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.2024 - root_mean_squared_error: 17.7824 - val_loss: 339.8994 - val_root_mean_squared_error: 18.1653
# Epoch 25/60
# 241/241 [==============================] - 10s 42ms/step - loss: 326.5053 - root_mean_squared_error: 17.7951 - val_loss: 339.8132 - val_root_mean_squared_error: 18.1675
# Epoch 26/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.0506 - root_mean_squared_error: 17.7896 - val_loss: 339.3296 - val_root_mean_squared_error: 18.1589
# Epoch 27/60
# 241/241 [==============================] - 10s 42ms/step - loss: 325.4323 - root_mean_squared_error: 17.7770 - val_loss: 339.6615 - val_root_mean_squared_error: 18.1697
# Epoch 28/60
# 241/241 [==============================] - 10s 43ms/step - loss: 325.2759 - root_mean_squared_error: 17.7740 - val_loss: 339.2471 - val_root_mean_squared_error: 18.1652
# Epoch 29/60
# 241/241 [==============================] - 10s 42ms/step - loss: 324.8304 - root_mean_squared_error: 17.7612 - val_loss: 338.9230 - val_root_mean_squared_error: 18.1598
# Epoch 30/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.4253 - root_mean_squared_error: 17.7520 - val_loss: 339.6726 - val_root_mean_squared_error: 18.1812
# Epoch 31/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.6126 - root_mean_squared_error: 17.7646 - val_loss: 339.9587 - val_root_mean_squared_error: 18.1918
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 324.1555 - root_mean_squared_error: 17.7518 - val_loss: 339.0710 - val_root_mean_squared_error: 18.1715
# Epoch 33/60
# 241/241 [==============================] - 11s 44ms/step - loss: 323.9641 - root_mean_squared_error: 17.7506 - val_loss: 338.5704 - val_root_mean_squared_error: 18.1671
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.4530 - root_mean_squared_error: 17.7437 - val_loss: 339.3797 - val_root_mean_squared_error: 18.1881
# Epoch 35/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.3675 - root_mean_squared_error: 17.7382 - val_loss: 339.5319 - val_root_mean_squared_error: 18.1936
# Epoch 36/60
# 241/241 [==============================] - 10s 42ms/step - loss: 322.5825 - root_mean_squared_error: 17.7188 - val_loss: 345.4756 - val_root_mean_squared_error: 18.3227
# Epoch 37/60
# 241/241 [==============================] - 10s 42ms/step - loss: 323.7225 - root_mean_squared_error: 17.7589 - val_loss: 337.7085 - val_root_mean_squared_error: 18.1480
# Epoch 38/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.5205 - root_mean_squared_error: 17.7272 - val_loss: 338.5348 - val_root_mean_squared_error: 18.1711
# Epoch 39/60
# 241/241 [==============================] - 10s 43ms/step - loss: 323.0220 - root_mean_squared_error: 17.7456 - val_loss: 337.3026 - val_root_mean_squared_error: 18.1492
# Epoch 40/60
# 241/241 [==============================] - 10s 42ms/step - loss: 322.8108 - root_mean_squared_error: 17.7444 - val_loss: 338.0483 - val_root_mean_squared_error: 18.1689
# Epoch 41/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.8492 - root_mean_squared_error: 17.7458 - val_loss: 338.1630 - val_root_mean_squared_error: 18.1819
# Epoch 42/60
# 241/241 [==============================] - 10s 43ms/step - loss: 322.3885 - root_mean_squared_error: 17.7404 - val_loss: 338.8796 - val_root_mean_squared_error: 18.2030
# Epoch 43/60
# 241/241 [==============================] - 10s 42ms/step - loss: 322.6765 - root_mean_squared_error: 17.7428 - val_loss: 337.3524 - val_root_mean_squared_error: 18.1618
# Epoch 44/60
# 241/241 [==============================] - 10s 42ms/step - loss: 322.3508 - root_mean_squared_error: 17.7438 - val_loss: 338.6645 - val_root_mean_squared_error: 18.1924
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.8498 - root_mean_squared_error: 17.7296 - val_loss: 337.6347 - val_root_mean_squared_error: 18.1732
# Epoch 46/60
# 241/241 [==============================] - 10s 42ms/step - loss: 321.8554 - root_mean_squared_error: 17.7347 - val_loss: 337.7656 - val_root_mean_squared_error: 18.1696
# Epoch 47/60
# 241/241 [==============================] - 10s 42ms/step - loss: 321.6776 - root_mean_squared_error: 17.7292 - val_loss: 337.6444 - val_root_mean_squared_error: 18.1762
# Epoch 48/60
# 241/241 [==============================] - 10s 43ms/step - loss: 321.2449 - root_mean_squared_error: 17.7178 - val_loss: 337.6214 - val_root_mean_squared_error: 18.1787
# Epoch 49/60
# 241/241 [==============================] - 10s 42ms/step - loss: 321.2080 - root_mean_squared_error: 17.7198 - val_loss: 336.5428 - val_root_mean_squared_error: 18.1477
# Epoch 50/60
# 241/241 [==============================] - 10s 42ms/step - loss: 320.6700 - root_mean_squared_error: 17.7062 - val_loss: 337.3849 - val_root_mean_squared_error: 18.1730
# Epoch 51/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.4739 - root_mean_squared_error: 17.7015 - val_loss: 337.5188 - val_root_mean_squared_error: 18.1659
# Epoch 52/60
# 241/241 [==============================] - 10s 42ms/step - loss: 320.8349 - root_mean_squared_error: 17.7124 - val_loss: 339.2051 - val_root_mean_squared_error: 18.2199
# Epoch 53/60
# 241/241 [==============================] - 10s 42ms/step - loss: 320.6655 - root_mean_squared_error: 17.7064 - val_loss: 338.5988 - val_root_mean_squared_error: 18.2073
# Epoch 54/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.6095 - root_mean_squared_error: 17.7076 - val_loss: 337.4587 - val_root_mean_squared_error: 18.1800
# Epoch 55/60
# 241/241 [==============================] - 10s 42ms/step - loss: 320.4913 - root_mean_squared_error: 17.7089 - val_loss: 337.4443 - val_root_mean_squared_error: 18.1832
# Epoch 56/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.3023 - root_mean_squared_error: 17.7015 - val_loss: 339.4818 - val_root_mean_squared_error: 18.2362
# Epoch 57/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.0084 - root_mean_squared_error: 17.6953 - val_loss: 337.6932 - val_root_mean_squared_error: 18.1869
# Epoch 58/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.7147 - root_mean_squared_error: 17.7144 - val_loss: 338.4056 - val_root_mean_squared_error: 18.2013
# Epoch 59/60
# 241/241 [==============================] - 10s 43ms/step - loss: 320.3857 - root_mean_squared_error: 17.7053 - val_loss: 338.8502 - val_root_mean_squared_error: 18.2202
# Epoch 60/60
# 241/241 [==============================] - 10s 42ms/step - loss: 320.5149 - root_mean_squared_error: 17.7106 - val_loss: 336.6169 - val_root_mean_squared_error: 18.1650
# 241/241 [==============================] - 2s 6ms/step - loss: 320.3621 - root_mean_squared_error: 17.7147
# 61/61 [==============================] - 0s 6ms/step - loss: 336.7879 - root_mean_squared_error: 18.1722
# Epoch 1/60
# 241/241 [==============================] - 13s 44ms/step - loss: 999.9122 - root_mean_squared_error: 28.8405 - val_loss: 649.0843 - val_root_mean_squared_error: 24.0950
# Epoch 2/60
# 241/241 [==============================] - 10s 42ms/step - loss: 700.7899 - root_mean_squared_error: 24.2538 - val_loss: 494.4771 - val_root_mean_squared_error: 20.6757
# Epoch 3/60
# 241/241 [==============================] - 10s 42ms/step - loss: 586.1323 - root_mean_squared_error: 22.4629 - val_loss: 462.1795 - val_root_mean_squared_error: 20.2927
# Epoch 4/60
# 241/241 [==============================] - 10s 43ms/step - loss: 513.6532 - root_mean_squared_error: 21.2870 - val_loss: 422.8404 - val_root_mean_squared_error: 19.3804
# Epoch 5/60
# 241/241 [==============================] - 10s 43ms/step - loss: 461.8750 - root_mean_squared_error: 20.4108 - val_loss: 388.7693 - val_root_mean_squared_error: 18.9458
# Epoch 6/60
# 241/241 [==============================] - 10s 43ms/step - loss: 422.0636 - root_mean_squared_error: 19.6817 - val_loss: 364.0752 - val_root_mean_squared_error: 18.4288
# Epoch 7/60
# 241/241 [==============================] - 10s 42ms/step - loss: 397.9530 - root_mean_squared_error: 19.2414 - val_loss: 342.4697 - val_root_mean_squared_error: 17.8578
# Epoch 8/60
# 241/241 [==============================] - 11s 46ms/step - loss: 381.8958 - root_mean_squared_error: 18.9343 - val_loss: 327.6250 - val_root_mean_squared_error: 17.5206
# Epoch 9/60
# 241/241 [==============================] - 10s 43ms/step - loss: 362.9378 - root_mean_squared_error: 18.5036 - val_loss: 336.4684 - val_root_mean_squared_error: 17.6849
# Epoch 10/60
# 241/241 [==============================] - 10s 43ms/step - loss: 357.6110 - root_mean_squared_error: 18.4019 - val_loss: 323.1165 - val_root_mean_squared_error: 17.4566
# Epoch 11/60
# 241/241 [==============================] - 10s 43ms/step - loss: 352.9076 - root_mean_squared_error: 18.3140 - val_loss: 321.9294 - val_root_mean_squared_error: 17.4819
# Epoch 12/60
# 241/241 [==============================] - 10s 42ms/step - loss: 350.4668 - root_mean_squared_error: 18.2778 - val_loss: 321.2251 - val_root_mean_squared_error: 17.4637
# Epoch 13/60
# 241/241 [==============================] - 10s 43ms/step - loss: 348.0308 - root_mean_squared_error: 18.2328 - val_loss: 319.7227 - val_root_mean_squared_error: 17.4577
# Epoch 14/60
# 241/241 [==============================] - 10s 43ms/step - loss: 344.2096 - root_mean_squared_error: 18.1545 - val_loss: 319.1366 - val_root_mean_squared_error: 17.4649
# Epoch 15/60
# 241/241 [==============================] - 10s 43ms/step - loss: 343.3097 - root_mean_squared_error: 18.1416 - val_loss: 318.8917 - val_root_mean_squared_error: 17.4695
# Epoch 16/60
# 241/241 [==============================] - 10s 42ms/step - loss: 342.4438 - root_mean_squared_error: 18.1262 - val_loss: 318.0141 - val_root_mean_squared_error: 17.4606
# Epoch 17/60
# 241/241 [==============================] - 10s 43ms/step - loss: 340.9890 - root_mean_squared_error: 18.1080 - val_loss: 318.5172 - val_root_mean_squared_error: 17.4942
# Epoch 18/60
# 241/241 [==============================] - 10s 43ms/step - loss: 340.3169 - root_mean_squared_error: 18.0989 - val_loss: 317.0931 - val_root_mean_squared_error: 17.4582
# Epoch 19/60
# 241/241 [==============================] - 10s 43ms/step - loss: 339.3629 - root_mean_squared_error: 18.0850 - val_loss: 316.9687 - val_root_mean_squared_error: 17.4567
# Epoch 20/60
# 241/241 [==============================] - 10s 43ms/step - loss: 338.0934 - root_mean_squared_error: 18.0589 - val_loss: 316.4284 - val_root_mean_squared_error: 17.4568
# Epoch 21/60
# 241/241 [==============================] - 10s 43ms/step - loss: 337.4386 - root_mean_squared_error: 18.0500 - val_loss: 315.9302 - val_root_mean_squared_error: 17.4526
# Epoch 22/60
# 241/241 [==============================] - 10s 43ms/step - loss: 335.8096 - root_mean_squared_error: 18.0096 - val_loss: 315.5797 - val_root_mean_squared_error: 17.4511
# Epoch 23/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.8068 - root_mean_squared_error: 17.9935 - val_loss: 315.4928 - val_root_mean_squared_error: 17.4642
# Epoch 24/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.7824 - root_mean_squared_error: 17.9994 - val_loss: 315.4188 - val_root_mean_squared_error: 17.4484
# Epoch 25/60
# 241/241 [==============================] - 10s 43ms/step - loss: 334.2212 - root_mean_squared_error: 17.9856 - val_loss: 314.8345 - val_root_mean_squared_error: 17.4495
# Epoch 26/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.5157 - root_mean_squared_error: 17.9749 - val_loss: 314.3222 - val_root_mean_squared_error: 17.4431
# Epoch 27/60
# 241/241 [==============================] - 10s 43ms/step - loss: 333.2429 - root_mean_squared_error: 17.9777 - val_loss: 314.0408 - val_root_mean_squared_error: 17.4409
# Epoch 28/60
# 241/241 [==============================] - 10s 43ms/step - loss: 332.1328 - root_mean_squared_error: 17.9491 - val_loss: 314.1600 - val_root_mean_squared_error: 17.4408
# Epoch 29/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.8758 - root_mean_squared_error: 17.9435 - val_loss: 313.9399 - val_root_mean_squared_error: 17.4441
# Epoch 30/60
# 241/241 [==============================] - 10s 43ms/step - loss: 332.1635 - root_mean_squared_error: 17.9606 - val_loss: 313.5256 - val_root_mean_squared_error: 17.4411
# Epoch 31/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.7485 - root_mean_squared_error: 17.9271 - val_loss: 313.8840 - val_root_mean_squared_error: 17.4514
# Epoch 32/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.1185 - root_mean_squared_error: 17.9381 - val_loss: 314.7888 - val_root_mean_squared_error: 17.4799
# Epoch 33/60
# 241/241 [==============================] - 10s 43ms/step - loss: 331.2846 - root_mean_squared_error: 17.9459 - val_loss: 313.4527 - val_root_mean_squared_error: 17.4441
# Epoch 34/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.9485 - root_mean_squared_error: 17.9358 - val_loss: 312.8766 - val_root_mean_squared_error: 17.4322
# Epoch 35/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.0121 - root_mean_squared_error: 17.9216 - val_loss: 313.0537 - val_root_mean_squared_error: 17.4450
# Epoch 36/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.4736 - root_mean_squared_error: 17.9359 - val_loss: 313.3608 - val_root_mean_squared_error: 17.4523
# Epoch 37/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.4951 - root_mean_squared_error: 17.9386 - val_loss: 312.8345 - val_root_mean_squared_error: 17.4471
# Epoch 38/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.5592 - root_mean_squared_error: 17.9196 - val_loss: 314.8161 - val_root_mean_squared_error: 17.4950
# Epoch 39/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.5092 - root_mean_squared_error: 17.9200 - val_loss: 312.4232 - val_root_mean_squared_error: 17.4417
# Epoch 40/60
# 241/241 [==============================] - 11s 44ms/step - loss: 329.7333 - root_mean_squared_error: 17.9261 - val_loss: 314.4075 - val_root_mean_squared_error: 17.4937
# Epoch 41/60
# 241/241 [==============================] - 10s 43ms/step - loss: 330.2957 - root_mean_squared_error: 17.9423 - val_loss: 312.4855 - val_root_mean_squared_error: 17.4464
# Epoch 42/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.5193 - root_mean_squared_error: 17.9006 - val_loss: 314.6340 - val_root_mean_squared_error: 17.5090
# Epoch 43/60
# 241/241 [==============================] - 10s 43ms/step - loss: 329.2642 - root_mean_squared_error: 17.9244 - val_loss: 312.5370 - val_root_mean_squared_error: 17.4599
# Epoch 44/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.3348 - root_mean_squared_error: 17.9045 - val_loss: 312.3808 - val_root_mean_squared_error: 17.4566
# Epoch 45/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.9037 - root_mean_squared_error: 17.9202 - val_loss: 312.8293 - val_root_mean_squared_error: 17.4632
# Epoch 46/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.9801 - root_mean_squared_error: 17.9218 - val_loss: 312.9780 - val_root_mean_squared_error: 17.4756
# Epoch 47/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.7868 - root_mean_squared_error: 17.9223 - val_loss: 312.0753 - val_root_mean_squared_error: 17.4531
# Epoch 48/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.4899 - root_mean_squared_error: 17.9177 - val_loss: 311.2816 - val_root_mean_squared_error: 17.4308
# Epoch 49/60
# 241/241 [==============================] - 10s 44ms/step - loss: 329.0566 - root_mean_squared_error: 17.9336 - val_loss: 311.5935 - val_root_mean_squared_error: 17.4449
# Epoch 50/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.2635 - root_mean_squared_error: 17.9165 - val_loss: 311.8730 - val_root_mean_squared_error: 17.4569
# Epoch 51/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.8710 - root_mean_squared_error: 17.9063 - val_loss: 311.0509 - val_root_mean_squared_error: 17.4306
# Epoch 52/60
# 241/241 [==============================] - 10s 43ms/step - loss: 328.0328 - root_mean_squared_error: 17.9083 - val_loss: 311.9061 - val_root_mean_squared_error: 17.4551
# Epoch 53/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.6905 - root_mean_squared_error: 17.9001 - val_loss: 311.2720 - val_root_mean_squared_error: 17.4365
# Epoch 54/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.2519 - root_mean_squared_error: 17.8902 - val_loss: 312.4588 - val_root_mean_squared_error: 17.4722
# Epoch 55/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.6627 - root_mean_squared_error: 17.9017 - val_loss: 310.9590 - val_root_mean_squared_error: 17.4332
# Epoch 56/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.1613 - root_mean_squared_error: 17.8635 - val_loss: 311.4561 - val_root_mean_squared_error: 17.4438
# Epoch 57/60
# 241/241 [==============================] - 10s 43ms/step - loss: 326.8325 - root_mean_squared_error: 17.8839 - val_loss: 310.8109 - val_root_mean_squared_error: 17.4329
# Epoch 58/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.0345 - root_mean_squared_error: 17.8886 - val_loss: 310.3452 - val_root_mean_squared_error: 17.4208
# Epoch 59/60
# 241/241 [==============================] - 11s 44ms/step - loss: 326.7236 - root_mean_squared_error: 17.8828 - val_loss: 310.3900 - val_root_mean_squared_error: 17.4230
# Epoch 60/60
# 241/241 [==============================] - 10s 43ms/step - loss: 327.4953 - root_mean_squared_error: 17.9066 - val_loss: 310.3493 - val_root_mean_squared_error: 17.4240
# 241/241 [==============================] - 2s 6ms/step - loss: 326.7672 - root_mean_squared_error: 17.8922
# 61/61 [==============================] - 0s 6ms/step - loss: 310.3625 - root_mean_squared_error: 17.4277
# Epoch 1/60
# 241/241 [==============================] - 13s 45ms/step - loss: 823.6974 - root_mean_squared_error: 25.7802 - val_loss: 699.6346 - val_root_mean_squared_error: 25.2352
# Epoch 2/60
# 241/241 [==============================] - 11s 44ms/step - loss: 634.1429 - root_mean_squared_error: 23.0341 - val_loss: 616.2624 - val_root_mean_squared_error: 23.5164
# Epoch 3/60
# 241/241 [==============================] - 11s 44ms/step - loss: 552.1365 - root_mean_squared_error: 21.8552 - val_loss: 521.5471 - val_root_mean_squared_error: 21.9534
# Epoch 4/60
# 241/241 [==============================] - 11s 46ms/step - loss: 481.1132 - root_mean_squared_error: 20.6715 - val_loss: 467.0154 - val_root_mean_squared_error: 20.9209
# Epoch 5/60
# 241/241 [==============================] - 11s 45ms/step - loss: 434.9388 - root_mean_squared_error: 19.8775 - val_loss: 399.7992 - val_root_mean_squared_error: 19.1931
# Epoch 6/60
# 241/241 [==============================] - 11s 45ms/step - loss: 404.1135 - root_mean_squared_error: 19.3258 - val_loss: 366.5203 - val_root_mean_squared_error: 18.5309
# Epoch 7/60
# 241/241 [==============================] - 11s 45ms/step - loss: 375.2548 - root_mean_squared_error: 18.7357 - val_loss: 364.2508 - val_root_mean_squared_error: 18.5861
# Epoch 8/60
# 241/241 [==============================] - 11s 44ms/step - loss: 355.8053 - root_mean_squared_error: 18.3125 - val_loss: 351.0619 - val_root_mean_squared_error: 18.2235
# Epoch 9/60
# 241/241 [==============================] - 11s 45ms/step - loss: 345.2177 - root_mean_squared_error: 18.0735 - val_loss: 348.2124 - val_root_mean_squared_error: 18.1826
# Epoch 10/60
# 241/241 [==============================] - 11s 44ms/step - loss: 343.8055 - root_mean_squared_error: 18.0735 - val_loss: 346.8672 - val_root_mean_squared_error: 18.1793
# Epoch 11/60
# 241/241 [==============================] - 11s 44ms/step - loss: 342.4603 - root_mean_squared_error: 18.0576 - val_loss: 348.3226 - val_root_mean_squared_error: 18.2448
# Epoch 12/60
# 241/241 [==============================] - 11s 44ms/step - loss: 338.5211 - root_mean_squared_error: 17.9783 - val_loss: 345.3762 - val_root_mean_squared_error: 18.2014
# Epoch 13/60
# 241/241 [==============================] - 11s 44ms/step - loss: 335.8961 - root_mean_squared_error: 17.9329 - val_loss: 345.3080 - val_root_mean_squared_error: 18.2100
# Epoch 14/60
# 241/241 [==============================] - 11s 44ms/step - loss: 333.8513 - root_mean_squared_error: 17.8941 - val_loss: 343.5499 - val_root_mean_squared_error: 18.1808
# Epoch 15/60
# 241/241 [==============================] - 11s 44ms/step - loss: 332.9955 - root_mean_squared_error: 17.8969 - val_loss: 343.5953 - val_root_mean_squared_error: 18.2123
# Epoch 16/60
# 241/241 [==============================] - 11s 44ms/step - loss: 332.7924 - root_mean_squared_error: 17.9111 - val_loss: 342.0181 - val_root_mean_squared_error: 18.1752
# Epoch 17/60
# 241/241 [==============================] - 11s 45ms/step - loss: 332.9552 - root_mean_squared_error: 17.9250 - val_loss: 342.6496 - val_root_mean_squared_error: 18.2072
# Epoch 18/60
# 241/241 [==============================] - 11s 44ms/step - loss: 330.8853 - root_mean_squared_error: 17.8830 - val_loss: 342.0811 - val_root_mean_squared_error: 18.1935
# Epoch 19/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.7196 - root_mean_squared_error: 17.8291 - val_loss: 342.2098 - val_root_mean_squared_error: 18.2116
# Epoch 20/60
# 241/241 [==============================] - 11s 44ms/step - loss: 328.8822 - root_mean_squared_error: 17.8423 - val_loss: 344.2180 - val_root_mean_squared_error: 18.2870
# Epoch 21/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.8074 - root_mean_squared_error: 17.8251 - val_loss: 342.0251 - val_root_mean_squared_error: 18.2234
# Epoch 22/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.1780 - root_mean_squared_error: 17.8097 - val_loss: 340.3766 - val_root_mean_squared_error: 18.1868
# Epoch 23/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.6695 - root_mean_squared_error: 17.8065 - val_loss: 340.0191 - val_root_mean_squared_error: 18.1831
# Epoch 24/60
# 241/241 [==============================] - 11s 44ms/step - loss: 325.8244 - root_mean_squared_error: 17.7872 - val_loss: 341.4412 - val_root_mean_squared_error: 18.2333
# Epoch 25/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.8974 - root_mean_squared_error: 17.7909 - val_loss: 340.2739 - val_root_mean_squared_error: 18.2006
# Epoch 26/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.7774 - root_mean_squared_error: 17.7685 - val_loss: 341.1478 - val_root_mean_squared_error: 18.2332
# Epoch 27/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.9823 - root_mean_squared_error: 17.7802 - val_loss: 340.8747 - val_root_mean_squared_error: 18.2246
# Epoch 28/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.0629 - root_mean_squared_error: 17.7545 - val_loss: 339.3990 - val_root_mean_squared_error: 18.1838
# Epoch 29/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.9439 - root_mean_squared_error: 17.7556 - val_loss: 340.2495 - val_root_mean_squared_error: 18.2138
# Epoch 30/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.8802 - root_mean_squared_error: 17.7571 - val_loss: 342.8643 - val_root_mean_squared_error: 18.2845
# Epoch 31/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.4669 - root_mean_squared_error: 17.7516 - val_loss: 341.9051 - val_root_mean_squared_error: 18.2536
# Epoch 32/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.0215 - root_mean_squared_error: 17.7361 - val_loss: 345.6235 - val_root_mean_squared_error: 18.3470
# Epoch 33/60
# 241/241 [==============================] - 11s 46ms/step - loss: 323.3897 - root_mean_squared_error: 17.7479 - val_loss: 339.1395 - val_root_mean_squared_error: 18.1990
# Epoch 34/60
# 241/241 [==============================] - 11s 45ms/step - loss: 323.3698 - root_mean_squared_error: 17.7596 - val_loss: 339.8460 - val_root_mean_squared_error: 18.2089
# Epoch 35/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.8645 - root_mean_squared_error: 17.7388 - val_loss: 340.1523 - val_root_mean_squared_error: 18.2261
# Epoch 36/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.6090 - root_mean_squared_error: 17.7415 - val_loss: 340.1115 - val_root_mean_squared_error: 18.2356
# Epoch 37/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.8912 - root_mean_squared_error: 17.7518 - val_loss: 338.1929 - val_root_mean_squared_error: 18.1841
# Epoch 38/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.6090 - root_mean_squared_error: 17.7455 - val_loss: 339.5219 - val_root_mean_squared_error: 18.2202
# Epoch 39/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.7894 - root_mean_squared_error: 17.7542 - val_loss: 338.2750 - val_root_mean_squared_error: 18.1883
# Epoch 40/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.3635 - root_mean_squared_error: 17.7459 - val_loss: 338.1867 - val_root_mean_squared_error: 18.1921
# Epoch 41/60
# 241/241 [==============================] - 11s 45ms/step - loss: 322.2684 - root_mean_squared_error: 17.7419 - val_loss: 340.0187 - val_root_mean_squared_error: 18.2394
# Epoch 42/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.5963 - root_mean_squared_error: 17.7289 - val_loss: 338.4387 - val_root_mean_squared_error: 18.2025
# Epoch 43/60
# 241/241 [==============================] - 11s 46ms/step - loss: 321.2071 - root_mean_squared_error: 17.7206 - val_loss: 339.8646 - val_root_mean_squared_error: 18.2374
# Epoch 44/60
# 241/241 [==============================] - 11s 46ms/step - loss: 321.8045 - root_mean_squared_error: 17.7386 - val_loss: 339.8506 - val_root_mean_squared_error: 18.2420
# Epoch 45/60
# 241/241 [==============================] - 11s 46ms/step - loss: 321.0270 - root_mean_squared_error: 17.7184 - val_loss: 339.4857 - val_root_mean_squared_error: 18.2372
# Epoch 46/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.8581 - root_mean_squared_error: 17.7451 - val_loss: 340.2550 - val_root_mean_squared_error: 18.2511
# Epoch 47/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.2638 - root_mean_squared_error: 17.7302 - val_loss: 338.3233 - val_root_mean_squared_error: 18.2078
# Epoch 48/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.9665 - root_mean_squared_error: 17.7216 - val_loss: 341.2822 - val_root_mean_squared_error: 18.2822
# Epoch 49/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.7957 - root_mean_squared_error: 17.7504 - val_loss: 338.6565 - val_root_mean_squared_error: 18.2160
# Epoch 50/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.3987 - root_mean_squared_error: 17.7321 - val_loss: 337.6034 - val_root_mean_squared_error: 18.1854
# Epoch 51/60
# 241/241 [==============================] - 11s 45ms/step - loss: 321.8074 - root_mean_squared_error: 17.7487 - val_loss: 337.3955 - val_root_mean_squared_error: 18.1882
# Epoch 52/60
# 241/241 [==============================] - 11s 46ms/step - loss: 320.6165 - root_mean_squared_error: 17.7182 - val_loss: 337.5852 - val_root_mean_squared_error: 18.1954
# Epoch 53/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.5088 - root_mean_squared_error: 17.7188 - val_loss: 337.1477 - val_root_mean_squared_error: 18.1859
# Epoch 54/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.6465 - root_mean_squared_error: 17.7254 - val_loss: 339.5304 - val_root_mean_squared_error: 18.2452
# Epoch 55/60
# 241/241 [==============================] - 11s 46ms/step - loss: 319.4760 - root_mean_squared_error: 17.6901 - val_loss: 338.7553 - val_root_mean_squared_error: 18.2260
# Epoch 56/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.3535 - root_mean_squared_error: 17.7158 - val_loss: 340.1697 - val_root_mean_squared_error: 18.2627
# Epoch 57/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.2807 - root_mean_squared_error: 17.7154 - val_loss: 339.7703 - val_root_mean_squared_error: 18.2582
# Epoch 58/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.9106 - root_mean_squared_error: 17.7068 - val_loss: 337.8323 - val_root_mean_squared_error: 18.2038
# Epoch 59/60
# 241/241 [==============================] - 11s 45ms/step - loss: 319.6523 - root_mean_squared_error: 17.6983 - val_loss: 338.3284 - val_root_mean_squared_error: 18.2249
# Epoch 60/60
# 241/241 [==============================] - 11s 45ms/step - loss: 320.2562 - root_mean_squared_error: 17.7216 - val_loss: 337.7039 - val_root_mean_squared_error: 18.2050
# 241/241 [==============================] - 2s 6ms/step - loss: 320.2089 - root_mean_squared_error: 17.7244
# 61/61 [==============================] - 0s 7ms/step - loss: 336.3599 - root_mean_squared_error: 18.1744
# Epoch 1/60
# 241/241 [==============================] - 13s 47ms/step - loss: 898.9991 - root_mean_squared_error: 26.8246 - val_loss: 599.7620 - val_root_mean_squared_error: 22.6205
# Epoch 2/60
# 241/241 [==============================] - 11s 44ms/step - loss: 668.0950 - root_mean_squared_error: 23.5740 - val_loss: 537.9421 - val_root_mean_squared_error: 21.8640
# Epoch 3/60
# 241/241 [==============================] - 11s 44ms/step - loss: 572.9726 - root_mean_squared_error: 22.1335 - val_loss: 459.0009 - val_root_mean_squared_error: 20.1922
# Epoch 4/60
# 241/241 [==============================] - 11s 45ms/step - loss: 511.4653 - root_mean_squared_error: 21.1922 - val_loss: 433.3033 - val_root_mean_squared_error: 19.8915
# Epoch 5/60
# 241/241 [==============================] - 11s 45ms/step - loss: 468.2216 - root_mean_squared_error: 20.5132 - val_loss: 405.5716 - val_root_mean_squared_error: 19.4291
# Epoch 6/60
# 241/241 [==============================] - 11s 44ms/step - loss: 420.9673 - root_mean_squared_error: 19.6510 - val_loss: 355.3997 - val_root_mean_squared_error: 18.1533
# Epoch 7/60
# 241/241 [==============================] - 11s 45ms/step - loss: 387.5227 - root_mean_squared_error: 18.9751 - val_loss: 343.5651 - val_root_mean_squared_error: 17.9459
# Epoch 8/60
# 241/241 [==============================] - 11s 45ms/step - loss: 364.1740 - root_mean_squared_error: 18.4829 - val_loss: 334.6226 - val_root_mean_squared_error: 17.7007
# Epoch 9/60
# 241/241 [==============================] - 11s 44ms/step - loss: 357.0521 - root_mean_squared_error: 18.3389 - val_loss: 333.4154 - val_root_mean_squared_error: 17.7235
# Epoch 10/60
# 241/241 [==============================] - 11s 45ms/step - loss: 357.3449 - root_mean_squared_error: 18.3899 - val_loss: 331.1848 - val_root_mean_squared_error: 17.7153
# Epoch 11/60
# 241/241 [==============================] - 11s 44ms/step - loss: 348.5697 - root_mean_squared_error: 18.1871 - val_loss: 331.0973 - val_root_mean_squared_error: 17.7142
# Epoch 12/60
# 241/241 [==============================] - 11s 45ms/step - loss: 348.2722 - root_mean_squared_error: 18.2154 - val_loss: 329.4500 - val_root_mean_squared_error: 17.7444
# Epoch 13/60
# 241/241 [==============================] - 11s 44ms/step - loss: 345.8858 - root_mean_squared_error: 18.1794 - val_loss: 327.5582 - val_root_mean_squared_error: 17.6901
# Epoch 14/60
# 241/241 [==============================] - 11s 44ms/step - loss: 344.9088 - root_mean_squared_error: 18.1730 - val_loss: 327.0780 - val_root_mean_squared_error: 17.6787
# Epoch 15/60
# 241/241 [==============================] - 11s 45ms/step - loss: 342.6239 - root_mean_squared_error: 18.1254 - val_loss: 325.9731 - val_root_mean_squared_error: 17.6772
# Epoch 16/60
# 241/241 [==============================] - 11s 45ms/step - loss: 339.9790 - root_mean_squared_error: 18.0627 - val_loss: 327.0691 - val_root_mean_squared_error: 17.7106
# Epoch 17/60
# 241/241 [==============================] - 11s 45ms/step - loss: 338.3542 - root_mean_squared_error: 18.0385 - val_loss: 324.7190 - val_root_mean_squared_error: 17.6782
# Epoch 18/60
# 241/241 [==============================] - 11s 44ms/step - loss: 337.7069 - root_mean_squared_error: 18.0372 - val_loss: 324.1717 - val_root_mean_squared_error: 17.6671
# Epoch 19/60
# 241/241 [==============================] - 11s 45ms/step - loss: 334.9370 - root_mean_squared_error: 17.9705 - val_loss: 325.9474 - val_root_mean_squared_error: 17.7188
# Epoch 20/60
# 241/241 [==============================] - 11s 44ms/step - loss: 334.6963 - root_mean_squared_error: 17.9771 - val_loss: 325.1616 - val_root_mean_squared_error: 17.7027
# Epoch 21/60
# 241/241 [==============================] - 11s 44ms/step - loss: 334.8180 - root_mean_squared_error: 17.9885 - val_loss: 322.7123 - val_root_mean_squared_error: 17.6544
# Epoch 22/60
# 241/241 [==============================] - 11s 44ms/step - loss: 333.2540 - root_mean_squared_error: 17.9511 - val_loss: 322.7137 - val_root_mean_squared_error: 17.6631
# Epoch 23/60
# 241/241 [==============================] - 11s 45ms/step - loss: 332.4075 - root_mean_squared_error: 17.9366 - val_loss: 322.5721 - val_root_mean_squared_error: 17.6635
# Epoch 24/60
# 241/241 [==============================] - 11s 44ms/step - loss: 333.0879 - root_mean_squared_error: 17.9632 - val_loss: 322.0239 - val_root_mean_squared_error: 17.6652
# Epoch 25/60
# 241/241 [==============================] - 11s 45ms/step - loss: 330.6455 - root_mean_squared_error: 17.9048 - val_loss: 321.7011 - val_root_mean_squared_error: 17.6571
# Epoch 26/60
# 241/241 [==============================] - 11s 44ms/step - loss: 330.8426 - root_mean_squared_error: 17.9183 - val_loss: 321.5781 - val_root_mean_squared_error: 17.6614
# Epoch 27/60
# 241/241 [==============================] - 11s 44ms/step - loss: 330.0688 - root_mean_squared_error: 17.9030 - val_loss: 320.6060 - val_root_mean_squared_error: 17.6396
# Epoch 28/60
# 241/241 [==============================] - 11s 44ms/step - loss: 330.3560 - root_mean_squared_error: 17.9130 - val_loss: 320.7753 - val_root_mean_squared_error: 17.6506
# Epoch 29/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.4151 - root_mean_squared_error: 17.8940 - val_loss: 321.2334 - val_root_mean_squared_error: 17.6616
# Epoch 30/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.8305 - root_mean_squared_error: 17.9058 - val_loss: 321.0531 - val_root_mean_squared_error: 17.6629
# Epoch 31/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.4952 - root_mean_squared_error: 17.9028 - val_loss: 320.3532 - val_root_mean_squared_error: 17.6539
# Epoch 32/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.6706 - root_mean_squared_error: 17.8852 - val_loss: 321.5412 - val_root_mean_squared_error: 17.6829
# Epoch 33/60
# 241/241 [==============================] - 11s 45ms/step - loss: 329.1235 - root_mean_squared_error: 17.8966 - val_loss: 320.1603 - val_root_mean_squared_error: 17.6529
# Epoch 34/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.2979 - root_mean_squared_error: 17.8813 - val_loss: 320.0638 - val_root_mean_squared_error: 17.6558
# Epoch 35/60
# 241/241 [==============================] - 11s 45ms/step - loss: 328.3148 - root_mean_squared_error: 17.8863 - val_loss: 320.1732 - val_root_mean_squared_error: 17.6597
# Epoch 36/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.7423 - root_mean_squared_error: 17.8731 - val_loss: 320.5992 - val_root_mean_squared_error: 17.6738
# Epoch 37/60
# 241/241 [==============================] - 11s 44ms/step - loss: 327.9955 - root_mean_squared_error: 17.8845 - val_loss: 319.9241 - val_root_mean_squared_error: 17.6613
# Epoch 38/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.9899 - root_mean_squared_error: 17.8870 - val_loss: 320.6966 - val_root_mean_squared_error: 17.6837
# Epoch 39/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.0576 - root_mean_squared_error: 17.8649 - val_loss: 319.9198 - val_root_mean_squared_error: 17.6677
# Epoch 40/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.9234 - root_mean_squared_error: 17.8923 - val_loss: 319.8876 - val_root_mean_squared_error: 17.6670
# Epoch 41/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.9169 - root_mean_squared_error: 17.8687 - val_loss: 320.8518 - val_root_mean_squared_error: 17.6971
# Epoch 42/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.9985 - root_mean_squared_error: 17.8737 - val_loss: 321.7882 - val_root_mean_squared_error: 17.7231
# Epoch 43/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.1380 - root_mean_squared_error: 17.8771 - val_loss: 319.1855 - val_root_mean_squared_error: 17.6607
# Epoch 44/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.7966 - root_mean_squared_error: 17.8713 - val_loss: 318.8066 - val_root_mean_squared_error: 17.6531
# Epoch 45/60
# 241/241 [==============================] - 11s 45ms/step - loss: 327.0704 - root_mean_squared_error: 17.8853 - val_loss: 319.1647 - val_root_mean_squared_error: 17.6668
# Epoch 46/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.9304 - root_mean_squared_error: 17.8804 - val_loss: 319.6557 - val_root_mean_squared_error: 17.6777
# Epoch 47/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.9631 - root_mean_squared_error: 17.8776 - val_loss: 319.9938 - val_root_mean_squared_error: 17.6795
# Epoch 48/60
# 241/241 [==============================] - 11s 45ms/step - loss: 326.7307 - root_mean_squared_error: 17.8819 - val_loss: 318.7616 - val_root_mean_squared_error: 17.6663
# Epoch 49/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.9126 - root_mean_squared_error: 17.8659 - val_loss: 318.5122 - val_root_mean_squared_error: 17.6584
# Epoch 50/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.6656 - root_mean_squared_error: 17.8603 - val_loss: 318.8665 - val_root_mean_squared_error: 17.6682
# Epoch 51/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.5922 - root_mean_squared_error: 17.8552 - val_loss: 318.7531 - val_root_mean_squared_error: 17.6660
# Epoch 52/60
# 241/241 [==============================] - 11s 44ms/step - loss: 325.6342 - root_mean_squared_error: 17.8561 - val_loss: 318.6278 - val_root_mean_squared_error: 17.6595
# Epoch 53/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.5145 - root_mean_squared_error: 17.8564 - val_loss: 317.9124 - val_root_mean_squared_error: 17.6488
# Epoch 54/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.5080 - root_mean_squared_error: 17.8606 - val_loss: 319.5222 - val_root_mean_squared_error: 17.6911
# Epoch 55/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.5548 - root_mean_squared_error: 17.8616 - val_loss: 318.1648 - val_root_mean_squared_error: 17.6561
# Epoch 56/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.0615 - root_mean_squared_error: 17.8484 - val_loss: 319.0084 - val_root_mean_squared_error: 17.6805
# Epoch 57/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.2372 - root_mean_squared_error: 17.8541 - val_loss: 318.3119 - val_root_mean_squared_error: 17.6576
# Epoch 58/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.5512 - root_mean_squared_error: 17.8637 - val_loss: 319.0076 - val_root_mean_squared_error: 17.6733
# Epoch 59/60
# 241/241 [==============================] - 11s 45ms/step - loss: 324.6668 - root_mean_squared_error: 17.8408 - val_loss: 318.3023 - val_root_mean_squared_error: 17.6658
# Epoch 60/60
# 241/241 [==============================] - 11s 45ms/step - loss: 325.0610 - root_mean_squared_error: 17.8533 - val_loss: 318.5896 - val_root_mean_squared_error: 17.6743

# %%
# Create concat model for overview
tabular_NN = build_neural_net(input_size=12, hidden_nodes=20)
image_size = (64, 64, 3)
image_NN = build_convol_net(image_size=image_size, hidden_nodes=20)
concat_model = concatenate_models(image_NN, tabular_NN, hidden_nodes=20)

# Create overview of layers in model
tf.keras.utils.plot_model(concat_model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB')
